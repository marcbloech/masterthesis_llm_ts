# %%
import pandas as pd
import numpy as np

# %%
from transform_annotations_functions import unify_salsa_processing
from transform_annotations_functions import Family, Quality

# %%
def run_on_file_dict(file_dict, dataset_name, compute_metrics=True):
    sentences_dataset = []
    edits_dataset = []

    for filepath, system_name in file_dict.items():
        df_sent, df_edits = unify_salsa_processing(
            file_path_or_data=filepath,
            dataset_name=dataset_name,
            system_name=system_name,
            compute_metrics=compute_metrics
        )
        sentences_dataset.append(df_sent)
        edits_dataset.append(df_edits)

    sentences_dataset = pd.concat(sentences_dataset)
    edits_dataset = pd.concat(edits_dataset)

    print("DEBUG COLS: ", edits_dataset.columns)

    # Convert enum objects to strings
    enum_objects = ["Family", "Quality"]
    for enum_object in enum_objects:
        if enum_object in edits_dataset.columns:
            edits_dataset[enum_object] = edits_dataset[enum_object].apply(
                lambda x: x.value if isinstance(x, (Family, Quality)) else x
            )

    # Add new columns for input and output text spans
    edits_dataset['Input Text'] = edits_dataset.apply(
        lambda row: get_text_from_indices(row['Source'], eval(row['Input Index']) if isinstance(row['Input Index'], str) else row['Input Index']), 
        axis=1
    )
    
    edits_dataset['Output Text'] = edits_dataset.apply(
        lambda row: get_text_from_indices(row['Target'], eval(row['Output Index']) if isinstance(row['Output Index'], str) else row['Output Index']), 
        axis=1
    )

    # Convert lists to strings for better readability
    edits_dataset['Input Text'] = edits_dataset['Input Text'].apply(lambda x: ' | '.join(x) if x else '')
    edits_dataset['Output Text'] = edits_dataset['Output Text'].apply(lambda x: ' | '.join(x) if x else '')
            
    return sentences_dataset, edits_dataset


# Add helper function to get text spans from indices
# (to show actual texts affected in output tables)
def get_text_from_indices(text: str, indices: list) -> list:
    """Extract text spans from a string based on list of index pairs."""
    if not indices or not isinstance(indices, list):
        return []
    
    text_spans = []
    for start, end in indices:
        if isinstance(start, int) and isinstance(end, int):
            text_spans.append(text[start:end])
    
    return text_spans

# %% [markdown]
# #  Analysis Execution - Metric Calculation and Analysis per Dataset
#
# ## Load, transform and combine data (ready for analysis)

# %%
global_compute_metrics = True

# %% [markdown]
# ### Dataset 01: WikiEN (English)

# %%
# load data

file_dict = {
    '../data/salsa_annotations/final_annotated/data_f_wikiEN_ChatGPT.json': 'ChatGPT',
    '../data/salsa_annotations/final_annotated/data_f_wikiEN_LLAMA.json': 'LLAMA',
    '../data/salsa_annotations/final_annotated/data_f_wikiEN_MUSS.json': 'MUSS',
     '../data/salsa_annotations/final_annotated/data_f_wikiEN_DisSim.json': 'DisSim'
}

df_sentences_wikiEN, df_edits_wikiEN = run_on_file_dict(
    file_dict, 
    "wikiEN", 
    compute_metrics=global_compute_metrics)
# Out:
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  3.13it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 12.78it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 11.57it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 11.60it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 11.22it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  8.59it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 11.71it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 12.23it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 15.10it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  9.81it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 12.91it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 11.42it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 13.41it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 11.31it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 11.79it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 13.88it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 14.41it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 11.05it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 12.40it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 13.99it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  5.64it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 15.26it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 10.09it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 15.56it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  8.61it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 11.43it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  8.89it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 15.49it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 11.33it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 14.91it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 15.24it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  9.42it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 11.54it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 11.49it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 13.53it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 14.42it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 10.63it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  9.68it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 13.54it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 11.21it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  9.11it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 13.26it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 11.07it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 10.89it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 13.38it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 10.70it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 10.66it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 11.01it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 14.62it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 13.31it/s]
# WARNING:root:Structure edit missing or malformed structure_type field; annotation is: {'impact': {'val': 'good', 'good': 'minor'}, 'grammar_error': 'no'}
# WARNING:root:Structure edit missing or malformed structure_type field; annotation is: {'impact': {'val': 'bad', 'bad': 'minor'}, 'grammar_error': 'no'}
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 13.96it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 13.24it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 13.00it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 11.19it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 13.18it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  9.35it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 11.91it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  7.52it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 14.05it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 11.17it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 12.06it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 11.76it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 14.13it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 11.77it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 13.25it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 13.27it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 11.49it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 11.03it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 13.61it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 11.48it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 11.76it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 12.78it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 10.35it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 14.82it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  9.22it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 13.46it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 13.33it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 13.62it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 11.94it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 14.20it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 14.16it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 10.81it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 11.37it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 13.72it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 13.53it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 15.77it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 11.51it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 10.79it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 12.74it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 14.20it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 11.63it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 14.55it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 12.35it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  8.10it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 13.56it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 10.75it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 10.36it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 13.84it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 11.01it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 13.85it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 11.94it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 11.51it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 11.65it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# ...
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 13.69it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  9.96it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 12.08it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 11.86it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  9.03it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  8.46it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  9.49it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 14.91it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  8.00it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  9.77it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 11.10it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 14.06it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 11.16it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 12.32it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 13.38it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  7.93it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  9.51it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 11.09it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 13.20it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 13.56it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  7.94it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  9.17it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 10.79it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  7.11it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  8.23it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 11.82it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  9.46it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  9.63it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 13.99it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  9.92it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 11.18it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  7.49it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 14.80it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 10.90it/s]
# DEBUG COLS:  Index(['Sentence ID', 'Source', 'Target', 'System', 'Dataset', 'Family',
#        'Edit Type', 'Edit Sub-Type', 'Edit Classification',
#        'Structure Sub-Type', 'Quality', 'Information Impact', 'Grammar Error',
#        'Significance', 'Input Index', 'Output Index', 'Constituent Edits',
#        'Is Constituent Edit', 'Parent Edit Type', 'Constituent Input Index',
#        'Constituent Output Index'],
#       dtype='object')

# %%
df_sentences_wikiEN.head(5)
# Out:
#    Sentence ID                                             Source  \
# 0  ChatGPT_001  The N1 road also designated as RN1, is a road ...
# 1  ChatGPT_002  Originating in the capital city of Bangui, the...
# 2  ChatGPT_003  As a key component of the country's road netwo...
# 3  ChatGPT_004  The N1 route commences in the heart of Bangui,...
# 4  ChatGPT_005  The terrain along this stretch is characterize...
#
#                                               Target   System Dataset  \
# 0  The N1 road, also called RN1, is a road in the...  ChatGPT  wikiEN
# 1  The road starts in Bangui and goes northwest t...  ChatGPT  wikiEN
# 2  The N1 is an important part of the country's r...  ChatGPT  wikiEN
# 3  The N1 route starts in the center of Bangui, t...  ChatGPT  wikiEN
# 4  The land here is mostly flat or gently sloping...  ChatGPT  wikiEN
#
#    Total Edits  substitution_count  insertion_count  split_count  \
# 0            4                   1                1            1
# 1            7                   1                0            0
# 2            5                   2                0            1
# 3            4                   3                0            0
# 4           10                   5                1            0
#
#    structure_count  ...  Lexical_Diversity_Difference  \
# 0                1  ...                      0.040909
# 1                1  ...                      0.166667
# 2                1  ...                      0.088889
# 3                0  ...                     -0.007527
# 4                2  ...                      0.024074
#
#    Syntactic_Complexity_Source  Syntactic_Complexity_Target  \
# 0                            2                            1
# 1                            3                            2
# 2                            2                            2
# 3                            1                            1
# 4                            3                            0
#
#    Syntactic_Complexity_Difference  BERTScore_Precision  BERTScore_Recall  \
# 0                               -1             0.965502          0.956754
# 1                               -1             0.963212          0.928761
# 2                                0             0.956089          0.954746
# 3                                0             0.987401          0.983464
# 4                               -3             0.936264          0.917814
#
#    BERTScore_F1      GLEU  LENS_SALSA  no_edit_count
# 0      0.961108  0.372340   68.790299            NaN
# 1      0.945673  0.141509   73.989666            NaN
# 2      0.955417  0.309524   76.867175            NaN
# 3      0.985429  0.708955   60.895467            NaN
# 4      0.926947  0.145455   76.670897            NaN
#
# [5 rows x 30 columns]

# %%
df_edits_wikiEN.head(5)
# Out:
#    Sentence ID                                             Source  \
# 0  ChatGPT_001  The N1 road also designated as RN1, is a road ...
# 1  ChatGPT_001  The N1 road also designated as RN1, is a road ...
# 2  ChatGPT_001  The N1 road also designated as RN1, is a road ...
# 3  ChatGPT_001  The N1 road also designated as RN1, is a road ...
# 4  ChatGPT_002  Originating in the capital city of Bangui, the...
#
#                                               Target   System Dataset  \
# 0  The N1 road, also called RN1, is a road in the...  ChatGPT  wikiEN
# 1  The N1 road, also called RN1, is a road in the...  ChatGPT  wikiEN
# 2  The N1 road, also called RN1, is a road in the...  ChatGPT  wikiEN
# 3  The N1 road, also called RN1, is a road in the...  ChatGPT  wikiEN
# 4  The road starts in Bangui and goes northwest t...  ChatGPT  wikiEN
#
#        Family     Edit Type   Edit Sub-Type Edit Classification  \
# 0  Conceptual  substitution            None   Good Substitution
# 1  Conceptual     insertion            None   Trivial Insertion
# 2      Syntax         split  Sentence Split          Good Split
# 3      Syntax     structure  Part of Speech   Trivial Structure
# 4  Conceptual      deletion    Bad Deletion        Bad Deletion
#
#   Structure Sub-Type  ... Significance Input Index Output Index  \
# 0               None  ...            1  [[17, 27]]   [[18, 24]]
# 1               None  ...            0        None   [[43, 46]]
# 2               None  ...            0        None         None
# 3     Part of Speech  ...            0        None         None
# 4               None  ...            0  [[19, 34]]         None
#
#    Constituent Edits Is Constituent Edit Parent Edit Type  \
# 0                  0               False              N/A
# 1                  0               False              N/A
# 2                  1               False              N/A
# 3                  1               False              N/A
# 4                  0               False              N/A
#
#    Constituent Input Index  Constituent Output Index       Input Text  \
# 0                       []                        []       designated
# 1                       []                        []
# 2             [[[74, 78]]]              [[[76, 78]]]
# 3            [[[79, 104]]]   [[[76, 78], [97, 101]]]
# 4                       []                        []  capital city of
#
#   Output Text
# 0      called
# 1         the
# 2
# 3
# 4
#
# [5 rows x 23 columns]

# %%
# Verify whether all edits are being properly transformed: 
# Calculate number of edits directly

import json

df_valuecounts = df_edits_wikiEN['System'].value_counts()
df_valuecounts

def count_edits_per_file(file_dict):
    edits_per_file = {}
    
    # Iterate through each file in the dictionary
    for file_path, label in file_dict.items():
        try:
            # Load the JSON file
            with open(file_path, 'r') as file:
                data = json.load(file)

            total_edits = 0
            
            # Iterate through each entry in the JSON file
            for entry in data:
                if 'edits' in entry:
                    # Count the number of edits for the current entry
                    total_edits += len(entry['edits'])
            
            # Store the result in the edits_per_file dictionary with the label
            edits_per_file[label] = total_edits
        
        except FileNotFoundError:
            # If the file is not found, handle the error
            edits_per_file[label] = 'File not found'
        except json.JSONDecodeError:
            # If the file is not a valid JSON, handle the error
            edits_per_file[label] = 'Invalid JSON format'

    return edits_per_file

def verify_edits_transformations(df_edits, file_dict):
    # get all systems in df_edits
    systems = df_edits['System'].unique()
    
    # count edits per system
    # first remove all "Is Constituent Edit" = True entries
    df_edits_no_constituent = df_edits[df_edits['Is Constituent Edit'] == False]

    # also remove all rows where edit_type is "no_edit"
    df_edits_no_constituent = df_edits_no_constituent[df_edits_no_constituent['Edit Type'] != 'no_edit']

    edits_count_df = df_edits_no_constituent['System'].value_counts()
    
    # compare edits_count with df_valuecounts
    edits_count_file = count_edits_per_file(file_dict)
    print(edits_count_file)
    
    for system in systems:
        if edits_count_df[system] != edits_count_file[system]:
            print(f"**************************************************")
            print(f"ATTENTION Mismatch for system {system}")
            print(f"   edits in source file: {edits_count_file[system]}")
            print(f"   edits in transformed DF: {edits_count_df[system]}")
            print(f"**************************************************")
        else:
            print(f"OK for system {system}")


verify_edits_transformations(df_edits_wikiEN, file_dict)
# Out:
# {'ChatGPT': 213, 'LLAMA': 278, 'MUSS': 220, 'DisSim': 293}
# OK for system ChatGPT
# OK for system LLAMA
# OK for system MUSS
# OK for system DisSim

# %% [markdown]
# ### Dataset 02: Cochrane Medical (English)

# %%
# load data cochrane data

dataset_name = 'cochrane'

file_dict = {
    '../data/salsa_annotations/final_annotated/data_f_Cochrane_ChatGPT.json': 'ChatGPT',
    '../data/salsa_annotations/final_annotated/data_f_Cochrane_LLAMA.json': 'LLAMA',
    '../data/salsa_annotations/final_annotated/data_f_Cochrane_MUSS.json': 'MUSS',
    '../data/salsa_annotations/final_annotated/data_f_Cochrane_DisSim.json': 'DisSim'
}

df_sentences_cochrane, df_edits_cochrane = run_on_file_dict(
    file_dict, 
    dataset_name,
    compute_metrics=global_compute_metrics
    )

df_sentences_cochrane.tail()
# Out:
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  2.44it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 12.63it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  8.32it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 13.00it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 13.57it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 11.28it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 13.56it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 15.03it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 10.98it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  6.64it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 14.20it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 11.83it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 14.19it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  7.12it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 10.15it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 10.80it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  6.47it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  7.50it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  9.53it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 14.16it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 13.86it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  8.97it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 11.41it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 11.57it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 14.55it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 10.87it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 10.64it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 14.16it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 12.06it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 13.65it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 11.10it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 15.14it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 13.95it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 12.97it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 13.61it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 10.39it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 11.15it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 12.26it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  9.84it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 14.63it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 14.55it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 12.03it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  9.99it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 13.61it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 13.53it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 14.06it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 11.74it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 13.80it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 14.47it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 15.95it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  9.73it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 15.07it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 13.92it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  8.53it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 12.78it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 11.11it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 13.04it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 13.92it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 11.94it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 11.53it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 13.80it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 11.80it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 15.32it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  5.20it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 11.68it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 12.02it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  6.46it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  8.16it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  9.32it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 14.69it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 11.05it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 14.16it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 11.32it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 11.28it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 12.86it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 10.98it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 10.96it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 13.10it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 12.02it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 12.41it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  8.40it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 11.74it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  8.14it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 11.88it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 12.72it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 12.62it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 12.06it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 12.91it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  9.47it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 12.79it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 12.67it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 11.85it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  9.21it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 11.37it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 12.85it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 12.63it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 10.91it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 12.65it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 13.05it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 14.48it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  8.22it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 14.85it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 12.38it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  7.93it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# ...
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 10.46it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 10.04it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 12.98it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  8.72it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  9.02it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 10.79it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 11.27it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 11.34it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  8.09it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 13.15it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 12.96it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 11.43it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  8.67it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 10.75it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 10.03it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 10.95it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  8.06it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 10.66it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 12.79it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  9.04it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  6.47it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 10.70it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 11.92it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 12.52it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 11.03it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 13.27it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 13.78it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 13.67it/s]
# DEBUG COLS:  Index(['Sentence ID', 'Source', 'Target', 'System', 'Dataset', 'Family',
#        'Edit Type', 'Edit Sub-Type', 'Edit Classification',
#        'Structure Sub-Type', 'Quality', 'Information Impact', 'Grammar Error',
#        'Significance', 'Input Index', 'Output Index', 'Constituent Edits',
#        'Is Constituent Edit', 'Parent Edit Type', 'Constituent Input Index',
#        'Constituent Output Index'],
#       dtype='object')
#    Sentence ID                                             Source  \
# 45  DisSim_046  Low‐certainty evidence did not detect a differ...
# 46  DisSim_047  No studies assessed SAEs for the following: be...
# 47  DisSim_048  Repetitive transcranial magnetic stimulation (...
# 48  DisSim_049  Current pharmacological and psychotherapeutic ...
# 49  DisSim_050  The evidence is very uncertain about the effec...
#
#                                                Target  System   Dataset  \
# 45  Low‐certainty evidence did not detect a differ...  DisSim  cochrane
# 46  No studies assessed SAEs for the following. ||...  DisSim  cochrane
# 47  Repetitive transcranial magnetic stimulation (...  DisSim  cochrane
# 48  Current pharmacological and psychotherapeutic ...  DisSim  cochrane
# 49  The evidence is very uncertain about the effec...  DisSim  cochrane
#
#     Total Edits  substitution_count  deletion_count  reorder_count  \
# 45            4                   0               0              0
# 46            6                   0               0              0
# 47            0                   0               0              0
# 48            0                   0               0              0
# 49            0                   0               0              0
#
#     structure_count  ...  Lexical_Diversity_Difference  \
# 45              NaN  ...                     -0.041667
# 46              NaN  ...                     -0.294643
# 47              NaN  ...                      0.000000
# 48              NaN  ...                      0.000000
# 49              NaN  ...                      0.000000
#
#     Syntactic_Complexity_Source  Syntactic_Complexity_Target  \
# 45                            2                            2
# 46                            1                            4
# 47                            1                            1
# 48                            1                            1
# 49                            0                            0
#
#     Syntactic_Complexity_Difference  BERTScore_Precision  BERTScore_Recall  \
# 45                                0             0.946639          0.978627
# 46                                3             0.935131          0.954521
# 47                                0             1.000000          1.000000
# 48                                0             1.000000          1.000000
# 49                                0             1.000000          1.000000
#
#     BERTScore_F1      GLEU  LENS_SALSA  no_edit_count
# 45      0.962367  0.527273   57.879913            0.0
# 46      0.944727  0.400000   54.451776            0.0
# 47      1.000000  1.000000   62.297642            1.0
# 48      1.000000  1.000000   68.792772            1.0
# 49      1.000000  1.000000   71.432281            1.0
#
# [5 rows x 30 columns]

# %%
df_edits_cochrane.tail(5)
# Out:
#     Sentence ID                                             Source  \
# 283  DisSim_047  No studies assessed SAEs for the following: be...
# 284  DisSim_047  No studies assessed SAEs for the following: be...
# 285  DisSim_048  Repetitive transcranial magnetic stimulation (...
# 286  DisSim_049  Current pharmacological and psychotherapeutic ...
# 287  DisSim_050  The evidence is very uncertain about the effec...
#
#                                                 Target  System   Dataset  \
# 283  No studies assessed SAEs for the following. ||...  DisSim  cochrane
# 284  No studies assessed SAEs for the following. ||...  DisSim  cochrane
# 285  Repetitive transcranial magnetic stimulation (...  DisSim  cochrane
# 286  Current pharmacological and psychotherapeutic ...  DisSim  cochrane
# 287  The evidence is very uncertain about the effec...  DisSim  cochrane
#
#          Family  Edit Type   Edit Sub-Type Edit Classification  \
# 283  Conceptual  insertion      Repetition       Bad Insertion
# 284      Syntax      split  Trivial Change       Trivial Split
# 285        None    no_edit            None                None
# 286        None    no_edit            None                None
# 287        None    no_edit            None                None
#
#     Structure Sub-Type  ... Significance Input Index  Output Index  \
# 283                NaN  ...            0        None  [[167, 186]]
# 284                NaN  ...            0        None          None
# 285                NaN  ...            0        None          None
# 286                NaN  ...            0        None          None
# 287                NaN  ...            0        None          None
#
#      Constituent Edits Is Constituent Edit Parent Edit Type  \
# 283                  0               False              N/A
# 284                  1               False              N/A
# 285                  0               False              N/A
# 286                  0               False              N/A
# 287                  0               False              N/A
#
#      Constituent Input Index  Constituent Output Index Input Text  \
# 283                       []                        []
# 284                   [None]            [[[164, 166]]]
# 285                     None                      None
# 286                     None                      None
# 287                     None                      None
#
#              Output Text
# 283  No studies assessed
# 284
# 285
# 286
# 287
#
# [5 rows x 23 columns]

# %%
verify_edits_transformations(df_edits_cochrane, file_dict)
# Out:
# {'ChatGPT': 270, 'LLAMA': 302, 'MUSS': 182, 'DisSim': 281}
# OK for system ChatGPT
# OK for system LLAMA
# OK for system MUSS
# OK for system DisSim

# %% [markdown]
# ### Dataset 03: SCOTUS (Legal, English)

# %%
# load data cochrane data

dataset_name = 'scotus'

file_dict = {
    '../data/salsa_annotations/final_annotated/data_f_SCOTUS_ChatGPT.json': 'ChatGPT',
    '../data/salsa_annotations/final_annotated/data_f_SCOTUS_LLAMA.json': 'LLAMA',
    '../data/salsa_annotations/final_annotated/data_f_SCOTUS_MUSS.json': 'MUSS',
    '../data/salsa_annotations/final_annotated/data_f_SCOTUS_DisSim.json': 'DisSim'
}

df_sentences_scotus, df_edits_scotus = run_on_file_dict(
    file_dict, 
    dataset_name,
    compute_metrics=global_compute_metrics
    )

df_sentences_scotus.tail()
# Out:
# WARNING:root:Structure edit missing or malformed structure_type field; annotation is: {'impact': {'val': 'good', 'good': 'somewhat'}, 'grammar_error': 'no'}
# WARNING:root:Structure edit missing or malformed structure_type field; annotation is: {'impact': {'val': 'good', 'good': 'somewhat'}, 'grammar_error': 'no'}
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  8.99it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  8.72it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 10.74it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 11.27it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 11.81it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 11.14it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 11.57it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 15.18it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 11.46it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 14.23it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 14.73it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 13.65it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 15.54it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 14.91it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 12.43it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 14.32it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 14.54it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  9.87it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 15.45it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 12.02it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 13.26it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 12.00it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  6.77it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  6.80it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 11.71it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 11.45it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  8.79it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 12.04it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 11.01it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 11.31it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  9.13it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 11.27it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 14.26it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 14.12it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 14.23it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 13.86it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 15.17it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 15.07it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  9.74it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 15.40it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 11.70it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  8.90it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  9.60it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 11.35it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 11.82it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 11.61it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  7.72it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 10.69it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  9.19it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 11.85it/s]
# WARNING:root:Structure edit missing or malformed structure_type field; annotation is: {'impact': {'val': 'good', 'good': 'minor'}, 'grammar_error': 'no'}
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  6.44it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  5.91it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 12.03it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 11.92it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 14.65it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 11.54it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 11.72it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 12.58it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 11.93it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 12.80it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 11.02it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 13.90it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 15.45it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 13.24it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 12.97it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 14.89it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 11.25it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 10.82it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 14.77it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 12.39it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 15.35it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 11.33it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  7.83it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 14.24it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 13.78it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 14.04it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 11.53it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 13.60it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 11.36it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 13.40it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  9.76it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 11.13it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  9.12it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 13.15it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 14.81it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 13.59it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 14.14it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 14.19it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  9.28it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 14.37it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 11.90it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  9.45it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 10.72it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 11.35it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 13.89it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 11.95it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  8.84it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 11.14it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 11.32it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 13.24it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  9.22it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  9.92it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 11.43it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# ...
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  5.61it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 10.01it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 10.10it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 11.65it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  6.31it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  9.98it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  9.49it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 11.39it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  8.44it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 10.70it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 13.42it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 10.42it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 14.16it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 11.16it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 15.36it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 14.19it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  8.90it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  8.83it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  9.39it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  6.33it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  8.28it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  9.49it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 12.14it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 10.78it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  6.59it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 10.98it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  8.71it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 11.56it/s]
# DEBUG COLS:  Index(['Sentence ID', 'Source', 'Target', 'System', 'Dataset', 'Family',
#        'Edit Type', 'Edit Sub-Type', 'Edit Classification',
#        'Structure Sub-Type', 'Quality', 'Information Impact', 'Grammar Error',
#        'Significance', 'Input Index', 'Output Index', 'Constituent Edits',
#        'Is Constituent Edit', 'Parent Edit Type', 'Constituent Input Index',
#        'Constituent Output Index'],
#       dtype='object')
#    Sentence ID                                             Source  \
# 45  DisSim_046  Asencio-Cordero cannot invoke the exception hi...
# 46  DisSim_047  Thus in United States ex rel. Knauff v. Shaugh...
# 47  DisSim_048  The District Court granted summary judgment to...
# 48  DisSim_049  Thus in Apprendi v. New Jersey, 530 U. S. 466,...
# 49  DisSim_050  But a sentencing procedure followed by a few S...
#
#                                                Target  System Dataset  \
# 45  Asencio-Cordero can not invoke the exception h...  DisSim  scotus
# 46  ... forbid aliens or classes of aliens. || Thi...  DisSim  scotus
# 47  The District Court granted summary judgment. |...  DisSim  scotus
# 48  A novel `` sentencing enhancement '' was uncon...  DisSim  scotus
# 49  But a sentencing procedure followed by a few S...  DisSim  scotus
#
#     Total Edits  substitution_count  split_count  structure_count  \
# 45            2                   0            2              NaN
# 46           17                   0            6              NaN
# 47            6                   0            4              NaN
# 48           10                   0            3              NaN
# 49            1                   0            1              NaN
#
#     deletion_count  ...  Lexical_Diversity_Difference  \
# 45               0  ...                      0.005926
# 46               0  ...                     -0.096471
# 47               0  ...                     -0.214554
# 48               1  ...                     -0.066287
# 49               0  ...                      0.005109
#
#     Syntactic_Complexity_Source  Syntactic_Complexity_Target  \
# 45                            4                            4
# 46                            4                            4
# 47                            4                            4
# 48                            5                            5
# 49                            3                            3
#
#     Syntactic_Complexity_Difference  BERTScore_Precision  BERTScore_Recall  \
# 45                                0             0.966063          0.974282
# 46                                0             0.893951          0.910212
# 47                                0             0.928381          0.963657
# 48                                0             0.909108          0.934313
# 49                                0             0.953538          0.951542
#
#     BERTScore_F1      GLEU  LENS_SALSA  no_edit_count
# 45      0.970155  0.484127   58.083200            0.0
# 46      0.902008  0.510638   16.050099            0.0
# 47      0.945690  0.405941   54.102457            0.0
# 48      0.921538  0.466443   36.632434            0.0
# 49      0.952539  0.674603   61.412752            0.0
#
# [5 rows x 30 columns]

# %%
verify_edits_transformations(df_edits_scotus, file_dict)
# Out:
# {'ChatGPT': 298, 'LLAMA': 299, 'MUSS': 206, 'DisSim': 277}
# OK for system ChatGPT
# OK for system LLAMA
# OK for system MUSS
# OK for system DisSim

# %% [markdown]
# ### Dataset 04: wikiDE (Wikipedia, German)

# %%
# load wikiDE data
dataset_name = 'wikiDE'

file_dict = {
    '../data/salsa_annotations/final_annotated/data_f_wikiDE_ChatGPT.json': 'ChatGPT',
    '../data/salsa_annotations/final_annotated/data_f_wikiDE_LLAMA.json': 'LLAMA',
    '../data/salsa_annotations/final_annotated/data_f_wikiDE_MBART.json': 'MUSS',
}

df_sentences_wikiDE, df_edits_wikiDE = run_on_file_dict(
    file_dict, 
    dataset_name,
    compute_metrics=global_compute_metrics
)

# Display the first few rows
df_sentences_wikiDE.head()
# Out:
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Debug: calculating german BERTSCORE
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  6.58it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Debug: calculating german BERTSCORE
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  9.37it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Debug: calculating german BERTSCORE
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  6.86it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Debug: calculating german BERTSCORE
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 10.58it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Debug: calculating german BERTSCORE
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 10.30it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Debug: calculating german BERTSCORE
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  9.95it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Debug: calculating german BERTSCORE
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  9.27it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Debug: calculating german BERTSCORE
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 11.66it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Debug: calculating german BERTSCORE
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  8.07it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Debug: calculating german BERTSCORE
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 10.03it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Debug: calculating german BERTSCORE
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  9.56it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Debug: calculating german BERTSCORE
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 11.65it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Debug: calculating german BERTSCORE
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 11.51it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Debug: calculating german BERTSCORE
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  8.26it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Debug: calculating german BERTSCORE
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 14.29it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Debug: calculating german BERTSCORE
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 10.20it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Debug: calculating german BERTSCORE
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 11.69it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Debug: calculating german BERTSCORE
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 13.88it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Debug: calculating german BERTSCORE
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  9.73it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Debug: calculating german BERTSCORE
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 12.49it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Debug: calculating german BERTSCORE
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 10.34it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Debug: calculating german BERTSCORE
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  8.27it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Debug: calculating german BERTSCORE
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  9.50it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Debug: calculating german BERTSCORE
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  9.83it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Debug: calculating german BERTSCORE
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 11.62it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Debug: calculating german BERTSCORE
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 10.47it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Debug: calculating german BERTSCORE
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  6.69it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Debug: calculating german BERTSCORE
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 11.56it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Debug: calculating german BERTSCORE
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 10.26it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Debug: calculating german BERTSCORE
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  9.33it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Debug: calculating german BERTSCORE
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 11.35it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Debug: calculating german BERTSCORE
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 11.65it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Debug: calculating german BERTSCORE
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 11.75it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Debug: calculating german BERTSCORE
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 12.08it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Debug: calculating german BERTSCORE
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  8.83it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Debug: calculating german BERTSCORE
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  7.95it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# Debug: calculating german BERTSCORE
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  8.64it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Debug: calculating german BERTSCORE
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  9.55it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Debug: calculating german BERTSCORE
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  8.48it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Debug: calculating german BERTSCORE
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 10.06it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Debug: calculating german BERTSCORE
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  9.62it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Debug: calculating german BERTSCORE
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  7.83it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Debug: calculating german BERTSCORE
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 11.58it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Debug: calculating german BERTSCORE
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  7.39it/s]
# Debug: calculating german BERTSCORE
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 11.26it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Debug: calculating german BERTSCORE
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  9.42it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Debug: calculating german BERTSCORE
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  9.58it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Debug: calculating german BERTSCORE
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  6.63it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Debug: calculating german BERTSCORE
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  9.53it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Debug: calculating german BERTSCORE
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  8.56it/s]
# WARNING:root:Structure edit missing or malformed structure_type field; annotation is: {'impact': {'val': 'good', 'good': 'minor'}, 'grammar_error': 'no'}
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Debug: calculating german BERTSCORE
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  7.27it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Debug: calculating german BERTSCORE
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  9.57it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Debug: calculating german BERTSCORE
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  7.06it/s]
# Debug: calculating german BERTSCORE
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 11.23it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Debug: calculating german BERTSCORE
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  8.81it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Debug: calculating german BERTSCORE
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  8.91it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Debug: calculating german BERTSCORE
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  8.64it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Debug: calculating german BERTSCORE
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  9.36it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Debug: calculating german BERTSCORE
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  7.75it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# Debug: calculating german BERTSCORE
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 11.42it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Debug: calculating german BERTSCORE
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  9.33it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Debug: calculating german BERTSCORE
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 10.65it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Debug: calculating german BERTSCORE
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  9.56it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Debug: calculating german BERTSCORE
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  8.72it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Debug: calculating german BERTSCORE
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 13.02it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Debug: calculating german BERTSCORE
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  9.31it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Debug: calculating german BERTSCORE
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  9.59it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Debug: calculating german BERTSCORE
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 14.40it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Debug: calculating german BERTSCORE
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  8.31it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Debug: calculating german BERTSCORE
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 11.26it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Debug: calculating german BERTSCORE
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  8.81it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Debug: calculating german BERTSCORE
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  8.55it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Debug: calculating german BERTSCORE
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  9.60it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Debug: calculating german BERTSCORE
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  9.43it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Debug: calculating german BERTSCORE
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 11.72it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Debug: calculating german BERTSCORE
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 11.26it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Debug: calculating german BERTSCORE
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  6.95it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Debug: calculating german BERTSCORE
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  9.50it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Debug: calculating german BERTSCORE
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  9.65it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Debug: calculating german BERTSCORE
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  9.52it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Debug: calculating german BERTSCORE
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  8.86it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Debug: calculating german BERTSCORE
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 11.39it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Debug: calculating german BERTSCORE
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 11.84it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Debug: calculating german BERTSCORE
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 11.42it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Debug: calculating german BERTSCORE
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  9.37it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Debug: calculating german BERTSCORE
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  7.70it/s]
# Debug: calculating german BERTSCORE
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  8.70it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Debug: calculating german BERTSCORE
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 11.18it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Debug: calculating german BERTSCORE
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  9.08it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Debug: calculating german BERTSCORE
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 10.90it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Debug: calculating german BERTSCORE
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  9.28it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Debug: calculating german BERTSCORE
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  7.93it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Debug: calculating german BERTSCORE
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 11.34it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Debug: calculating german BERTSCORE
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  7.21it/s]
# Debug: calculating german BERTSCORE
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 11.15it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Debug: calculating german BERTSCORE
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  9.50it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# ...
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Debug: calculating german BERTSCORE
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 11.32it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Debug: calculating german BERTSCORE
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  9.46it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Debug: calculating german BERTSCORE
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  7.11it/s]
# Debug: calculating german BERTSCORE
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 11.68it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Debug: calculating german BERTSCORE
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 11.08it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Debug: calculating german BERTSCORE
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  9.77it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Debug: calculating german BERTSCORE
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 11.26it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Debug: calculating german BERTSCORE
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 11.59it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Debug: calculating german BERTSCORE
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 11.83it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Debug: calculating german BERTSCORE
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 11.94it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Debug: calculating german BERTSCORE
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  9.89it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Debug: calculating german BERTSCORE
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  9.02it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Debug: calculating german BERTSCORE
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  8.86it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Debug: calculating german BERTSCORE
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  9.87it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Debug: calculating german BERTSCORE
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  9.41it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Debug: calculating german BERTSCORE
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 11.48it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Debug: calculating german BERTSCORE
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  8.95it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Debug: calculating german BERTSCORE
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  8.95it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Debug: calculating german BERTSCORE
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  9.63it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Debug: calculating german BERTSCORE
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  7.22it/s]
# Debug: calculating german BERTSCORE
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 13.27it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Debug: calculating german BERTSCORE
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  9.67it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Debug: calculating german BERTSCORE
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  9.82it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Debug: calculating german BERTSCORE
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  7.88it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Debug: calculating german BERTSCORE
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 11.24it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Debug: calculating german BERTSCORE
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  9.44it/s]
# DEBUG COLS:  Index(['Sentence ID', 'Source', 'Target', 'System', 'Dataset', 'Family',
#        'Edit Type', 'Edit Sub-Type', 'Edit Classification',
#        'Structure Sub-Type', 'Quality', 'Information Impact', 'Grammar Error',
#        'Significance', 'Input Index', 'Output Index', 'Constituent Edits',
#        'Is Constituent Edit', 'Parent Edit Type', 'Constituent Input Index',
#        'Constituent Output Index'],
#       dtype='object')
#    Sentence ID                                             Source  \
# 0  ChatGPT_001  Am 22. März 1985 unterzeichnete die Europäisch...
# 1  ChatGPT_002  Im folgenden Jahr wurde die VERORDNUNG (EWG) N...
# 2  ChatGPT_003  Zur Anpassung an die Änderungen des Montrealer...
# 3  ChatGPT_004  Unternehmen müssen die Emissionen von geregelt...
# 4  ChatGPT_005  Francesco Calzolari stammte aus einer alteinge...
#
#                                               Target   System Dataset  \
# 0  Die Europäische Gemeinschaft unterzeichnete am...  ChatGPT  wikiDE
# 1  Im nächsten Jahr wurde die Verordnung (EWG) Nr...  ChatGPT  wikiDE
# 2  Um das Montrealer Protokoll anzupassen, ergänz...  ChatGPT  wikiDE
# 3  Unternehmen müssen verhindern, dass schädliche...  ChatGPT  wikiDE
# 4  Francesco Calzolari kam aus einer alten Famili...  ChatGPT  wikiDE
#
#    Total Edits  reorder_count  deletion_count  substitution_count  \
# 0            5              2               3                   0
# 1            4              1               0                   1
# 2            7              0               0                   3
# 3            4              0               0                   2
# 4            6              1               0                   5
#
#    split_count  ...  Lexical_Diversity_Difference  \
# 0            0  ...                     -0.053623
# 1            1  ...                     -0.095238
# 2            2  ...                      0.081818
# 3            0  ...                     -0.037500
# 4            0  ...                     -0.050000
#
#    Syntactic_Complexity_Source  Syntactic_Complexity_Target  \
# 0                            1                            1
# 1                            3                            3
# 2                            2                            4
# 3                            1                            2
# 4                            2                            1
#
#    Syntactic_Complexity_Difference  BERTScore_Precision  BERTScore_Recall  \
# 0                                0             0.963163          0.904386
# 1                                0             0.876339          0.877588
# 2                                2             0.848119          0.868368
# 3                                1             0.801097          0.792511
# 4                               -1             0.939942          0.880234
#
#    BERTScore_F1      GLEU  LENS_SALSA  no_edit_count
# 0      0.932849  0.507937   58.915269            NaN
# 1      0.876963  0.385965   59.443283            NaN
# 2      0.858124  0.321918   51.670396            NaN
# 3      0.796781  0.151163   59.764546            NaN
# 4      0.909109  0.393617   63.699377            NaN
#
# [5 rows x 30 columns]

# %%
# replace LENS-SALSA scores with NaN, since it can only handle English
df_sentences_wikiDE['LENS-SALSA'] = np.nan

# %%
# Display edit level data
df_edits_wikiDE.head()
# Out:
#    Sentence ID                                             Source  \
# 0  ChatGPT_001  Am 22. März 1985 unterzeichnete die Europäisch...
# 1  ChatGPT_001  Am 22. März 1985 unterzeichnete die Europäisch...
# 2  ChatGPT_001  Am 22. März 1985 unterzeichnete die Europäisch...
# 3  ChatGPT_001  Am 22. März 1985 unterzeichnete die Europäisch...
# 4  ChatGPT_001  Am 22. März 1985 unterzeichnete die Europäisch...
#
#                                               Target   System Dataset  \
# 0  Die Europäische Gemeinschaft unterzeichnete am...  ChatGPT  wikiDE
# 1  Die Europäische Gemeinschaft unterzeichnete am...  ChatGPT  wikiDE
# 2  Die Europäische Gemeinschaft unterzeichnete am...  ChatGPT  wikiDE
# 3  Die Europäische Gemeinschaft unterzeichnete am...  ChatGPT  wikiDE
# 4  Die Europäische Gemeinschaft unterzeichnete am...  ChatGPT  wikiDE
#
#        Family Edit Type            Edit Sub-Type Edit Classification  \
# 0      Syntax   reorder  Component-level Reorder        Good Reorder
# 1      Syntax   reorder           Trivial Change        Good Reorder
# 2  Conceptual  deletion                     None       Good Deletion
# 3  Conceptual  deletion                     None       Good Deletion
# 4  Conceptual  deletion                     None       Good Deletion
#
#   Structure Sub-Type  ... Significance   Input Index Output Index  \
# 0               None  ...            0    [[32, 60]]    [[0, 28]]
# 1               None  ...            0    [[17, 31]]   [[29, 43]]
# 2               None  ...            1    [[61, 99]]         None
# 3               None  ...            0  [[156, 170]]         None
# 4               None  ...            0  [[193, 197]]         None
#
#    Constituent Edits Is Constituent Edit Parent Edit Type  \
# 0                  0               False              N/A
# 1                  0               False              N/A
# 2                  0               False              N/A
# 3                  0               False              N/A
# 4                  0               False              N/A
#
#    Constituent Input Index  Constituent Output Index  \
# 0                       []                        []
# 1                       []                        []
# 2                       []                        []
# 3                       []                        []
# 4                       []                        []
#
#                                Input Text                   Output Text
# 0            die Europäische Gemeinschaft  Die Europäische Gemeinschaft
# 1                          unterzeichnete                unterzeichnete
# 2  gemeinsam mit mehreren Mitgliedstaaten
# 3                          darauf folgend
# 4                                    auch
#
# [5 rows x 23 columns]

# %%
# Verify the edit transformations
verify_edits_transformations(df_edits_wikiDE, file_dict)
# Out:
# {'ChatGPT': 272, 'LLAMA': 393, 'MUSS': 154}
# OK for system ChatGPT
# OK for system LLAMA
# OK for system MUSS

# %% [markdown]
# ### Combine Datasets

# %%
# combine the datasets (append)

#df_sentences = df_sentences_wikiEN
#df_edits = df_edits_wikiEN

df_sentences = pd.concat([
    df_sentences_wikiEN, 
    df_sentences_cochrane,
    df_sentences_scotus,
    df_sentences_wikiDE
], axis=0)

df_edits = pd.concat([
    df_edits_wikiEN, 
    df_edits_cochrane,
    df_edits_scotus,
    df_edits_wikiDE
], axis=0)


print(df_sentences.shape)
print(df_edits.shape)
# Out:
# (750, 31)
# (3954, 23)

# %%
# get all column names for df_edits
df_edits.columns
# Out:
# Index(['Sentence ID', 'Source', 'Target', 'System', 'Dataset', 'Family',
#        'Edit Type', 'Edit Sub-Type', 'Edit Classification',
#        'Structure Sub-Type', 'Quality', 'Information Impact', 'Grammar Error',
#        'Significance', 'Input Index', 'Output Index', 'Constituent Edits',
#        'Is Constituent Edit', 'Parent Edit Type', 'Constituent Input Index',
#        'Constituent Output Index', 'Input Text', 'Output Text'],
#       dtype='object')

# %%
# get all unique values for columns:
cols = [ 'Family',
       'Edit Type', 'Edit Sub-Type',
       'Edit Classification', 'Quality', 'Information Impact',
       'Grammar Error', 'Significance']

for col in cols:
    print(f"Unique values for column {col}:")
    print(df_edits[col].unique())
    print("\n")
# Out:
# Unique values for column Family:
# ['Conceptual' 'Syntax' 'Lexical' None]
#
#
# Unique values for column Edit Type:
# ['substitution' 'insertion' 'split' 'structure' 'deletion' 'reorder'
#  'no_edit']
#
#
# Unique values for column Edit Sub-Type:
# [None 'Sentence Split' 'Part of Speech' 'Bad Deletion' 'Trivial Change'
#  'Clausal Structure' 'Component-level Reorder' 'Information Rewrite'
#  'Voice' 'Tense' 'Grammatical Number' 'Bad Component Reorder'
#  'Unknown Structure Change' 'Complex Wrong' 'Factual Error' 'Repetition'
#  'Bad Split' 'Contradiction' 'Coreference']
#
#
# Unique values for column Edit Classification:
# ['Good Substitution' 'Trivial Insertion' 'Good Split' 'Trivial Structure'
#  'Bad Deletion' 'Good Deletion' 'Trivial Deletion' 'Good Structure'
#  'Good Reorder' 'Bad Substitution' 'Trivial Substitution' 'Good Insertion'
#  'Bad Reorder' 'Bad Structure' 'Bad Insertion' 'Trivial Split' 'Bad Split'
#  None]
#
#
# Unique values for column Quality:
# ['No Error' 'Trivial' 'Error' None]
#
#
# Unique values for column Information Impact:
# ['Same Information' 'Elaboration' 'Generalization' None]
#
#
# Unique values for column Grammar Error:
# ['No' 'Yes']
#
#
# Unique values for column Significance:
# [1 0 2]

# %% [markdown]
# ### Minor additional transformations

# %%
# Increase Signifiance by 1 to have levels [1, 2, 3] instead of [0, 1, 2]
df_edits['Significance'] = df_edits['Significance'] + 1

# set when Quality == Trivial  Significance to 0 (back, as it has been increased by 1)
df_edits.loc[df_edits['Quality'] == 'Trivial', 'Significance'] = 0

# Signifiance unique values
df_edits['Significance'].unique()
# Out:
# array([2, 1, 0, 3])

# %% [markdown]
# ### Enhance with more metadata

# %%
# load csv with additional information about the sentences
df_sentences_add_metadata = pd.read_csv("../data/TS_datasets/allSets_SpecializedTermsAndEntities.csv")
# drop "Original Sentence" column
df_sentences_add_metadata = df_sentences_add_metadata.drop(columns=['Original Sentence'])

df_sentences_add_metadata.head(1)
# Out:
#   dataset  sentence_id  sentence_has_specialized_terms  \
# 0  scotus            1                            True
#
#    sentence_contains_named_entity
# 0                            True

# %%
# read df_edits metadata
df_edits_add_metadata = pd.read_csv("../data/TS_datasets/allEdits_SpecializedTermsAndEntities.csv")
df_edits_add_metadata
# Out:
#       Sentence ID   System Dataset     Edit Type  \
# 0     ChatGPT_001  ChatGPT  wikiEN  substitution
# 1     ChatGPT_001  ChatGPT  wikiEN     insertion
# 2     ChatGPT_001  ChatGPT  wikiEN         split
# 3     ChatGPT_001  ChatGPT  wikiEN     structure
# 4     ChatGPT_002  ChatGPT  wikiEN      deletion
# ...           ...      ...     ...           ...
# 3949     MUSS_049     MUSS  wikiDE      deletion
# 3950     MUSS_049     MUSS  wikiDE      deletion
# 3951     MUSS_050     MUSS  wikiDE      deletion
# 3952     MUSS_050     MUSS  wikiDE     structure
# 3953     MUSS_050     MUSS  wikiDE      deletion
#
#                                              Input Text Output Text  \
# 0                                            designated      called
# 1                                                   NaN         the
# 2                                                   NaN         NaN
# 3                                                   NaN         NaN
# 4                                       capital city of         NaN
# ...                                                 ...         ...
# 3949                     eine Gegendemonstration statt.         NaN
# 3950                                               fand         NaN
# 3951           Als Reaktion auf die anhaltenden Unruhen         NaN
# 3952                                                NaN         NaN
# 3953  mehrere Länder, darunter Australien, Nigeria u...         NaN
#
#        Input Index Output Index  has_specialized_terms  contains_named_entity
# 0       [[17, 27]]   [[18, 24]]                  False                  False
# 1              NaN   [[43, 46]]                  False                  False
# 2              NaN          NaN                  False                  False
# 3              NaN          NaN                  False                  False
# 4       [[19, 34]]          NaN                  False                   True
# ...            ...          ...                    ...                    ...
# 3949  [[109, 139]]          NaN                  False                  False
# 3950    [[86, 90]]          NaN                  False                  False
# 3951     [[0, 40]]          NaN                  False                  False
# 3952           NaN          NaN                  False                  False
# 3953   [[71, 131]]          NaN                  False                   True
#
# [3954 rows x 10 columns]

# %%
print(df_edits_add_metadata.shape)

# drop "Input Text" and "Output Text" cols
df_edits_add_metadata = df_edits_add_metadata.drop(columns=['Input Text', 'Output Text'])


# remove all Edit Type = split or structure or no_edit
df_edits_add_metadata = df_edits_add_metadata[
    ~df_edits_add_metadata['Edit Type'].isin(['split', 'structure', 'no_edit'])
]

print(df_edits_add_metadata.shape)
# get unique values for Edit Type
df_edits_add_metadata['Edit Type'].unique()
# Out:
# (3954, 10)
# (3111, 8)
# array(['substitution', 'insertion', 'deletion', 'reorder'], dtype=object)

# %%
# Create a copy of df_edits to avoid modifying the original
df_edits_temp = df_edits.copy()

# Convert list columns to strings for merging
list_columns = ['Input Index', 'Output Index']
for col in list_columns:
    df_edits_temp[col] = df_edits_temp[col].apply(lambda x: str(x) if isinstance(x, list) else x)

# Perform the merge
df_edits = pd.merge(
    df_edits_temp, 
    df_edits_add_metadata,
    on=['Sentence ID', 'System', 'Dataset', 'Edit Type', 
         'Input Index', 'Output Index'],
    how='left'
)

# Convert string representation of lists back to actual lists if needed
for col in list_columns:
    df_edits[col] = df_edits[col].apply(lambda x: eval(x) if isinstance(x, str) and x != 'nan' and x != 'None' else None)

# %%
# set has_specialized_terms and contains_named_entity to False if Nan if Edit Type in split, structure, no_edit

df_edits.loc[
    df_edits['Edit Type'].isin(['split', 'structure', 'no_edit']),
    ['has_specialized_terms', 'contains_named_entity']
] = False

# count number of rows with either has_specialized_terms or contains_named_entity NaN
print(df_edits[
    df_edits['has_specialized_terms'].isna() | df_edits['contains_named_entity'].isna()
].shape)

df_edits
# Out:
# (0, 25)
#       Sentence ID                                             Source  \
# 0     ChatGPT_001  The N1 road also designated as RN1, is a road ...
# 1     ChatGPT_001  The N1 road also designated as RN1, is a road ...
# 2     ChatGPT_001  The N1 road also designated as RN1, is a road ...
# 3     ChatGPT_001  The N1 road also designated as RN1, is a road ...
# 4     ChatGPT_002  Originating in the capital city of Bangui, the...
# ...           ...                                                ...
# 3949     MUSS_049  Auch in Bristol, das einige Tage zuvor Schaupl...
# 3950     MUSS_049  Auch in Bristol, das einige Tage zuvor Schaupl...
# 3951     MUSS_050  Als Reaktion auf die anhaltenden Unruhen veröf...
# 3952     MUSS_050  Als Reaktion auf die anhaltenden Unruhen veröf...
# 3953     MUSS_050  Als Reaktion auf die anhaltenden Unruhen veröf...
#
#                                                  Target   System Dataset  \
# 0     The N1 road, also called RN1, is a road in the...  ChatGPT  wikiEN
# 1     The N1 road, also called RN1, is a road in the...  ChatGPT  wikiEN
# 2     The N1 road, also called RN1, is a road in the...  ChatGPT  wikiEN
# 3     The N1 road, also called RN1, is a road in the...  ChatGPT  wikiEN
# 4     The road starts in Bangui and goes northwest t...  ChatGPT  wikiEN
# ...                                                 ...      ...     ...
# 3949  Am 7. August 2024 war Schauplatz gewalttätiger...     MUSS  wikiDE
# 3950  Am 7. August 2024 war Schauplatz gewalttätiger...     MUSS  wikiDE
# 3951  Am 5. August wurden Reisewarnungen für das Ver...     MUSS  wikiDE
# 3952  Am 5. August wurden Reisewarnungen für das Ver...     MUSS  wikiDE
# 3953  Am 5. August wurden Reisewarnungen für das Ver...     MUSS  wikiDE
#
#           Family     Edit Type   Edit Sub-Type Edit Classification  \
# 0     Conceptual  substitution            None   Good Substitution
# 1     Conceptual     insertion            None   Trivial Insertion
# 2         Syntax         split  Sentence Split          Good Split
# 3         Syntax     structure  Part of Speech   Trivial Structure
# 4     Conceptual      deletion    Bad Deletion        Bad Deletion
# ...          ...           ...             ...                 ...
# 3949  Conceptual      deletion    Bad Deletion        Bad Deletion
# 3950  Conceptual      deletion    Bad Deletion        Bad Deletion
# 3951  Conceptual      deletion    Bad Deletion        Bad Deletion
# 3952      Syntax     structure           Voice   Trivial Structure
# 3953  Conceptual      deletion            None       Good Deletion
#
#      Structure Sub-Type  ... Output Index Constituent Edits  \
# 0                  None  ...   [[18, 24]]                 0
# 1                  None  ...   [[43, 46]]                 0
# 2                  None  ...         None                 1
# 3        Part of Speech  ...         None                 1
# 4                  None  ...         None                 0
# ...                 ...  ...          ...               ...
# 3949               None  ...         None                 0
# 3950               None  ...         None                 0
# 3951               None  ...         None                 0
# 3952              Voice  ...         None                 1
# 3953               None  ...         None                 0
#
#      Is Constituent Edit  Parent Edit Type Constituent Input Index  \
# 0                  False               N/A                      []
# 1                  False               N/A                      []
# 2                  False               N/A            [[[74, 78]]]
# 3                  False               N/A           [[[79, 104]]]
# 4                  False               N/A                      []
# ...                  ...               ...                     ...
# 3949               False               N/A                      []
# 3950               False               N/A                      []
# 3951               False               N/A                      []
# 3952               False               N/A            [[[41, 57]]]
# 3953               False               N/A                      []
#
#      Constituent Output Index  \
# 0                          []
# 1                          []
# 2                [[[76, 78]]]
# 3     [[[76, 78], [97, 101]]]
# 4                          []
# ...                       ...
# 3949                       []
# 3950                       []
# 3951                       []
# 3952   [[[13, 19], [65, 80]]]
# 3953                       []
#
#                                              Input Text  Output Text  \
# 0                                            designated       called
# 1                                                                the
# 2
# 3
# 4                                       capital city of
# ...                                                 ...          ...
# 3949                     eine Gegendemonstration statt.
# 3950                                               fand
# 3951           Als Reaktion auf die anhaltenden Unruhen
# 3952
# 3953  mehrere Länder, darunter Australien, Nigeria u...
#
#      has_specialized_terms contains_named_entity
# 0                    False                 False
# 1                    False                 False
# 2                    False                 False
# 3                    False                 False
# 4                    False                  True
# ...                    ...                   ...
# 3949                 False                 False
# 3950                 False                 False
# 3951                 False                 False
# 3952                 False                 False
# 3953                 False                  True
#
# [3954 rows x 25 columns]

# %% [markdown]
# ### Pivot Good/Bad Data based on df_edits

# %%
# Pivot the sentence level data to have Good / Bad counts
from helper_functions import pivot_key_columns

processed_df_sentences = pivot_key_columns(df_edits, df_sentences)

df_sentences = processed_df_sentences.copy()

df_sentences.columns
# Out:
# Index(['Sentence ID', 'Source', 'Target', 'System', 'Dataset', 'Total Edits',
#        'Substitution_count', 'Insertion_count', 'Split_count',
#        'Structure_count', 'Deletion_count', 'Reorder_count', 'FKGL_Source',
#        'FKGL_Target', 'FKGL_Difference', 'ARI_Source', 'ARI_Target',
#        'ARI_Difference', 'Lexical_Diversity_Source',
#        'Lexical_Diversity_Target', 'Lexical_Diversity_Difference',
#        'Syntactic_Complexity_Source', 'Syntactic_Complexity_Target',
#        'Syntactic_Complexity_Difference', 'BERTScore_Precision',
#        'BERTScore_Recall', 'BERTScore_F1', 'GLEU', 'LENS_SALSA',
#        'No_edit_count', 'LENS-SALSA', 'Deletion (Bad)', 'Insertion (Bad)',
#        'Reorder (Bad)', 'Split (Bad)', 'Structure (Bad)', 'Substitution (Bad)',
#        'Deletion (Good)', 'Insertion (Good)', 'Reorder (Good)', 'Split (Good)',
#        'Structure (Good)', 'Substitution (Good)', 'Deletion (Neutral)',
#        'Insertion (Neutral)', 'Reorder (Neutral)', 'Split (Neutral)',
#        'Structure (Neutral)', 'Substitution (Neutral)'],
#       dtype='object')

# %% [markdown]
# ## Export to CSV for further processing

# %%
# export to csv

# disabled after run
# df_sentences.to_csv("../data/salsa_annotations/final_annotated/df_sentences.csv", index=False)
# df_edits.to_csv("../data/salsa_annotations/final_annotated/df_edits.csv", index=False)
