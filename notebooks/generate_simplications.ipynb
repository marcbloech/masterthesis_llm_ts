# %%
import pandas as pd
import random
import os
import re
import json
import requests
import inspect
from openai import OpenAI
import openai
from dotenv import load_dotenv
import sys
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM

# %% [markdown]
# ## Dataset Preparation

# %%
# set seed
seed = 42

# %% [markdown]
# ### Wikilarge (own) - English

# %%
df_wikiEN = pd.read_csv("../data/TS_datasets/WikiMB_EN.csv", sep=",")

df_wikiEN = df_wikiEN.drop(columns=["Source Link"])
df_wikiEN.columns = ['complex_sentence']

df_wikiEN.head()
# Out:
#                                     complex_sentence
# 0  The N1 road also designated as RN1, is a road ...
# 1  Originating in the capital city of Bangui, the...
# 2  As a key component of the country's road netwo...
# 3  The N1 route commences in the heart of Bangui,...
# 4  The terrain along this stretch is characterize...

# %% [markdown]
# ### Wikilarge (own) - German

# %%
df_wikiDE = pd.read_csv("../data/TS_datasets/WikiMB_DE.csv", sep=",")

df_wikiDE = df_wikiDE.drop(columns=["Source Link"])

df_wikiDE.columns = ['complex_sentence']

df_wikiDE.head()
# Out:
#                                     complex_sentence
# 0  Am 22. März 1985 unterzeichnete die Europäisch...
# 1  Im folgenden Jahr wurde die VERORDNUNG (EWG) N...
# 2  Zur Anpassung an die Änderungen des Montrealer...
# 3  Unternehmen müssen die Emissionen von geregelt...
# 4  Francesco Calzolari stammte aus einer alteinge...

# %% [markdown]
# ### Cochrane Database (Medical) (own)

# %%
df_cochrane = pd.read_csv("../data/TS_datasets/CochraneMB.csv", sep=",")

df_cochrane.drop(columns=['Source Link'], inplace=True)
df_cochrane.columns = ['complex_sentence', 'original_simple_sentence']

df_cochrane.head()
# Out:
#                                     complex_sentence  \
# 0  TEP technique may carry a higher risk of conve...
# 1  An inguinal hernia occurs when part of the int...
# 2  There may be little to no difference between T...
# 3  TEP technique may carry a higher risk of conve...
# 4  CBT may result in a small‐to‐moderate reductio...
#
#                             original_simple_sentence
# 0  If the TEP technique is used, there may be a h...
# 1  A groin hernia is a weakness or defect in the ...
# 2  The evidence suggests there may be little to n...
# 3  The evidence suggests that the risk of needing...
# 4  Evidence suggests that cognitive behavioural t...

# %% [markdown]
# ### Legal Dataset (own)

# %%
df_scotus = pd.read_csv("../data/TS_datasets/ScotusMB.csv", sep=",")

df_scotus.drop(columns=['Source Link'], inplace=True)
df_scotus.columns = ['complex_sentence']

df_scotus.head()
# Out:
#                                     complex_sentence
# 0  To determine whether Corner Post’s APA claim i...
# 1  While the Board argues that §2401(a) should no...
# 2  Importantly, contemporaneous dictionaries also...
# 3  The Board leaves open the possibility that som...
# 4  The APA provisions grant Corner Post a cause o...

# %% [markdown]
# ## API Calls

# %%
# Load environment variables from .env file
load_dotenv()
# Setup API Keys
openai.api_key = os.getenv('OPENAI_API_KEY')
client = OpenAI(api_key=openai.api_key)
# Out:
# ---------------------------------------------------------------------------
# OpenAIError                               Traceback (most recent call last)
# Cell In[16], line 5
#       3 # Setup API Keys
#       4 openai.api_key = os.getenv('OPENAI_API_KEY')
# ----> 5 client = OpenAI(api_key=openai.api_key)
#
# File /opt/anaconda3/envs/py311ts/lib/python3.11/site-packages/openai/_client.py:110, in OpenAI.__init__(self, api_key, organization, project, base_url, websocket_base_url, timeout, max_retries, default_headers, default_query, http_client, _strict_response_validation)
#     108     api_key = os.environ.get("OPENAI_API_KEY")
#     109 if api_key is None:
# --> 110     raise OpenAIError(
#     111         "The api_key client option must be set either by passing api_key to the client or by setting the OPENAI_API_KEY environment variable"
#     112     )
#     113 self.api_key = api_key
#     115 if organization is None:
#
# OpenAIError: The api_key client option must be set either by passing api_key to the client or by setting the OPENAI_API_KEY environment variable

# %%
# a general function to run a specified model on a set of datasets and save the output

def run_model_on_multiple_datasets(model_function, datasets, input_column, output_column, save_dir, model_name):
    """
    Run a given model function on multiple datasets and save the results.
    """
    processed_datasets = {}
    
    # Ensure the save directory exists
    os.makedirs(save_dir, exist_ok=True)
    
    for dataset_name, dataset in datasets.items():
        # Create a copy of the dataset to avoid modifying the original
        dataset_copy = dataset.copy()
        
        # Apply the model function to the input column and store results in the output column
        dataset_copy[output_column] = dataset_copy[input_column].apply(model_function)
        
        # Store the processed dataset in the result dictionary
        processed_datasets[dataset_name] = dataset_copy
        
        # Generate filename
        filename = f"{dataset_name}_{model_name}_simplified.csv"
        file_path = os.path.join(save_dir, filename)
        
        # Save the dataset
        dataset_copy.to_csv(file_path, index=False)
        
        print(f"Processed and saved dataset: {filename}")
    
    return processed_datasets

# %%
datasets = {
    'wikiEN': df_wikiEN,
    'cochrane': df_cochrane,
    'scotus': df_scotus
}

datasets_DE = {
    'wikiDE': df_wikiDE
}

# %%
# load asset (alva-manchego-etal-2020-asset) for prompt few shot examples 

# read original complex sentences
with open("../data/TS_datasets/asset-main/dataset/asset.valid.orig", "r") as file:
    asset_original = file.readlines()

# Reading user generated simplified sentences

directory = "../data/TS_datasets/asset-main/dataset/"

search_string = 'asset.valid.simp.'

# Dictionary to store lists for each file
file_lines_dict = {}

# Loop through all files in the specified directory
for filename in os.listdir(directory):
    # Check if the filename contains the search string
    if search_string in filename:
        print(f"Processing file: {filename}")
        # Extract the identifier (e.g., simp1, simp2, etc.)
        identifier = filename.split('asset.valid.')[1]
        print("Identifier:  ", identifier)
        
        # Create a list for this file
        file_lines_dict[identifier] = []

        # Open and read the file
        with open(os.path.join(directory, filename), 'r') as file:
            # Read all lines and store them in the list
            file_lines_dict[identifier] = file.readlines()
# Out:
# Processing file: asset.valid.simp.1
# Identifier:   simp.1
# Processing file: asset.valid.simp.6
# Identifier:   simp.6
# Processing file: asset.valid.simp.8
# Identifier:   simp.8
# Processing file: asset.valid.simp.9
# Identifier:   simp.9
# Processing file: asset.valid.simp.7
# Identifier:   simp.7
# Processing file: asset.valid.simp.0
# Identifier:   simp.0
# Processing file: asset.valid.simp.5
# Identifier:   simp.5
# Processing file: asset.valid.simp.2
# Identifier:   simp.2
# Processing file: asset.valid.simp.3
# Identifier:   simp.3
# Processing file: asset.valid.simp.4
# Identifier:   simp.4

# %%
# generate a random number to select a random few shot example (testing out)

# set number based on length of asset_original
random_number = random.randint(0, len(asset_original))
print("Random number: ", random_number)

# select random entry in file_lines_dict based on length of file_lines_dict
random_entry = random.choice(list(file_lines_dict.keys()))
print("Random entry: ", random_entry)

# print the original and simplified sentences on the same line
print(" Original:", asset_original[random_number], "Simplified:", file_lines_dict[random_entry][random_number])
# Out:
# Random number:  1239
# Random entry:  simp.7
#  Original: He was an exceptionally active campaigner and critic in the crisis years in Italy after the First World War and into the early years of Fascist rule.
#  Simplified: He was an active campaigner and critic in the crisis years. He was vocal in Italy after the First World War. As well as into the early years of Fascist rule.

# %%
# This function will generate a prompt sentence for few shot examples
def generate_few_shot_example_prompt():
    random_number = random.randint(0, len(asset_original) - 1)
    random_entry = random.choice(list(file_lines_dict.keys()))

    return f" Original: {asset_original[random_number]} Simplified: {file_lines_dict[random_entry][random_number]}"


generate_few_shot_example_prompt()
# Out:
# ' Original: This flag was the same, except the golden stripe had a human stick figure, a kanaga, in black, with arms raised to the sky.\n Simplified: This flag was the same, a human stick figure on it was the only difference. He was a kanaga, in black, with arms raised to the sky.\n'

# %%
# same for german examples (using TextComplexityDE)

df_TCDE = pd.read_csv("../data/TS_datasets/TextComplexityDE-master/TextComplexityDE19/parallel_corpus.csv", sep=",", encoding="ISO-8859-1")

df_TCDE
# Out:
#      Sentence_Id  Article_ID                            Article  \
# 0              5           1                        Seifenblase
# 1              7           1                        Seifenblase
# 2             11           1                        Seifenblase
# 3             13           1                        Seifenblase
# 4             15           1                        Seifenblase
# ..           ...         ...                                ...
# 245          974          22  Geschichte der Europäischen Union
# 246          979          23                 Martin Luther King
# 247          990          23                 Martin Luther King
# 248         1004          23                 Martin Luther King
# 249         1005          23                 Martin Luther King
#
#                                      Original_Sentence  \
# 0    Wegen dieser leichten Vergänglichkeit wurde ,S...
# 1    In der Kunst wird spätestens seit dem Barock d...
# 2    Eine Seifenblase entsteht, wenn sich ein dünne...
# 3    Infolge des gravitationsbedingten Auslaufens (...
# 4    Zudem erfolgt im Laufe des Auslaufprozesses ei...
# ..                                                 ...
# 245  Kohl war es, der Mitte 1988 Jacques Delors für...
# 246  Wesentlich durch Kings Einsatz und Wirkkraft i...
# 247  Der Vater änderte beide Namen nach einer Europ...
# 248  Am 20. September 1944 begann King sein Studium...
# 249  Im Hauptfach Soziologie wurde er von Walter P....
#
#                                         Simplification              Rating
# 0    Weil Seifenblasen nicht lange halten, wurden s...     Etwas einfacher
# 1    In der Kunst wird die Seifenblase spätestens s...  Deutlich einfacher
# 2    Eine Seifenblase entsteht, wenn sich eine klei...     Etwas einfacher
# 3    Wegen der Erdanziehungskraft läuft die Flüssig...     Etwas einfacher
# 4    Beim Auslaufen von einer Seifenblase sammeln s...  Deutlich einfacher
# ..                                                 ...                 ...
# 245  Im Jahr 1988 schlug der deutsche Bundeskanzler...  Deutlich einfacher
# 246  Das Civil Rights Movement ist durch den Einsat...  Deutlich einfacher
# 247  Der Vater änderte beide Namen nach einer Europ...     Etwas einfacher
# 248  Am 20. September 1944 begann King sein Studium...  Deutlich einfacher
# 249  Sein Hauptfach war Soziologie. In die Problema...     Etwas einfacher
#
# [250 rows x 6 columns]

# %%
def generate_few_shot_example_prompt_DE():
    random_number = random.randint(0, len(df_TCDE) - 1)

    return f" Original: {df_TCDE['Original_Sentence'][random_number]}\n Vereinfacht: {df_TCDE['Simplification'][random_number]}\n"

# testing
generate_few_shot_example_prompt_DE()
# Out:
# ' Original: In der Appekunny Formation im Osten des Parks, die auf ein Alter von 1,5\x961,3 Milliarden Jahre datiert wird, wurden 1982 Abdrücke gefunden, die von den Entdeckern als Metazoa interpretiert und nach neuen Untersuchungen 2002 als Horodyskia moniliformis beschrieben wurden.\n Vereinfacht: In der Appekunny Formation im Osten des Parks, die auf ein Alter von 1,5-1,3 Milliarden Jahre datiert wird, wurden 1982 Abdrücke gefunden. Diese Abdrücke wurden von den Entdeckern als vielzellige Lebenwesen (Metazoa) interpretiert. Nach neuen Untersuchungen wurden diese Metazoa als Horodyskai moniliformis beschrieben. \n'

# %%
save_directory = "../data/TS_model_outputs"

# %% [markdown]
# ### OpenAI - GPT 4o

# %%
main_prompt  = ( # inspired by BLESS paper -> which was inspired by Maddela et al. (2023) "LENS"
    "Please rewrite the following complex sentence in order to make it easier to understand by non-native speakers of English. ",
    "You can do so by reordering parts of the sentence, replacing complex words with simpler synonyms (i.e. paraphrasing), deleting unimportant information (i.e. compression), and/or splitting a long complex sentence into several simpler ones. ",
    "The final simplified sentence needs to be grammatical, fluent, and retain the main ideas of its original counterpart without altering its meaning.\n",
    "Respond only and always with the simplified sentence, nothing else. Do not start the response with any introduction.\n",
    "Examples:\n"
)

main_prompt_DE = ( 
    "Bitte schreibe den folgenden komplexen Satz um, um ihn für Nicht-Muttersprachler leichter verständlich zu machen. ",
    "Du kannst dies tun, indem du Teile des Satzes umstellst, komplexe Wörter durch einfachere Synonyme ersetzt (d.h. umformulieren), unwichtige Informationen weglässt (d.h. komprimieren) und/oder einen langen, komplexen Satz in mehrere einfachere Sätze aufteilst. ",
    "Der vereinfachte Satz muss grammatikalisch korrekt, fließend und verständlich sein und die Hauptideen des ursprünglichen Satzes beibehalten, ohne dessen Bedeutung zu verändern.\n",
    "Antworte ausschließlich und immer nur mit dem vereinfachten Satz, nichts weiter. Beginne die Antwort nicht mit einer Einleitung.\n",
    "Beispiele:\n"
)

# %%
def generate_main_prompt(main_prompt, language="EN"):
    """ Generate the main prompt for the task including the main instruction and 3 examples.
    Depending on the language, the prompt will be generated in English or German.
    """
    if language == "DE":
        prompt = ''.join(main_prompt_DE)
        prompt += generate_few_shot_example_prompt_DE()
        prompt += "\n"
        prompt += generate_few_shot_example_prompt_DE()
        prompt += "\n"
        prompt += generate_few_shot_example_prompt_DE()
        prompt += "\n"
    else:
        prompt = ''.join(main_prompt)
        prompt += generate_few_shot_example_prompt()
        prompt += "\n"
        prompt += generate_few_shot_example_prompt()
        prompt += "\n"
        prompt += generate_few_shot_example_prompt()
        prompt += "\n"

    return prompt

# testing
generate_main_prompt(main_prompt)
# Out:
# 'Please rewrite the following complex sentence in order to make it easier to understand by non-native speakers of English. You can do so by reordering parts of the sentence, replacing complex words with simpler synonyms (i.e. paraphrasing), deleting unimportant information (i.e. compression), and/or splitting a long complex sentence into several simpler ones. The final simplified sentence needs to be grammatical, fluent, and retain the main ideas of its original counterpart without altering its meaning.\nRespond only and always with the simplified sentence, nothing else. Do not start the response with any introduction.\nExamples:\n Original: In Augustan Rome, Quirinus was also an epithet of Janus, as Janus Quirinus.\n Simplified: Quirinus was another name used for Janus.\n\n Original: She first rose to prominence as an academic, barrister, campaigner and member of the Irish senate (1969 – 1989).\n Simplified: She was an academic, barrister, campaigner and member of the Irish senate (1969 – 1989).\n\n Original: Since independence, Botswana has had one of the fastest growth rates in per capita income in the world.\n Simplified: Botswana has had one of the fastest growing income rates in the world.\n\n'

# %%
# testing for german
generate_main_prompt(main_prompt, language="DE")
# Out:
# 'Bitte schreibe den folgenden komplexen Satz um, um ihn für Nicht-Muttersprachler leichter verständlich zu machen. Du kannst dies tun, indem du Teile des Satzes umstellst, komplexe Wörter durch einfachere Synonyme ersetzt (d.h. umformulieren), unwichtige Informationen weglässt (d.h. komprimieren) und/oder einen langen, komplexen Satz in mehrere einfachere Sätze aufteilst. Der vereinfachte Satz muss grammatikalisch korrekt, fließend und verständlich sein und die Hauptideen des ursprünglichen Satzes beibehalten, ohne dessen Bedeutung zu verändern.\nAntworte ausschließlich und immer nur mit dem vereinfachten Satz, nichts weiter. Beginne die Antwort nicht mit einer Einleitung.\nBeispiele:\n Original: Darüber hinaus sind Würfel in einer Vielzahl von Brettspielen bedeutend, um etwa die Bewegungsgeschwindigkeit von Spielfiguren oder den Ausgang von Zufallsereignissen zu bestimmen.\n Vereinfacht: Außerdem sind Würfel wichtig für viele Brettspiele. Zum Beispiel um die Bewegung von Spielfiguren oder das Ergebnis von zufälligen Entscheidungen zu bestimmen.\n\n Original: Als zweitgrößte Belastungszone ist der Kontakt zwischen Gesäß und Sattel anzusehen.\n Vereinfacht: Neben den Füßen wird beim Radfahren auch das Gesäß belastet.\n\n Original: Vielfach wurde vermutet, der technische Fortschritt des 20. Jahrhunderts werde mehrheitlich zur Verringerung der Arbeitszeit und zu einem Anwachsen der Freizeit führen.\n Vereinfacht: Oft wurde vermutet, dass der technische Fortschritt vom 20. Jahrhundert zu kürzeren Arbeitszeiten und mehr Freizeit führen.\n\n'

# %%
# generate simplified sentences through GPT-4 API

def generate_simplified_sentence_OpenAI(complex_sentence):
    # Custom prompt to generate simplified sentences
    #system_prompt = "You are a helpful assistant."

    prompt = generate_main_prompt(main_prompt)
    prompt += f"Original sentences to simplify:\n\"{complex_sentence}\".\n Simplified: "

    print("Prompt: ", prompt)
    
    response = client.chat.completions.create(
        model="gpt-4o-2024-05-13",
        messages=[
            {"role": "system", "content": "You are a helpful assistant that is an expert in simplifying sentences for non-native speakers."},
            {"role": "user", "content": prompt},
        ]
        )

    # Extract the simplified sentence from the response

    response_text = response.choices[0].message.content
    print("Response text:" + response_text) 
    simplified_sentence = response_text
    
    print(f"\n\nSimplified OG sentence: {complex_sentence} to {simplified_sentence}")
    print("----------------------------\n\n")

    return simplified_sentence

# %%
# Process all datasets with the OpenAI API and save them
run_model_on_multiple_datasets(
    model_function = generate_simplified_sentence_OpenAI, 
    datasets = datasets, 
    input_column = 'complex_sentence', 
    output_column = 'simplified_sentence', 
    save_dir = save_directory, 
    model_name = 'OpenAI')
# Out:
# Prompt:  Please rewrite the following complex sentence in order to make it easier to understand by non-native speakers of English. You can do so by reordering parts of the sentence, replacing complex words with simpler synonyms (i.e. paraphrasing), deleting unimportant information (i.e. compression), and/or splitting a long complex sentence into several simpler ones. The final simplified sentence needs to be grammatical, fluent, and retain the main ideas of its original counterpart without altering its meaning.
# Respond only and always with the simplified sentence, nothing else. Do not start the response with any introduction.
# Examples:
#  Original: Arunachal Pradesh (,) is the easternmost state of India.
#  Simplified: Arunachal Pradesh is the Indian state farthest to the east.
#
#  Original: C. L. Barber, “Shakespearian Comedy in the Comedy of Errors, ” College English 25.7 (1964), p. 493.
#  Simplified: C. L. Barber, “Shakespearian Comedy in the Comedy of Errors,” in College English book.
#
#  Original: Due to the Cold War, subsequent trials never took place.
#  Simplified: Due to the Cold War, upcoming trials never took place.
#
# Original sentences to simplify:
# "The N1 road also designated as RN1, is a road in Central African Republic that spans a total distance of 498 kilometers.".
#  Simplified:
# Response text:"The N1 road, also called RN1, is a road in the Central African Republic that is 498 kilometers long."
#
#
# Simplified OG sentence: The N1 road also designated as RN1, is a road in Central African Republic that spans a total distance of 498 kilometers. to "The N1 road, also called RN1, is a road in the Central African Republic that is 498 kilometers long."
# ----------------------------
#
#
# Prompt:  Please rewrite the following complex sentence in order to make it easier to understand by non-native speakers of English. You can do so by reordering parts of the sentence, replacing complex words with simpler synonyms (i.e. paraphrasing), deleting unimportant information (i.e. compression), and/or splitting a long complex sentence into several simpler ones. The final simplified sentence needs to be grammatical, fluent, and retain the main ideas of its original counterpart without altering its meaning.
# Respond only and always with the simplified sentence, nothing else. Do not start the response with any introduction.
# Examples:
#  Original: By early the next day, the remnants of Gabrielle were absorbed by an approaching cold front.
#  Simplified: An approaching cold front absorbed the remnants of Gabrielle.
#
#  Original: On 20 February 2007, Encyclopædia Britannica, Inc. announced that it was working with mobile phone search company AskMeNow to launch a mobile encyclopedia.
#  Simplified: Encyclopædia Britannica, Inc. announced that it was working with mobile phone search company AskMeNow to launch a mobile encyclopedia in 2007
#
#  Original: Their unusual size is attributed to island gigantism, since there are no other carnivorous animals to fill the niche on the islands where they live, and also to the Komodo dragon's low metabolic rate.
#  Simplified: The Komodo dragons are relatively larger in size. This unusual large size is because there are no other meat eating animals on the their island. Also, it's because of Komodo dragon's low metabolic rate.
#
# Original sentences to simplify:
# "Originating in the capital city of Bangui, the road extends northwest, ultimately terminating at the international border with Chad, near the town of Békoro.".
#  Simplified:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[57], line 2
#       1 # Process all datasets with the OpenAI API and save them
# ----> 2 run_model_on_multiple_datasets(
#       3     model_function = generate_simplified_sentence_OpenAI,
#       4     datasets = datasets,
#       5     input_column = 'complex_sentence',
#       6     output_column = 'simplified_sentence',
#       7     save_dir = save_directory,
#       8     model_name = 'OpenAI')
#
# Cell In[45], line 28, in run_model_on_multiple_datasets(model_function, datasets, input_column, output_column, save_dir, model_name)
#      25 dataset_copy = dataset.copy()
#      27 # Apply the model function to the input column and store results in the output column
# ---> 28 dataset_copy[output_column] = dataset_copy[input_column].apply(model_function)
#      30 # Store the processed dataset in the result dictionary
#      31 processed_datasets[dataset_name] = dataset_copy
#
# File ~/miniforge3/envs/py311ts/lib/python3.11/site-packages/pandas/core/series.py:4771, in Series.apply(self, func, convert_dtype, args, **kwargs)
#    4661 def apply(
#    4662     self,
#    4663     func: AggFuncType,
#    (...)
#    4666     **kwargs,
#    4667 ) -> DataFrame | Series:
#    4668     """
#    4669     Invoke function on values of Series.
#    4670
#    (...)
#    4769     dtype: float64
#    4770     """
# -> 4771     return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#
# File ~/miniforge3/envs/py311ts/lib/python3.11/site-packages/pandas/core/apply.py:1123, in SeriesApply.apply(self)
#    1120     return self.apply_str()
#    1122 # self.f is Callable
# -> 1123 return self.apply_standard()
#
# File ~/miniforge3/envs/py311ts/lib/python3.11/site-packages/pandas/core/apply.py:1174, in SeriesApply.apply_standard(self)
#    1172     else:
#    1173         values = obj.astype(object)._values
# -> 1174         mapped = lib.map_infer(
#    1175             values,
#    1176             f,
#    1177             convert=self.convert_dtype,
#    1178         )
#    1180 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1181     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1182     #  See also GH#25959 regarding EA support
#    1183     return obj._constructor_expanddim(list(mapped), index=obj.index)
#
# File ~/miniforge3/envs/py311ts/lib/python3.11/site-packages/pandas/_libs/lib.pyx:2924, in pandas._libs.lib.map_infer()
#
# Cell In[56], line 12, in generate_simplified_sentence_OpenAI(complex_sentence)
#       8 prompt += f"Original sentences to simplify:\n\"{complex_sentence}\".\n Simplified: "
#      10 print("Prompt: ", prompt)
# ---> 12 response = client.chat.completions.create(
#      13 model="gpt-4o-2024-05-13",
#      14 messages=[
#      15     {"role": "system", "content": "You are a helpful assistant that is an expert in simplifying sentences for non-native speakers."},
#      16     {"role": "user", "content": prompt},
#      17 ]
#      18 )
#      20 # Extract the simplified sentence from the response
#      22 response_text = response.choices[0].message.content
#
# File ~/miniforge3/envs/py311ts/lib/python3.11/site-packages/openai/_utils/_utils.py:277, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     275             msg = f"Missing required argument: {quote(missing[0])}"
#     276     raise TypeError(msg)
# --> 277 return func(*args, **kwargs)
#
# File ~/miniforge3/envs/py311ts/lib/python3.11/site-packages/openai/resources/chat/completions.py:646, in Completions.create(self, messages, model, frequency_penalty, function_call, functions, logit_bias, logprobs, max_tokens, n, parallel_tool_calls, presence_penalty, response_format, seed, service_tier, stop, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, extra_headers, extra_query, extra_body, timeout)
#     612 @required_args(["messages", "model"], ["messages", "model", "stream"])
#     613 def create(
#     614     self,
#    (...)
#     644     timeout: float | httpx.Timeout | None | NotGiven = NOT_GIVEN,
#     645 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
# --> 646     return self._post(
#     647         "/chat/completions",
#     648         body=maybe_transform(
#     649             {
#     650                 "messages": messages,
#     651                 "model": model,
#     652                 "frequency_penalty": frequency_penalty,
#     653                 "function_call": function_call,
#     654                 "functions": functions,
#     655                 "logit_bias": logit_bias,
#     656                 "logprobs": logprobs,
#     657                 "max_tokens": max_tokens,
#     658                 "n": n,
#     659                 "parallel_tool_calls": parallel_tool_calls,
#     660                 "presence_penalty": presence_penalty,
#     661                 "response_format": response_format,
#     662                 "seed": seed,
#     663                 "service_tier": service_tier,
#     664                 "stop": stop,
#     665                 "stream": stream,
#     666                 "stream_options": stream_options,
#     667                 "temperature": temperature,
#     668                 "tool_choice": tool_choice,
#     669                 "tools": tools,
#     670                 "top_logprobs": top_logprobs,
#     671                 "top_p": top_p,
#     672                 "user": user,
#     673             },
#     674             completion_create_params.CompletionCreateParams,
#     675         ),
#     676         options=make_request_options(
#     677             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#     678         ),
#     679         cast_to=ChatCompletion,
#     680         stream=stream or False,
#     681         stream_cls=Stream[ChatCompletionChunk],
#     682     )
#
# File ~/miniforge3/envs/py311ts/lib/python3.11/site-packages/openai/_base_client.py:1271, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1257 def post(
#    1258     self,
#    1259     path: str,
#    (...)
#    1266     stream_cls: type[_StreamT] | None = None,
#    1267 ) -> ResponseT | _StreamT:
#    1268     opts = FinalRequestOptions.construct(
#    1269         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1270     )
# -> 1271     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File ~/miniforge3/envs/py311ts/lib/python3.11/site-packages/openai/_base_client.py:942, in SyncAPIClient.request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     933 def request(
#     934     self,
#     935     cast_to: Type[ResponseT],
#    (...)
#     940     stream_cls: type[_StreamT] | None = None,
#     941 ) -> ResponseT | _StreamT:
# --> 942     return self._request(
#     943         cast_to=cast_to,
#     944         options=options,
#     945         stream=stream,
#     946         stream_cls=stream_cls,
#     947         remaining_retries=remaining_retries,
#     948     )
#
# File ~/miniforge3/envs/py311ts/lib/python3.11/site-packages/openai/_base_client.py:978, in SyncAPIClient._request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     975 log.debug("Sending HTTP Request: %s %s", request.method, request.url)
#     977 try:
# --> 978     response = self._client.send(
#     979         request,
#     980         stream=stream or self._should_stream_response_body(request=request),
#     981         **kwargs,
#     982     )
#     983 except httpx.TimeoutException as err:
#     984     log.debug("Encountered httpx.TimeoutException", exc_info=True)
#
# File ~/miniforge3/envs/py311ts/lib/python3.11/site-packages/httpx/_client.py:914, in Client.send(self, request, stream, auth, follow_redirects)
#     906 follow_redirects = (
#     907     self.follow_redirects
#     908     if isinstance(follow_redirects, UseClientDefault)
#     909     else follow_redirects
#     910 )
#     912 auth = self._build_request_auth(request, auth)
# --> 914 response = self._send_handling_auth(
#     915     request,
#     916     auth=auth,
#     917     follow_redirects=follow_redirects,
#     918     history=[],
#     919 )
#     920 try:
#     921     if not stream:
#
# File ~/miniforge3/envs/py311ts/lib/python3.11/site-packages/httpx/_client.py:942, in Client._send_handling_auth(self, request, auth, follow_redirects, history)
#     939 request = next(auth_flow)
#     941 while True:
# --> 942     response = self._send_handling_redirects(
#     943         request,
#     944         follow_redirects=follow_redirects,
#     945         history=history,
#     946     )
#     947     try:
#     948         try:
#
# File ~/miniforge3/envs/py311ts/lib/python3.11/site-packages/httpx/_client.py:979, in Client._send_handling_redirects(self, request, follow_redirects, history)
#     976 for hook in self._event_hooks["request"]:
#     977     hook(request)
# --> 979 response = self._send_single_request(request)
#     980 try:
#     981     for hook in self._event_hooks["response"]:
#
# File ~/miniforge3/envs/py311ts/lib/python3.11/site-packages/httpx/_client.py:1015, in Client._send_single_request(self, request)
#    1010     raise RuntimeError(
#    1011         "Attempted to send an async request with a sync Client instance."
#    1012     )
#    1014 with request_context(request=request):
# -> 1015     response = transport.handle_request(request)
#    1017 assert isinstance(response.stream, SyncByteStream)
#    1019 response.request = request
#
# File ~/miniforge3/envs/py311ts/lib/python3.11/site-packages/httpx/_transports/default.py:233, in HTTPTransport.handle_request(self, request)
#     220 req = httpcore.Request(
#     221     method=request.method,
#     222     url=httpcore.URL(
#    (...)
#     230     extensions=request.extensions,
#     231 )
#     232 with map_httpcore_exceptions():
# --> 233     resp = self._pool.handle_request(req)
#     235 assert isinstance(resp.stream, typing.Iterable)
#     237 return Response(
#     238     status_code=resp.status,
#     239     headers=resp.headers,
#     240     stream=ResponseStream(resp.stream),
#     241     extensions=resp.extensions,
#     242 )
#
# File ~/miniforge3/envs/py311ts/lib/python3.11/site-packages/httpcore/_sync/connection_pool.py:216, in ConnectionPool.handle_request(self, request)
#     213         closing = self._assign_requests_to_connections()
#     215     self._close_connections(closing)
# --> 216     raise exc from None
#     218 # Return the response. Note that in this case we still have to manage
#     219 # the point at which the response is closed.
#     220 assert isinstance(response.stream, Iterable)
#
# File ~/miniforge3/envs/py311ts/lib/python3.11/site-packages/httpcore/_sync/connection_pool.py:196, in ConnectionPool.handle_request(self, request)
#     192 connection = pool_request.wait_for_connection(timeout=timeout)
#     194 try:
#     195     # Send the request on the assigned connection.
# --> 196     response = connection.handle_request(
#     197         pool_request.request
#     198     )
#     199 except ConnectionNotAvailable:
#     200     # In some cases a connection may initially be available to
#     201     # handle a request, but then become unavailable.
#     202     #
#     203     # In this case we clear the connection and try again.
#     204     pool_request.clear_connection()
#
# File ~/miniforge3/envs/py311ts/lib/python3.11/site-packages/httpcore/_sync/connection.py:101, in HTTPConnection.handle_request(self, request)
#      98     self._connect_failed = True
#      99     raise exc
# --> 101 return self._connection.handle_request(request)
#
# File ~/miniforge3/envs/py311ts/lib/python3.11/site-packages/httpcore/_sync/http11.py:143, in HTTP11Connection.handle_request(self, request)
#     141     with Trace("response_closed", logger, request) as trace:
#     142         self._response_closed()
# --> 143 raise exc
#
# File ~/miniforge3/envs/py311ts/lib/python3.11/site-packages/httpcore/_sync/http11.py:113, in HTTP11Connection.handle_request(self, request)
#     102     pass
#     104 with Trace(
#     105     "receive_response_headers", logger, request, kwargs
#     106 ) as trace:
#     107     (
#     108         http_version,
#     109         status,
#     110         reason_phrase,
#     111         headers,
#     112         trailing_data,
# --> 113     ) = self._receive_response_headers(**kwargs)
#     114     trace.return_value = (
#     115         http_version,
#     116         status,
#     117         reason_phrase,
#     118         headers,
#     119     )
#     121 network_stream = self._network_stream
#
# File ~/miniforge3/envs/py311ts/lib/python3.11/site-packages/httpcore/_sync/http11.py:186, in HTTP11Connection._receive_response_headers(self, request)
#     183 timeout = timeouts.get("read", None)
#     185 while True:
# --> 186     event = self._receive_event(timeout=timeout)
#     187     if isinstance(event, h11.Response):
#     188         break
#
# File ~/miniforge3/envs/py311ts/lib/python3.11/site-packages/httpcore/_sync/http11.py:224, in HTTP11Connection._receive_event(self, timeout)
#     221     event = self._h11_state.next_event()
#     223 if event is h11.NEED_DATA:
# --> 224     data = self._network_stream.read(
#     225         self.READ_NUM_BYTES, timeout=timeout
#     226     )
#     228     # If we feed this case through h11 we'll raise an exception like:
#     229     #
#     230     #     httpcore.RemoteProtocolError: can't handle event type
#    (...)
#     234     # perspective. Instead we handle this case distinctly and treat
#     235     # it as a ConnectError.
#     236     if data == b"" and self._h11_state.their_state == h11.SEND_RESPONSE:
#
# File ~/miniforge3/envs/py311ts/lib/python3.11/site-packages/httpcore/_backends/sync.py:126, in SyncStream.read(self, max_bytes, timeout)
#     124 with map_exceptions(exc_map):
#     125     self._sock.settimeout(timeout)
# --> 126     return self._sock.recv(max_bytes)
#
# File ~/miniforge3/envs/py311ts/lib/python3.11/ssl.py:1295, in SSLSocket.recv(self, buflen, flags)
#    1291     if flags != 0:
#    1292         raise ValueError(
#    1293             "non-zero flags not allowed in calls to recv() on %s" %
#    1294             self.__class__)
# -> 1295     return self.read(buflen)
#    1296 else:
#    1297     return super().recv(buflen, flags)
#
# File ~/miniforge3/envs/py311ts/lib/python3.11/ssl.py:1168, in SSLSocket.read(self, len, buffer)
#    1166         return self._sslobj.read(len, buffer)
#    1167     else:
# -> 1168         return self._sslobj.read(len)
#    1169 except SSLError as x:
#    1170     if x.args[0] == SSL_ERROR_EOF and self.suppress_ragged_eofs:
#
# KeyboardInterrupt:

# %%
# now run on GERMAN dataset(s)

def generate_simplified_sentence_OpenAI_DE(complex_sentence):
    prompt = generate_main_prompt(main_prompt_DE, language="DE")
    prompt += f"Originaler Satz zu vereinfachen:\n\"{complex_sentence}\".\n Vereinfacht: "

    print("Prompt: ", prompt)
    
    response = client.chat.completions.create(
    model="gpt-4o",
    messages=[
        {"role": "system", "content": "Du bist ein hilfreicher Assistent und Experte im vereinfachen von Sätzen für nicht-muttersprachliche Leser."}, #different system prompt!
        {"role": "user", "content": prompt},
    ]
    )

    # Extract the simplified sentence from the response
    response_text = response.choices[0].message.content
    print("Response text:" + response_text) 
    simplified_sentence = response_text

    # Remove leading and trailing quotation marks if present
    simplified_sentence = response_text.strip('"')
    
    print(f"\n\nSimplified OG sentence: {complex_sentence} to {simplified_sentence}")
    print("----------------------------\n\n")

    return simplified_sentence

# %%
# GERMAN Execution for OpenAI's ChatGPT model

run_model_on_multiple_datasets(
    model_function = generate_simplified_sentence_OpenAI_DE, 
    datasets = datasets_DE, 
    input_column = 'complex_sentence', 
    output_column = 'simplified_sentence', 
    save_dir = save_directory, 
    model_name = 'OpenAI')
# Out:
# Prompt:  Bitte schreibe den folgenden komplexen Satz um, um ihn für Nicht-Muttersprachler leichter verständlich zu machen. Du kannst dies tun, indem du Teile des Satzes umstellst, komplexe Wörter durch einfachere Synonyme ersetzt (d.h. umformulieren), unwichtige Informationen weglässt (d.h. komprimieren) und/oder einen langen, komplexen Satz in mehrere einfachere Sätze aufteilst. Der vereinfachte Satz muss grammatikalisch korrekt, fließend und verständlich sein und die Hauptideen des ursprünglichen Satzes beibehalten, ohne dessen Bedeutung zu verändern.
# Antworte ausschließlich und immer nur mit dem vereinfachten Satz, nichts weiter. Beginne die Antwort nicht mit einer Einleitung.
# Beispiele:
#  Original: Zudem erfolgt im Laufe des Auslaufprozesses eine Anreicherung von Seifenfilm-stabilisierenden Tensidmolekülen im unteren Bereich der Seifenblase, sodass deren obere Region infolge des relativen Mangels von an die Oberfläche adsorbierten Tensidmolekülen zusätzlich destabilisiert wird.
#  Vereinfacht: Beim Auslaufen von einer Seifenblase sammeln sich Moleküle, die die Seifenblase stabil machen, im unteren Bereich der Seifenblase. Dadurch sind im oberen Bereich nur noch wenige vorhanden. Dadurch wird die Seifenblase weniger stabil.
#
#  Original: Die Versauerung verläuft nach dem Fünften Sachstandsbericht des IPCC schneller als alle ähnlichen Versauerungen der vergangenen 65 Mio. Jahre, eventuell der vergangenen 300 Mio. Jahre.
#  Vereinfacht: Die Versauerung verläuft nach dem fünften Bericht des IPCC schneller als alle ähnlichen Versauerungen der letzten 65 Mio. Jahre. Vielleicht sogar der vergangenen 300 Mio. Jahre.
#
#  Original: In beiden Fällen wird die Versauerung auf die menschlichen Emissionen von Kohlenstoffdioxid zurückgeführt und mit 0,11 pH-Einheiten beziffert.
#  Vereinfacht: In beiden Fällen liegt die Versauerung am Kohlenstoffdioxid, das durch Menschen entstanden ist. Die Versauerung wurde mit 0,11 pH-Einheiten gemessen.
#
# Originaler Satz zu vereinfachen:
# "Am 22. März 1985 unterzeichnete die Europäische Gemeinschaft gemeinsam mit mehreren Mitgliedstaaten das Wiener Übereinkommen zum Schutz der Ozonschicht und darauf folgend am 16. September 1987 auch das Montrealer Protokoll.".
#  Vereinfacht:
# Response text:Die Europäische Gemeinschaft unterzeichnete am 22. März 1985 das Wiener Übereinkommen zum Schutz der Ozonschicht und am 16. September 1987 das Montrealer Protokoll.
#
#
# Simplified OG sentence: Am 22. März 1985 unterzeichnete die Europäische Gemeinschaft gemeinsam mit mehreren Mitgliedstaaten das Wiener Übereinkommen zum Schutz der Ozonschicht und darauf folgend am 16. September 1987 auch das Montrealer Protokoll. to Die Europäische Gemeinschaft unterzeichnete am 22. März 1985 das Wiener Übereinkommen zum Schutz der Ozonschicht und am 16. September 1987 das Montrealer Protokoll.
# ----------------------------
#
#
# Prompt:  Bitte schreibe den folgenden komplexen Satz um, um ihn für Nicht-Muttersprachler leichter verständlich zu machen. Du kannst dies tun, indem du Teile des Satzes umstellst, komplexe Wörter durch einfachere Synonyme ersetzt (d.h. umformulieren), unwichtige Informationen weglässt (d.h. komprimieren) und/oder einen langen, komplexen Satz in mehrere einfachere Sätze aufteilst. Der vereinfachte Satz muss grammatikalisch korrekt, fließend und verständlich sein und die Hauptideen des ursprünglichen Satzes beibehalten, ohne dessen Bedeutung zu verändern.
# Antworte ausschließlich und immer nur mit dem vereinfachten Satz, nichts weiter. Beginne die Antwort nicht mit einer Einleitung.
# Beispiele:
#  Original: Auch um den hohen Zeitaufwand dieses Verfahrens zu umgehen, werden jedoch immer mehr Gesetzesvorschläge in informellen Trilogverfahren verhandelt, um dann bereits in erster Lesung beschlossen werden zu können: zwischen 2004 und 2009 etwa traf dies auf 72 % aller Gesetzesentwürfe zu, im Vergleich zu 33 % zwischen 1999 und 2004.
#  Vereinfacht: Auch weil dieses Verfahren sehr lange dauert, werden immer mehr Gesetzesvorschläge in informellen Trilogverfahren verhandelt. Das wird gemacht, damit sie bereits in der ersten Lesung beschlossen werden können. Zwischen 2004 und 2009 etwa traf dies auf 72% aller Gesetzesentwürfe zu. Zwischen 1999 und 2004 waren es nur 33%.
#
#  Original: Wenn man von diesen Abweichungen absieht, dann ist Idealität eine Eigenschaft des Bauplans des Würfels, also unter anderem seiner geometrischen Form.
#  Vereinfacht: Die ideale Funktionsweise eines Würfels wird durch seine geometrische Form bestimmt.
#
#  Original: Auf drei Schiffen des III. Geschwaders weigerten sich die Matrosen, die Anker zu lichten.
#  Vereinfacht: Auf drei Schiffen, die zu einem Verband von Kriegsschiffen gehörten, weigerten sich die Schiffsleute weiterzufahren.
#
# Originaler Satz zu vereinfachen:
# "Im folgenden Jahr wurde die VERORDNUNG (EWG) Nr. 3322/88, als erste europäische Verordnung zur Regelung ozonschädigender Stoffe verabschiedet.".
#  Vereinfacht:
# Response text:Im nächsten Jahr wurde die Verordnung (EWG) Nr. 3322/88 verabschiedet. Es war die erste europäische Verordnung, die ozonschädigende Stoffe regelte.
#
#
# Simplified OG sentence: Im folgenden Jahr wurde die VERORDNUNG (EWG) Nr. 3322/88, als erste europäische Verordnung zur Regelung ozonschädigender Stoffe verabschiedet. to Im nächsten Jahr wurde die Verordnung (EWG) Nr. 3322/88 verabschiedet. Es war die erste europäische Verordnung, die ozonschädigende Stoffe regelte.
# ----------------------------
#
#
# Prompt:  Bitte schreibe den folgenden komplexen Satz um, um ihn für Nicht-Muttersprachler leichter verständlich zu machen. Du kannst dies tun, indem du Teile des Satzes umstellst, komplexe Wörter durch einfachere Synonyme ersetzt (d.h. umformulieren), unwichtige Informationen weglässt (d.h. komprimieren) und/oder einen langen, komplexen Satz in mehrere einfachere Sätze aufteilst. Der vereinfachte Satz muss grammatikalisch korrekt, fließend und verständlich sein und die Hauptideen des ursprünglichen Satzes beibehalten, ohne dessen Bedeutung zu verändern.
# Antworte ausschließlich und immer nur mit dem vereinfachten Satz, nichts weiter. Beginne die Antwort nicht mit einer Einleitung.
# Beispiele:
#  Original: Die als Bestandteil des Binnenmarkts in der Einheitlichen Europäischen Akte festgeschriebene Freizügigkeit des Personenverkehrs wurde durch das 1985 in Schengen getroffene Abkommen zunächst von den Beneluxstaaten, Frankreich und der Bundesrepublik Deutschland auf den Weg gebracht, ohne dass aber die dazu nötige polizeiliche Zusammenarbeit und Vereinheitlichung der Visa die Durchführung schon gestattet hätte.
#  Vereinfacht: Teil der Schengener Abkommens war die Freizügigkeit des Personenverkehrs. Sie wurde 1985 zunächst von den Beneluxstaaten, Frankreich und Deutschland durchgesetzt. Allerdings ohne vorher auf Erlaubnis zu warten zur polizeilichen Zusammenarbeit und Vereinheitlichung der Visa.
#
#  Original: Anders als in den meisten nationalen Parlamenten, wo die Regierungsfraktionen normalerweise loyal zur Regierung stehen und deren Gesetzentwürfe prinzipiell unterstützen, bilden sich im Europäischen Parlament je nach Abstimmungsthema wechselnde Mehrheiten.
#  Vereinfacht: In den meisten nationalen Parlamenten stehen die Regierungsfraktionen (Gruppen innerhalb der Regierung) normalerweise der Regierung treu. Sie unterstützen die Gesetzesentwürfe der Regierung. Aber im Europäischen Parlament bilden sich je nach Abstimmungsthema unterschiedliche Mehrheiten.
#
#  Original: Sie umfasst die in der Erde gespeicherte Energie, soweit sie entzogen und genutzt werden kann, und zählt zu den regenerativen Energien.
#  Vereinfacht: Erdwärme ist die in der Erde gespeicherte Energie, wenn sie entzogen und genutzt werden kann. Die Erdwärme zählt zu den erneuerbaren Energien.
#
# Originaler Satz zu vereinfachen:
# "Zur Anpassung an die Änderungen des Montrealer Protokolls wurden durch nachfolgende Verordnungen die geregelten Substanzen immer weiter ergänzt und Ein- und Ausfuhr, Produktion und Verwendung weiter eingeschränkt, Fristen verkürzt und Substanzen letztendlich verboten.".
#  Vereinfacht:
# Response text:Um das Montrealer Protokoll anzupassen, ergänzten nachfolgende Verordnungen die geregelten Substanzen. Außerdem wurden Einfuhr, Ausfuhr, Produktion und Verwendung weiter eingeschränkt. Fristen wurden verkürzt und bestimmte Substanzen schließlich verboten.
#
#
# Simplified OG sentence: Zur Anpassung an die Änderungen des Montrealer Protokolls wurden durch nachfolgende Verordnungen die geregelten Substanzen immer weiter ergänzt und Ein- und Ausfuhr, Produktion und Verwendung weiter eingeschränkt, Fristen verkürzt und Substanzen letztendlich verboten. to Um das Montrealer Protokoll anzupassen, ergänzten nachfolgende Verordnungen die geregelten Substanzen. Außerdem wurden Einfuhr, Ausfuhr, Produktion und Verwendung weiter eingeschränkt. Fristen wurden verkürzt und bestimmte Substanzen schließlich verboten.
# ----------------------------
#
#
# Prompt:  Bitte schreibe den folgenden komplexen Satz um, um ihn für Nicht-Muttersprachler leichter verständlich zu machen. Du kannst dies tun, indem du Teile des Satzes umstellst, komplexe Wörter durch einfachere Synonyme ersetzt (d.h. umformulieren), unwichtige Informationen weglässt (d.h. komprimieren) und/oder einen langen, komplexen Satz in mehrere einfachere Sätze aufteilst. Der vereinfachte Satz muss grammatikalisch korrekt, fließend und verständlich sein und die Hauptideen des ursprünglichen Satzes beibehalten, ohne dessen Bedeutung zu verändern.
# Antworte ausschließlich und immer nur mit dem vereinfachten Satz, nichts weiter. Beginne die Antwort nicht mit einer Einleitung.
# Beispiele:
#  Original: Teilweise vertreten verschiedene gesellschaftliche Gruppen jeweils den Standpunkt der Wahlfreiheit, allerdings mit unterschiedlicher Gewichtung: Die eine Seite hebt die Möglichkeit zur Erwerbsarbeit auch mit Kindern hervor, die andere betont die Freiheit, auch die traditionelle Familienform zu wählen.
#  Vereinfacht: Verschiedene gesellschaftliche Gruppen sind für die Wahlfreiheit. Allerdings möchte die eine Gruppe, dass es auch möglich ist zu arbeiten, wenn man Kinder hat. Und die andere Gruppe findet es wichtig, dass man auch traditionelle Familienformen wählen kann.
#
#  Original: Infolge des gravitationsbedingten Auslaufens (Drainage) der zwischen den Seifenfilmoberflächen befindlichen Flüssigkeit dünnt eine Seifenblase in ihrem oberen Teil zunehmend aus.
#  Vereinfacht: Wegen der Erdanziehungskraft läuft die Flüssigkeit, die sich zwischen den Seifenfilmoberflächen befindet, nach unten (Drainage). Deshalb dünnt eine Seifenblase in ihrem oberen Teil zunehmend aus.
#
#  Original: Die als Bestandteil des Binnenmarkts in der Einheitlichen Europäischen Akte festgeschriebene Freizügigkeit des Personenverkehrs wurde durch das 1985 in Schengen getroffene Abkommen zunächst von den Beneluxstaaten, Frankreich und der Bundesrepublik Deutschland auf den Weg gebracht, ohne dass aber die dazu nötige polizeiliche Zusammenarbeit und Vereinheitlichung der Visa die Durchführung schon gestattet hätte.
#  Vereinfacht: Teil der Schengener Abkommens war die Freizügigkeit des Personenverkehrs. Sie wurde 1985 zunächst von den Beneluxstaaten, Frankreich und Deutschland durchgesetzt. Allerdings ohne vorher auf Erlaubnis zu warten zur polizeilichen Zusammenarbeit und Vereinheitlichung der Visa.
#
# Originaler Satz zu vereinfachen:
# "Unternehmen müssen die Emissionen von geregelten Stoffen in die Umwelt verhindern oder auf ein Mindestmaß reduzieren.".
#  Vereinfacht:
# Response text:Unternehmen müssen verhindern, dass schädliche Stoffe in die Umwelt gelangen, oder die Menge dieser Stoffe so gering wie möglich halten.
#
#
# Simplified OG sentence: Unternehmen müssen die Emissionen von geregelten Stoffen in die Umwelt verhindern oder auf ein Mindestmaß reduzieren. to Unternehmen müssen verhindern, dass schädliche Stoffe in die Umwelt gelangen, oder die Menge dieser Stoffe so gering wie möglich halten.
# ----------------------------
#
#
# Prompt:  Bitte schreibe den folgenden komplexen Satz um, um ihn für Nicht-Muttersprachler leichter verständlich zu machen. Du kannst dies tun, indem du Teile des Satzes umstellst, komplexe Wörter durch einfachere Synonyme ersetzt (d.h. umformulieren), unwichtige Informationen weglässt (d.h. komprimieren) und/oder einen langen, komplexen Satz in mehrere einfachere Sätze aufteilst. Der vereinfachte Satz muss grammatikalisch korrekt, fließend und verständlich sein und die Hauptideen des ursprünglichen Satzes beibehalten, ohne dessen Bedeutung zu verändern.
# Antworte ausschließlich und immer nur mit dem vereinfachten Satz, nichts weiter. Beginne die Antwort nicht mit einer Einleitung.
# Beispiele:
#  Original: Bald danach  zum 1. Januar 1995  traten mit Österreich, Schweden und Finnland nach zügigen Beitrittsverhandlungen drei Staaten der EU bei, die bis zum Ende der Ost-West-Konfrontation durch ihre strikte Neutralitätspolitik daran gehindert waren.
#  Vereinfacht: Zum 1. Januar 1995 traten Österreich, Schweden und Finnland in die EU ein. Die Beitrittsverhandlungen dauerten nicht lange. Vor dem Ende der Ost-West-Konfrontation konnten sie nicht in die EU eintreten, weil ihre Politik neutral war.
#
#  Original: Spannungen innerhalb der Decke führten zu einer Synklinale, einer konkav  also nach innen  gewölbten Struktur, durch die Gesteinsschichten im Osten und Westen des Parks höher liegen als im Zentrum.
#  Vereinfacht: Spannungen innerhalb der Decke führten zu einer konkaven - also nach innen - gewölbten Struktur. Aufgrund dieser Struktur (auch Synklinale genannt) liegen die Gesteinsschichten im Osten und Westen des Parks höher als im Zentrum.
#
#  Original: Den Hafen des schwedischen Luleå können viele Schiffe nicht mehr anlaufen, hier sinkt der Meeresspiegel jährlich ebenfalls um nahezu einen Zentimeter, prognostiziert für noch mindestens 600 weitere Jahre.
#  Vereinfacht: In dem Hafen des schwedischen Luleå können viele Schiffe nicht mehr anlegen. Dort sinkt der Meeresspiegel jährlich um fast einen Zentimeter. Das soll wohl auch die nächsten 600 Jahre weiter so sein.
#
# Originaler Satz zu vereinfachen:
# "Francesco Calzolari stammte aus einer alteingesessenen Veroneser Familie, die sich bereits im 13. Jahrhundert unter Ezzelino da Romano einen Namen gemacht hatte.".
#  Vereinfacht:
# Response text:Francesco Calzolari kam aus einer alten Familie aus Verona, die schon im 13. Jahrhundert unter Ezzelino da Romano bekannt wurde.
#
#
# Simplified OG sentence: Francesco Calzolari stammte aus einer alteingesessenen Veroneser Familie, die sich bereits im 13. Jahrhundert unter Ezzelino da Romano einen Namen gemacht hatte. to Francesco Calzolari kam aus einer alten Familie aus Verona, die schon im 13. Jahrhundert unter Ezzelino da Romano bekannt wurde.
# ----------------------------
#
#
# Prompt:  Bitte schreibe den folgenden komplexen Satz um, um ihn für Nicht-Muttersprachler leichter verständlich zu machen. Du kannst dies tun, indem du Teile des Satzes umstellst, komplexe Wörter durch einfachere Synonyme ersetzt (d.h. umformulieren), unwichtige Informationen weglässt (d.h. komprimieren) und/oder einen langen, komplexen Satz in mehrere einfachere Sätze aufteilst. Der vereinfachte Satz muss grammatikalisch korrekt, fließend und verständlich sein und die Hauptideen des ursprünglichen Satzes beibehalten, ohne dessen Bedeutung zu verändern.
# Antworte ausschließlich und immer nur mit dem vereinfachten Satz, nichts weiter. Beginne die Antwort nicht mit einer Einleitung.
# Beispiele:
#  Original: Die Töne wurden zunächst in eine Zinnfolie geritzt, später auf einer Phonographenwalze mit wendelförmiger Tonspur in Höhenschrift gespeichert, wobei das Prinzip der Amplitudenauslenkung auch hier unmittelbar akustisch (Membran/Trichter) genutzt wurde.
#  Vereinfacht: Die Töne wurden zunächst in eine Zinnfolie geritzt. Später wurden sie auf einer Phonographenwalze mit wendelförmiger Tonspur in Höhenschrift gespeichert. Das Prinzip der Amplitudenauslenkung wurde auch hier unmittelbar akustisch genutzt. Dies geschah mit einer Membran oder einem Trichter.
#
#  Original: Wirtschaftliche und politische Spannungen mit dem Deutschen Reich gehören zu den wichtigsten Ursachen des Ersten Weltkriegs, in dem Großbritannien in hohem Maße auf die Unterstützung durch seine Kolonien angewiesen war.
#  Vereinfacht: Eine der wichtigsten Ursachen des ersten Weltkriegs war die wirtschaftliche und politische Spannung mit dem Deutschen Reich. In dem Krieg war Großbritannien sehr auf die Unterstützungen der Kolonien angewiesen.
#
#  Original: Auch der Gesamtenergieverbrauch bei der Wiederaufbereitung wird vielfach überschätzt.
#  Vereinfacht: Viele überschätzen den Gesamtenergieverbrauch bei der Wiederaufbereitung.
#
# Originaler Satz zu vereinfachen:
# "Francescos kindliche Neugierde beschränkte sich aber nicht nur auf die Botanik, auch Mineralien, Fossilien, und Insekten weckten sein Interesse, die er bei seinen Wanderungen mit seinem Vater sammelte.".
#  Vereinfacht:
# Response text:Francesco interessierte sich nicht nur für Pflanzen, sondern auch für Mineralien, Fossilien und Insekten, die er mit seinem Vater sammelte.
#
#
# Simplified OG sentence: Francescos kindliche Neugierde beschränkte sich aber nicht nur auf die Botanik, auch Mineralien, Fossilien, und Insekten weckten sein Interesse, die er bei seinen Wanderungen mit seinem Vater sammelte. to Francesco interessierte sich nicht nur für Pflanzen, sondern auch für Mineralien, Fossilien und Insekten, die er mit seinem Vater sammelte.
# ----------------------------
#
#
# Prompt:  Bitte schreibe den folgenden komplexen Satz um, um ihn für Nicht-Muttersprachler leichter verständlich zu machen. Du kannst dies tun, indem du Teile des Satzes umstellst, komplexe Wörter durch einfachere Synonyme ersetzt (d.h. umformulieren), unwichtige Informationen weglässt (d.h. komprimieren) und/oder einen langen, komplexen Satz in mehrere einfachere Sätze aufteilst. Der vereinfachte Satz muss grammatikalisch korrekt, fließend und verständlich sein und die Hauptideen des ursprünglichen Satzes beibehalten, ohne dessen Bedeutung zu verändern.
# Antworte ausschließlich und immer nur mit dem vereinfachten Satz, nichts weiter. Beginne die Antwort nicht mit einer Einleitung.
# Beispiele:
#  Original: Als grobe Richtlinie sollten die imaginären Verbindungslinien der drei Kontaktpunkte und des Schulterblattes eine Raute darstellen, deren Seiten möglichst etwa gleich lang sein sollten.
#  Vereinfacht: Als grobe Richtlinie sollten die gedachten Verbindungslinien der drei Kontaktpunkte und des Schulterblattes eine Raute darstellen. Deren Seiten sollten möglichst gleich lang sein.
#
#  Original: Bei den Mönchsorden regelten genaue Vorschriften die Benutzung und Verwahrung der verwendeten Rasiermesser.
#  Vereinfacht: Bei den Mönchsorden gab es genaue Vorschriften. So wurde genau geregelt, wie Rasiermesser benutzt und verwahrt werden sollten.
#
#  Original: Um Durchschnittswerte für Meereswasser angeben zu können, müssen darüber hinaus Modelle angewendet werden, um ein chemisches Gleichgewicht des Ozeans zu simulieren.
#  Vereinfacht: Es müssen Modelle angewendet werden, die ein chemisches Gleichgewicht des Ozeans simulieren. Damit können dann Durchschnittswerte für Meerwasser angegeben werden.
#
# Originaler Satz zu vereinfachen:
# "Die Apotheke seines Vaters wurde auch von Gelehrten aufgesucht, die dort ihre Meinungen und Erkenntnisse austauschten und die einen entscheidenden Einfluss auf den aufgeweckten, jungen Francesco Calzolari ausübten.".
#  Vereinfacht:
# Response text:Gelehrte besuchten die Apotheke seines Vaters, um Meinungen und Erkenntnisse auszutauschen. Sie beeinflussten den aufgeweckten jungen Francesco Calzolari stark.
#
#
# Simplified OG sentence: Die Apotheke seines Vaters wurde auch von Gelehrten aufgesucht, die dort ihre Meinungen und Erkenntnisse austauschten und die einen entscheidenden Einfluss auf den aufgeweckten, jungen Francesco Calzolari ausübten. to Gelehrte besuchten die Apotheke seines Vaters, um Meinungen und Erkenntnisse auszutauschen. Sie beeinflussten den aufgeweckten jungen Francesco Calzolari stark.
# ----------------------------
#
#
# Prompt:  Bitte schreibe den folgenden komplexen Satz um, um ihn für Nicht-Muttersprachler leichter verständlich zu machen. Du kannst dies tun, indem du Teile des Satzes umstellst, komplexe Wörter durch einfachere Synonyme ersetzt (d.h. umformulieren), unwichtige Informationen weglässt (d.h. komprimieren) und/oder einen langen, komplexen Satz in mehrere einfachere Sätze aufteilst. Der vereinfachte Satz muss grammatikalisch korrekt, fließend und verständlich sein und die Hauptideen des ursprünglichen Satzes beibehalten, ohne dessen Bedeutung zu verändern.
# Antworte ausschließlich und immer nur mit dem vereinfachten Satz, nichts weiter. Beginne die Antwort nicht mit einer Einleitung.
# Beispiele:
#  Original: Um Durchschnittswerte für Meereswasser angeben zu können, müssen darüber hinaus Modelle angewendet werden, um ein chemisches Gleichgewicht des Ozeans zu simulieren.
#  Vereinfacht: Es müssen Modelle angewendet werden, die ein chemisches Gleichgewicht des Ozeans simulieren. Damit können dann Durchschnittswerte für Meerwasser angegeben werden.
#
#  Original: Zunächst verwendete er als Pressmasse Zelluloid, das er unmittelbar vom Erfinder dieses Werkstoffs, John W. Hyatt, bezog und das sich bald als technisch ungeeignet erwies.
#  Vereinfacht: Am Anfang verwendete er zum Pressen das Material Zelluloid. Er bekam es von dem Erfinder, John W. Hyatt. Aber das Material erwies sich bald als ungeeignet.
#
#  Original: Die Rückverwandlung in hörbare Schallsignale kann rein mechanisch über eine Membran und einen Schalltrichter oder  bei heute üblichen Plattenspielern  auf elektromechanischem Weg mit anschließender elektronischer Verstärkung erfolgen.
#  Vereinfacht: Die Rückverwandlung in hörbare Schall-Signale kann rein mechanisch über eine Membran und einen Schalltrichter erfolgen. Oder wie bei heute üblichen Plattenspielern auf elektromechanischem Weg mit anschließender elektronischer Verstärkung.
#
# Originaler Satz zu vereinfachen:
#  Original: Die Ausgestaltung und Fortführung des europäischen Integrationsprozesses bleibt auch unter den Bedingungen des Reformvertrags von Lissabon eine außerordentliche Bewährungsprobe.
#  Vereinfacht: Auch mit dem Reformvertrag von Lissabon bleibt die Zusammenarbeit der europäischen Länder kompliziert.
#
#  Original: In den Tieflagen liegen Zungenbeckenseen, im höheren Gelände handelt es sich um Karseen.
#  Vereinfacht: In den Tälern liegen Seen, die man Zungenbeckenseen nennt. In den höheren Gegenden sind Seen, die man Karseen nennt.
#
# Originaler Satz zu vereinfachen:
# "Um den Monte Baldo noch näher zu sein, ließ sich Calzolari in Rivoli Veronese am südlichen Rand der Bergkette ein Landhaus errichten.".
#  Vereinfacht:
# Response text:Calzolari ließ sich in Rivoli Veronese ein Landhaus am südlichen Rand des Monte Baldo bauen, um näher am Berg zu sein.
#
#
# Simplified OG sentence: Um den Monte Baldo noch näher zu sein, ließ sich Calzolari in Rivoli Veronese am südlichen Rand der Bergkette ein Landhaus errichten. to Calzolari ließ sich in Rivoli Veronese ein Landhaus am südlichen Rand des Monte Baldo bauen, um näher am Berg zu sein.
# ----------------------------
#
#
# Prompt:  Bitte schreibe den folgenden komplexen Satz um, um ihn für Nicht-Muttersprachler leichter verständlich zu machen. Du kannst dies tun, indem du Teile des Satzes umstellst, komplexe Wörter durch einfachere Synonyme ersetzt (d.h. umformulieren), unwichtige Informationen weglässt (d.h. komprimieren) und/oder einen langen, komplexen Satz in mehrere einfachere Sätze aufteilst. Der vereinfachte Satz muss grammatikalisch korrekt, fließend und verständlich sein und die Hauptideen des ursprünglichen Satzes beibehalten, ohne dessen Bedeutung zu verändern.
# Antworte ausschließlich und immer nur mit dem vereinfachten Satz, nichts weiter. Beginne die Antwort nicht mit einer Einleitung.
# Beispiele:
#  Original: Demzufolge wird das Parlament gemeinsam mit dem Rat als Gesetzgeber tätig, übt gemeinsam mit ihm die Haushaltsbefugnisse aus und nimmt die politische Kontrolle wahr.
#  Vereinfacht: Das Europäische Parlament und der Rat sind als Gesetzgeber tätig. Gemeinsamen üben sie Haushalt-Befugnisse aus. Sie nehmen zudem die politische Kontrolle wahr.
#
#  Original: Die Erzeugung von Seifenblasen ist möglich, da die Oberfläche einer Flüssigkeit  in diesem Falle des Wassers  eine Oberflächenspannung besitzt, die zu einem elastischen Verhalten der Oberfläche führt.
#  Vereinfacht: Die Erzeugung von Seifenblasen ist möglich, weil Flüssigkeiten - in diesem Falle Wasser - eine elastische Oberfläche besitzen.
#
#  Original: Zusätzlich kommt in der Forschung ein breites Spektrum verschiedener Isotopenanalysen zum Einsatz, deren jüngste Entwicklungen eine bis vor kurzem unerreichbare Messgenauigkeit ermöglichen.
#  Vereinfacht: Außerdem werden in der Forschung viele verschiedene Isotopenanalysen eingesetzt. Ihre jüngste Entwicklung ermöglichen ermöglichen eine bis vor kurzem unerreichbare Messgenauigkeit.
#
# Originaler Satz zu vereinfachen:
# "Es gilt als erstes und ältestes Naturkundemuseum der Welt und ist erstmals 1554 dokumentiert, als Aldrovandi das von ihm als Naturae Theatrum beschriebene Museum besuchte.".
#  Vereinfacht:
# Response text:Es ist das älteste Naturkundemuseum der Welt und wurde erstmals 1554 erwähnt, als Aldrovandi es besuchte und als Naturae Theatrum beschrieb.
#
#
# Simplified OG sentence: Es gilt als erstes und ältestes Naturkundemuseum der Welt und ist erstmals 1554 dokumentiert, als Aldrovandi das von ihm als Naturae Theatrum beschriebene Museum besuchte. to Es ist das älteste Naturkundemuseum der Welt und wurde erstmals 1554 erwähnt, als Aldrovandi es besuchte und als Naturae Theatrum beschrieb.
# ----------------------------
#
#
# Prompt:  Bitte schreibe den folgenden komplexen Satz um, um ihn für Nicht-Muttersprachler leichter verständlich zu machen. Du kannst dies tun, indem du Teile des Satzes umstellst, komplexe Wörter durch einfachere Synonyme ersetzt (d.h. umformulieren), unwichtige Informationen weglässt (d.h. komprimieren) und/oder einen langen, komplexen Satz in mehrere einfachere Sätze aufteilst. Der vereinfachte Satz muss grammatikalisch korrekt, fließend und verständlich sein und die Hauptideen des ursprünglichen Satzes beibehalten, ohne dessen Bedeutung zu verändern.
# Antworte ausschließlich und immer nur mit dem vereinfachten Satz, nichts weiter. Beginne die Antwort nicht mit einer Einleitung.
# Beispiele:
#  Original: Die Erzeugung von Seifenblasen ist möglich, da die Oberfläche einer Flüssigkeit  in diesem Falle des Wassers  eine Oberflächenspannung besitzt, die zu einem elastischen Verhalten der Oberfläche führt.
#  Vereinfacht: Die Erzeugung von Seifenblasen ist möglich, weil Flüssigkeiten - in diesem Falle Wasser - eine elastische Oberfläche besitzen.
#
#  Original: Ein Spielwürfel, umgangssprachlich einfach (wie auch ursprünglich) Würfel (von althochdeutsch wurfil: verwandt mit Wurf und werfen[1]), ist ein Gegenstand, der nach einem Wurf auf einer waagerechten Ebene eine von mehreren unterscheidbaren stabilen Ruhelagen einnimmt und in vielen Spielen zum Erzeugen eines zufälligen Symbols (oft einer Zufallszahl) dient.
#  Vereinfacht: Ein Spielwürfel ist ein Gegenstand, der nach einem Wurf auf einer geraden Fläche in einer von mehreren Positionen liegen bleibt. Spielwürfel (oder auch Würfel) werden in vielen Spielen benutzt, um ein zufälliges Symbol oder eine Zahl zu erhalten.
#
#  Original: Vor 2,6 Milliarden Jahren bildete sich im Laufe der Entwicklung der Erdatmosphäre durch die Aktivität von Cyanobakterien der erste Sauerstoff in der Uratmosphäre und erreichte vor circa 2,2 Milliarden Jahren signifikante Konzentrationen.
#  Vereinfacht: Im Laufe der Entwicklung der Erdatmosphäre bildete sich vor 2,6 Milliarden Jahren  der erste Sauerstoff in der Uratmosphäre. Dies lag an der Aktivität von Cyanobakterien. Dieser Sauerstoff erreichte vor circa 2,2 Milliarden Jahren bedeutende Konzentrationen.
#
# Originaler Satz zu vereinfachen:
# "Diese kostete nur 20 Pfennig (ab 1871) und war damit die billigste und auflagenstärkste deutsche Buchreihe.".
#  Vereinfacht:
# Response text:Die Buchreihe kostete ab 1871 nur 20 Pfennig und war damit die günstigste und meistverkaufte in Deutschland.
#
#
# Simplified OG sentence: Diese kostete nur 20 Pfennig (ab 1871) und war damit die billigste und auflagenstärkste deutsche Buchreihe. to Die Buchreihe kostete ab 1871 nur 20 Pfennig und war damit die günstigste und meistverkaufte in Deutschland.
# ----------------------------
#
#
# Prompt:  Bitte schreibe den folgenden komplexen Satz um, um ihn für Nicht-Muttersprachler leichter verständlich zu machen. Du kannst dies tun, indem du Teile des Satzes umstellst, komplexe Wörter durch einfachere Synonyme ersetzt (d.h. umformulieren), unwichtige Informationen weglässt (d.h. komprimieren) und/oder einen langen, komplexen Satz in mehrere einfachere Sätze aufteilst. Der vereinfachte Satz muss grammatikalisch korrekt, fließend und verständlich sein und die Hauptideen des ursprünglichen Satzes beibehalten, ohne dessen Bedeutung zu verändern.
# Antworte ausschließlich und immer nur mit dem vereinfachten Satz, nichts weiter. Beginne die Antwort nicht mit einer Einleitung.
# Beispiele:
#  Original: Wegen des wachsenden Einflusses des Deutschen Reiches und der Vereinigten Staaten büßte Großbritannien seit etwa 1900 zunehmend seine politische und wirtschaftliche Vormachtstellung ein.
#  Vereinfacht: Seit 1900 verringerte sich die politische und wirtschaftlich führende Rolle von Großbritannien. Grund dafür war der steigende Einfluss des Deutschen Reiches und der Vereinigten Staaten.
#
#  Original: Während über die Ursachen der globalen Erwärmung weitgehend Einigkeit besteht[1] (hauptsächlich menschliche Emissionen von Treibhausgasen), werden ihre Folgen intensiv erörtert.
#  Vereinfacht: Über die Ursachen der globalen Erwärmung ist man sich weitgehend einig. Die Ursache sind hauptsächlich durch Menschen entstandene Treibhausgase. Die Folgen der globalen Erwärmung werden aber viel diskutiert.
#
#  Original: Betroffen sind davon bis auf wenige Ausnahmen alle Regionen, von den Tropen über die mittleren Breiten bis zu den polaren Eiskappen.
#  Vereinfacht: Betroffen sind bis auf wenige Ausnahmen alle Regionen. Die Tropen, die mittleren Breiten und die polaren Eiskappen.
#
# Originaler Satz zu vereinfachen:
# "Im Mittelalter lag südöstlich des heutigen Hofguts eine Burg, von der heute nur noch der Burgstall erhalten ist.".
#  Vereinfacht:
# Response text:Im Mittelalter gab es südöstlich des heutigen Hofguts eine Burg. Heute ist nur noch der Burghügel übrig.
#
#
# Simplified OG sentence: Im Mittelalter lag südöstlich des heutigen Hofguts eine Burg, von der heute nur noch der Burgstall erhalten ist. to Im Mittelalter gab es südöstlich des heutigen Hofguts eine Burg. Heute ist nur noch der Burghügel übrig.
# ----------------------------
#
#
# Prompt:  Bitte schreibe den folgenden komplexen Satz um, um ihn für Nicht-Muttersprachler leichter verständlich zu machen. Du kannst dies tun, indem du Teile des Satzes umstellst, komplexe Wörter durch einfachere Synonyme ersetzt (d.h. umformulieren), unwichtige Informationen weglässt (d.h. komprimieren) und/oder einen langen, komplexen Satz in mehrere einfachere Sätze aufteilst. Der vereinfachte Satz muss grammatikalisch korrekt, fließend und verständlich sein und die Hauptideen des ursprünglichen Satzes beibehalten, ohne dessen Bedeutung zu verändern.
# Antworte ausschließlich und immer nur mit dem vereinfachten Satz, nichts weiter. Beginne die Antwort nicht mit einer Einleitung.
# Beispiele:
#  Original: Neben dem ordentlichen Gesetzgebungsverfahren gibt es noch andere Formen der Rechtsetzung in der EU, bei denen das Parlament weniger Mitspracherechte besitzt.
#  Vereinfacht: Auch bei anderen Arten der Gesetzgebung hat das Parlament weniger Mitspracherechte.
#
#  Original: Dies bewirkt auch, dass die einzelnen Europa-Abgeordneten unabhängiger sind und mit Verhandlungsgeschick und Sachkenntnis größeren Einfluss auf die EU-Gesetzgebung haben, als es Abgeordneten nationaler Parlamente möglich ist.
#  Vereinfacht: Dies bewirkt auch, dass die einzelnen Europa-Abgeordneten unabhängiger sind. Außerdem haben sie mit guter Verhandlung und gutem Sach-Wissen größeren Einfluss auf die EU-Gesetzgebung. Mehr als Abgeordnete in nationalen Parlamenten.
#
#  Original: Wurde die Vereinbarkeit von Familie und Beruf ursprünglich mehr als die Frage angesehen, ob sich Mutterschaft und Berufstätigkeit überhaupt vereinbaren lassen,[1][2] entwickelte sich der gesellschaftliche Diskurs in den Industrienationen im Zuge der Emanzipation in die Richtung, wie sich für Mütter und Väter eine Berufstätigkeit mit der Erziehung der Kinder zeitlich vereinbaren lässt.
#  Vereinfacht: Früher war die Vereinbarkeit von Familie und Beruf eher als Frage angesehen, ob Mütter sich um ihre Kinder kümmern können und einen Beruf haben können. Später wurden die Frauen immer mehr den Männern gleich gestellt (Emanzipation). Der Begriff änderte sich also dazu, wie Eltern Beruf und die Erziehung der Kinder zeitlich kombinieren können.
#
# Originaler Satz zu vereinfachen:
# "Nach der Auflösung der Garnison Weingarten nach Beendigung des Ersten Weltkriegs wurde am oberen Froschweiher das städtische Freibad eingerichtet, dessen Vorläufer sich in der Nähe der Wileneggstrasse in Weingarten befanden.".
#  Vereinfacht:
# Response text:Nach dem Ende des Ersten Weltkriegs wurde beim oberen Froschweiher ein städtisches Freibad gebaut. Das erste Freibad davor war in der Nähe der Wileneggstrasse in Weingarten.
#
#
# Simplified OG sentence: Nach der Auflösung der Garnison Weingarten nach Beendigung des Ersten Weltkriegs wurde am oberen Froschweiher das städtische Freibad eingerichtet, dessen Vorläufer sich in der Nähe der Wileneggstrasse in Weingarten befanden. to Nach dem Ende des Ersten Weltkriegs wurde beim oberen Froschweiher ein städtisches Freibad gebaut. Das erste Freibad davor war in der Nähe der Wileneggstrasse in Weingarten.
# ----------------------------
#
#
# Prompt:  Bitte schreibe den folgenden komplexen Satz um, um ihn für Nicht-Muttersprachler leichter verständlich zu machen. Du kannst dies tun, indem du Teile des Satzes umstellst, komplexe Wörter durch einfachere Synonyme ersetzt (d.h. umformulieren), unwichtige Informationen weglässt (d.h. komprimieren) und/oder einen langen, komplexen Satz in mehrere einfachere Sätze aufteilst. Der vereinfachte Satz muss grammatikalisch korrekt, fließend und verständlich sein und die Hauptideen des ursprünglichen Satzes beibehalten, ohne dessen Bedeutung zu verändern.
# Antworte ausschließlich und immer nur mit dem vereinfachten Satz, nichts weiter. Beginne die Antwort nicht mit einer Einleitung.
# Beispiele:
#  Original: Da die Marineleitung sich des Gehorsams der Mannschaften nicht mehr sicher war, ließ sie ihren Schlachtplan fallen und beorderte das Geschwader nach Kiel zurück.
#  Vereinfacht: Die Marineleitung war sich nicht mehr sicher, dass die Mannschaft ihr gehorchte. Deshalb ließ sie ihren Schlachtplan fallen und bestellte die Schiffe nach Kiel zurück.
#
#  Original: Infolge der Eisschmelze in der Arktis und dem damit einhergehenden Verlust an beschwerender Masse steigt beispielsweise die Landmasse (-> Landfläche) Skandinaviens in Finnland und Schweden schneller als der regionale Meeresspiegel.
#  Vereinfacht: In der Artkis schmilzt das Eis. Durch das fehlende Gewicht steigt die Landfläche schnell in die Höhe. Dieses passiert in Skandinavien schneller als der Anstieg des Meeresspiegels, also die Höhe des Wassers im Meer. Betroffen sind zum Beispiel Finnland und Schweden.
#
#  Original: Der griechische Komödiendichter Aristophanes (um 450 bis 380 v. Chr.) zweifelt in Die Wolken daran, ob die sich in warmen Bädern verweichlichenden Griechen noch über die Manneskraft verfügten, die ihre Vorfahren in der Schlacht bei Marathon erfolgreich sein ließen.
#  Vereinfacht: Der griechische Komödiendichter Aristophanes (um 450 bis 380 vor Christus) erklärte in "Die Wolken", dass die Griechen durch warme Bäder verweichlicht seien. Er zweifelte daran, dass ihre Manneskraft mit denen der Vorfahren in der Schlacht bei Marathon vergleichbar sei.
#
# Originaler Satz zu vereinfachen:
# "In den Wäldern um Nessenreben findet man häufig Buchen, Eichen und Fichten".
#  Vereinfacht:
# Response text:In den Wäldern um Nessenreben wachsen oft Buchen, Eichen und Fichten.
#
#
# Simplified OG sentence: In den Wäldern um Nessenreben findet man häufig Buchen, Eichen und Fichten to In den Wäldern um Nessenreben wachsen oft Buchen, Eichen und Fichten.
# ----------------------------
#
#
# Prompt:  Bitte schreibe den folgenden komplexen Satz um, um ihn für Nicht-Muttersprachler leichter verständlich zu machen. Du kannst dies tun, indem du Teile des Satzes umstellst, komplexe Wörter durch einfachere Synonyme ersetzt (d.h. umformulieren), unwichtige Informationen weglässt (d.h. komprimieren) und/oder einen langen, komplexen Satz in mehrere einfachere Sätze aufteilst. Der vereinfachte Satz muss grammatikalisch korrekt, fließend und verständlich sein und die Hauptideen des ursprünglichen Satzes beibehalten, ohne dessen Bedeutung zu verändern.
# Antworte ausschließlich und immer nur mit dem vereinfachten Satz, nichts weiter. Beginne die Antwort nicht mit einer Einleitung.
# Beispiele:
#  Original: Seinem Biographen Martin Gilbert zufolge war der Vertrag, den Churchill mit der Zeitung aushandelte, wahrscheinlich der günstigste Vertrag, den überhaupt ein Kriegsberichterstatter bis dahin abgeschlossen hatte.
#  Vereinfacht: Churchills Vertrag mit der Zeitung war laut seines Biographen der beste Vertrag, den ein Kriegsberichterstatter je ausgehandelt hatte.
#
#  Original: Dem IPCC zufolge weisen von 29 436 Serien mit Beobachtungsdaten aus 75 Studien, die signifikante Veränderungen in physikalischen oder biologischen Systemen aufzeigen, 89 % mit den Erwartungen über eine erwärmte Welt übereinstimmende Veränderungen auf.
#  Vereinfacht: Laut dem IPCC zeigen 75 Studien deutliche Veränderungen in physikalischen und biologischen Systemen. 89% davon weisen eine globale Erwärmung nach.
#
#  Original: Aus den Ablagerungen von Sanden, Tonen und den Kalkgehäusen von Zooplankton in einem Urmeer entstanden zunächst Gesteine wie Sandstein, Schiefer und Kalkstein.
#  Vereinfacht: Aus den Sand-, Ton- und Kalkablagerungen in einem ehemaligen Meer entstanden zuerst Gesteine wie Sandstein, Schiefer und Kalkstein.
#
# Originaler Satz zu vereinfachen:
# "In den Wäldern leben Rehe, Wildschweine und Füchse, während die Wiesen und Felder Lebensraum für Vogelarten wie Rotkehlchen, Meisen und Bussarde bieten".
#  Vereinfacht:
# Response text:In den Wäldern leben Rehe, Wildschweine und Füchse, und die Wiesen und Felder sind Heimat für Vögel wie Rotkehlchen, Meisen und Bussarde.
#
#
# Simplified OG sentence: In den Wäldern leben Rehe, Wildschweine und Füchse, während die Wiesen und Felder Lebensraum für Vogelarten wie Rotkehlchen, Meisen und Bussarde bieten to In den Wäldern leben Rehe, Wildschweine und Füchse, und die Wiesen und Felder sind Heimat für Vögel wie Rotkehlchen, Meisen und Bussarde.
# ----------------------------
#
#
# Prompt:  Bitte schreibe den folgenden komplexen Satz um, um ihn für Nicht-Muttersprachler leichter verständlich zu machen. Du kannst dies tun, indem du Teile des Satzes umstellst, komplexe Wörter durch einfachere Synonyme ersetzt (d.h. umformulieren), unwichtige Informationen weglässt (d.h. komprimieren) und/oder einen langen, komplexen Satz in mehrere einfachere Sätze aufteilst. Der vereinfachte Satz muss grammatikalisch korrekt, fließend und verständlich sein und die Hauptideen des ursprünglichen Satzes beibehalten, ohne dessen Bedeutung zu verändern.
# Antworte ausschließlich und immer nur mit dem vereinfachten Satz, nichts weiter. Beginne die Antwort nicht mit einer Einleitung.
# Beispiele:
#  Original: Über die möglichen Folgen der Erwärmungen informieren auch die Unterartikel Folgen der globalen Erwärmung in Deutschland, Folgen der globalen Erwärmung in Europa, Folgen der globalen Erwärmung in der Arktis, Folgen der globalen Erwärmung in der Antarktis sowie Folgen der globalen Erwärmung für den Weinbau.
#  Vereinfacht: Weitere Unterartikel informieren über die Folgen der globalen Entwicklung in Deutschland, in Europa, der Arktis und für den Weinbau.
#
#  Original: Die Folgen dieser Versauerung betreffen zunächst kalkskelettbildende Lebewesen, deren Fähigkeit, sich Schutzhüllen bzw. Innenskelette zu bilden, bei sinkendem pH-Wert nachlässt.
#  Vereinfacht: Die Folgen dieser Versauerung betreffen zuerst Tiere mit Skeletten, die vor allem aus Kalk bestehen. Diese Tiere können bei sinkendem pH-Wert nicht mehr gut Schutzhüllen und Innenskelette bilden.
#
#  Original: Diese Erwartung wird im Zusammenhang mit der hohen Scheidungsrate, den sich ändernden Regelungen zum Unterhalt und der Diskussion um eventuelle Änderungen der Witwen-/Witwerrente in verstärktem Maß auch von der Gesellschaft an sie herangetragen.
#  Vereinfacht: Diese Erwartung wird noch durch die Gesellschaft verstärkt, da immer mehr Ehen geschieden werden und die Regelungen zum Unterhalt geändert wurden. Außerdem erhöht sich der Erwartungsdruck durch die Diskussion um die Änderungen der Witwen-/Witwerrente.
#
# Originaler Satz zu vereinfachen:
# "Die Schweiz ist auch Mitgründer des Internationalen Rhönradturn-Verbandes (IRV), welcher 1995 gegründet wurde und seinen Sitz in Bern hat.".
#  Vereinfacht:
# Response text:Die Schweiz ist Mitgründer des Internationalen Rhönradturn-Verbandes (IRV), der 1995 in Bern gegründet wurde.
#
#
# Simplified OG sentence: Die Schweiz ist auch Mitgründer des Internationalen Rhönradturn-Verbandes (IRV), welcher 1995 gegründet wurde und seinen Sitz in Bern hat. to Die Schweiz ist Mitgründer des Internationalen Rhönradturn-Verbandes (IRV), der 1995 in Bern gegründet wurde.
# ----------------------------
#
#
# Prompt:  Bitte schreibe den folgenden komplexen Satz um, um ihn für Nicht-Muttersprachler leichter verständlich zu machen. Du kannst dies tun, indem du Teile des Satzes umstellst, komplexe Wörter durch einfachere Synonyme ersetzt (d.h. umformulieren), unwichtige Informationen weglässt (d.h. komprimieren) und/oder einen langen, komplexen Satz in mehrere einfachere Sätze aufteilst. Der vereinfachte Satz muss grammatikalisch korrekt, fließend und verständlich sein und die Hauptideen des ursprünglichen Satzes beibehalten, ohne dessen Bedeutung zu verändern.
# Antworte ausschließlich und immer nur mit dem vereinfachten Satz, nichts weiter. Beginne die Antwort nicht mit einer Einleitung.
# Beispiele:
#  Original: Der seit dem Produktionsende der Grammophonplatten wesentlich geläufigere Begriff Schellackplatte grenzt diesen älteren Tonträger deutlich von der späteren Schallplatte aus Polyvinylchlorid ab.
#  Vereinfacht: Zum Produktionsende des Grammophons wurden die Tonträger Schellackplatten genannt.
# Damit wird die Bezeichnung der Schallplatten aus Polyvinylchlorid auch deutlich von den älteren Tonträgern abgegrenzt.
#
#  Original: Diese Erwartung wird im Zusammenhang mit der hohen Scheidungsrate, den sich ändernden Regelungen zum Unterhalt und der Diskussion um eventuelle Änderungen der Witwen-/Witwerrente in verstärktem Maß auch von der Gesellschaft an sie herangetragen.
# ...
# Antworte ausschließlich und immer nur mit dem vereinfachten Satz, nichts weiter. Beginne die Antwort nicht mit einer Einleitung.
# Beispiele:
#  Original: Dezember 2009 besitzt das Europäische Parlament im Bereich der Gemeinsamen Handelspolitik das Recht, Abänderungsvorschläge zu Gesetzesentwürfen einzubringen sowie auf Ablehnung des jeweiligen Rechtsaktes.
#  Vereinfacht: Seit dem 1.Dezember 2009 besitzt das Europäische Parlament in der gemeinsamen Handels-Politik das Recht, Vorschläge zur Änderung von Gesetzesentwürfen einzubringen. Außerdem kann das Parlament den jeweiligen Rechtsakt ablehnen.
#
#  Original: Deren Glaubwürdigkeit hätte ein gleichzeitiger Angriff der Flotte zunichtegemacht.
#  Vereinfacht: Ein Angriff der Flotte zu diesem Zeitpunkt hätte die Friedensverhandlungen sehr beeinträchtigt.
#
#  Original: Auch der Gesamtenergieverbrauch bei der Wiederaufbereitung wird vielfach überschätzt.
#  Vereinfacht: Viele überschätzen den Gesamtenergieverbrauch bei der Wiederaufbereitung.
#
# Originaler Satz zu vereinfachen:
# "Am Tag nach den gewalttätigen Ausbrüchen versammelten sich Einwohner, um die Spuren zu beseitigen; wieder einen Tag später fand ein kleiner Friedensmarsch statt.".
#  Vereinfacht:
# Response text:"Am Tag nach den gewalttätigen Vorfällen räumten die Einwohner auf. Einen Tag später gab es einen kleinen Friedensmarsch."
#
#
# Simplified OG sentence: Am Tag nach den gewalttätigen Ausbrüchen versammelten sich Einwohner, um die Spuren zu beseitigen; wieder einen Tag später fand ein kleiner Friedensmarsch statt. to Am Tag nach den gewalttätigen Vorfällen räumten die Einwohner auf. Einen Tag später gab es einen kleinen Friedensmarsch.
# ----------------------------
#
#
# Prompt:  Bitte schreibe den folgenden komplexen Satz um, um ihn für Nicht-Muttersprachler leichter verständlich zu machen. Du kannst dies tun, indem du Teile des Satzes umstellst, komplexe Wörter durch einfachere Synonyme ersetzt (d.h. umformulieren), unwichtige Informationen weglässt (d.h. komprimieren) und/oder einen langen, komplexen Satz in mehrere einfachere Sätze aufteilst. Der vereinfachte Satz muss grammatikalisch korrekt, fließend und verständlich sein und die Hauptideen des ursprünglichen Satzes beibehalten, ohne dessen Bedeutung zu verändern.
# Antworte ausschließlich und immer nur mit dem vereinfachten Satz, nichts weiter. Beginne die Antwort nicht mit einer Einleitung.
# Beispiele:
#  Original: Mehr als die erst bei wenigen ins Bewusstsein gedrungene Unionsbürgerschaft hat  bereits vor dem Euro  der Abbau der Grenzkontrollen und Grenzanlagen zwischen den Bürgern der am Schengener Abkommen beteiligten Mitgliedstaaten ein Gefühl europäischer Zusammengehörigkeit wecken können.
#  Vereinfacht: Der Abbau der Grenzkontrollen und Grenzanlagen hat zwischen den Bürgern der Mitgliedsstaaten vom Schengener Abkommen ein Gefühl europäischer Zusammengehörigkeit wecken können.
#
#  Original: Das Komitee zog eine posthume Vergabe in Betracht und prüfte sie.
#  Vereinfacht: Das Komitee überlegte, ihm noch nach seinem Tod den Preis zu verleihen.
#
#  Original: Bei einigen Automaten wurde die Greifhöhe abgesenkt; Tastatur und Ein/Ausgabe-Schächte befinden sich in einem geringeren Abstand zum Boden als bei Standardgeräten.
#  Vereinfacht: Einige Automaten wurden niedriger angebracht. Die Tastatur und alle anderen Elemente und sind jetzt besser erreichbar als normale Bankautomaten.
#
# Originaler Satz zu vereinfachen:
# "Der Tag wurde als Wendepunkt in der Entwicklung der Unruhen angesehen, jedoch noch nicht als das Ende dieser Vorkommnisse, zumal der relativ friedliche Verlauf dieses Tages möglicherweise hauptsächlich der Abschreckung durch die hohe Polizeipräsenz und durch die ersten Gefängnisstrafen, die für Gewalttäter verhängt worden waren, zu verdanken war.".
#  Vereinfacht:
# Response text:Der Tag wurde als Wendepunkt der Unruhen betrachtet, aber noch nicht als ihr Ende. Der friedliche Verlauf des Tages lag wahrscheinlich an der starken Polizeipräsenz und den ersten Gefängnisstrafen für Gewalttäter.
#
#
# Simplified OG sentence: Der Tag wurde als Wendepunkt in der Entwicklung der Unruhen angesehen, jedoch noch nicht als das Ende dieser Vorkommnisse, zumal der relativ friedliche Verlauf dieses Tages möglicherweise hauptsächlich der Abschreckung durch die hohe Polizeipräsenz und durch die ersten Gefängnisstrafen, die für Gewalttäter verhängt worden waren, zu verdanken war. to Der Tag wurde als Wendepunkt der Unruhen betrachtet, aber noch nicht als ihr Ende. Der friedliche Verlauf des Tages lag wahrscheinlich an der starken Polizeipräsenz und den ersten Gefängnisstrafen für Gewalttäter.
# ----------------------------
#
#
# Prompt:  Bitte schreibe den folgenden komplexen Satz um, um ihn für Nicht-Muttersprachler leichter verständlich zu machen. Du kannst dies tun, indem du Teile des Satzes umstellst, komplexe Wörter durch einfachere Synonyme ersetzt (d.h. umformulieren), unwichtige Informationen weglässt (d.h. komprimieren) und/oder einen langen, komplexen Satz in mehrere einfachere Sätze aufteilst. Der vereinfachte Satz muss grammatikalisch korrekt, fließend und verständlich sein und die Hauptideen des ursprünglichen Satzes beibehalten, ohne dessen Bedeutung zu verändern.
# Antworte ausschließlich und immer nur mit dem vereinfachten Satz, nichts weiter. Beginne die Antwort nicht mit einer Einleitung.
# Beispiele:
#  Original:
#  Vereinfacht: Man erwartet von einem Würfel, dass alle Ergebnisse gleich wahrscheinlich sind.
#
#  Original: Mittelalterliche Bildquellen zeigen sowohl glattrasierte Kleriker als auch solche mit Vollbärten.
#  Vereinfacht: Auf mittelalterlichen Bildern sieht man Geistliche mit und ohne Vollbart.
#
# Originaler Satz zu vereinfachen:
# "Als Reaktion auf die anhaltenden Unruhen veröffentlichten am 5. August mehrere Länder, darunter Australien, Nigeria und Indonesien, Reisewarnungen für das Vereinigte Königreich.".
#  Vereinfacht:
# Response text:Am 5. August gaben mehrere Länder, darunter Australien, Nigeria und Indonesien, wegen der Unruhen Reisewarnungen für das Vereinigte Königreich heraus.
#
#
# Simplified OG sentence: Als Reaktion auf die anhaltenden Unruhen veröffentlichten am 5. August mehrere Länder, darunter Australien, Nigeria und Indonesien, Reisewarnungen für das Vereinigte Königreich. to Am 5. August gaben mehrere Länder, darunter Australien, Nigeria und Indonesien, wegen der Unruhen Reisewarnungen für das Vereinigte Königreich heraus.
# ----------------------------
#
#
# Processed and saved dataset: wikiDE_OpenAI_simplified.csv
# {'wikiDE':                                      complex_sentence  \
#  0   Am 22. März 1985 unterzeichnete die Europäisch...
#  1   Im folgenden Jahr wurde die VERORDNUNG (EWG) N...
#  2   Zur Anpassung an die Änderungen des Montrealer...
#  3   Unternehmen müssen die Emissionen von geregelt...
#  4   Francesco Calzolari stammte aus einer alteinge...
#  5   Francescos kindliche Neugierde beschränkte sic...
#  6   Die Apotheke seines Vaters wurde auch von Gele...
#  7   Calzolari trat in die Fußstapfen seines Vaters...
#  8   Auch wenn ihn seine Arbeit als Apotheker davon...
#  9   Um den Monte Baldo noch näher zu sein, ließ si...
#  10  Es gilt als erstes und ältestes Naturkundemuse...
#  11  Diese kostete nur 20 Pfennig (ab 1871) und war...
#  12  Im Mittelalter lag südöstlich des heutigen Hof...
#  13  Nach der Auflösung der Garnison Weingarten nac...
#  14  In den Wäldern um Nessenreben findet man häufi...
#  15  In den Wäldern leben Rehe, Wildschweine und Fü...
#  16  Die Schweiz ist auch Mitgründer des Internatio...
#  17  Zusätzlich zu den drei Disziplinen wird im Lev...
#  18  An den vier Qualifikationswettkämpfen können s...
#  19  An der Schweizer Meisterschaft wird jeweils au...
#  20  Die Premiere der deutschen Produktion mit Vish...
#  21  Als der inhaftierten iranischen Menschenrechts...
#  22  Der ebenfalls in Teheran geborenene Majid Bakh...
#  23  Die Gumer kamen durch zwei Handelsunternehmen ...
#  24  Durch Einheirat waren die Gumer mit anderen al...
#  25  In Folge des Firmenkonkurses von 1799 und 1817...
#  26  Nach dem Bankrott des Handelshauses von Franz ...
#  27  Nach der österreichischen Rückeroberung Tirols...
#  28  Am 9. August 2024 stürzte das Flugzeug, eine A...
#  29  Im März 2024 wurde das Flugzeug durch einen Ta...
#  30  Das Flugzeug war laut VoePass „ohne betrieblic...
#  31  Die im Februar 2011 in den Systems Two Studios...
#  32  Das Album entstand als Tribut an den 2011 vers...
#  33  Dieses Projekt wurde bereits vor Motians Tod k...
#  35  Die Länge über Puffer von 21,72 Metern wurde v...
#  36  Die Wagen für den Fährverkehr nach Schweden un...
#  37  Die Gepäckwagen der Bauarten Pw4ü-28 und Pw4ü-...
#  38  Die Gasse wurde international bekannt, als im ...
#  39  Alle Gebäude der Corneliusgasse außer Haus Nr....
#  40  Viele Fans gingen nach der Absage zur Corneliu...
#  41  Die Unruhen im Vereinigten Königreich 2024 sin...
#  42  Er hat auch Inhalte verbreitet, die die britis...
#  43  Am 31. Juli 2024 kam es bei einer „Genug ist g...
#  44  Am 3. August 2024 wurden in ganz Deutschland 1...
#  45  Diese Stadt verlor zwischen 1975 und 1989 ein ...
#  46  Am Tag nach den gewalttätigen Vorfällen räumte...
#  47  Der Tag wurde als Wendepunkt der Unruhen betra...
#  48  Am 7. August 2024 gab es in Bristol eine Gegen...
#  49  Am 5. August gaben mehrere Länder, darunter Au...  }

# %% [markdown]
# ### LLama 3.1 (8bn)

# %%
# LLAMA simpler few shot prompt --> mention source in paper that similarly did this in a simpler fashion

smaller_main_prompt  = ( # inspired by BLESS paper -> which was inspired by Maddela et al. (2023) "LENS"
    "Please rewrite the following complex sentence in order to make it easier to understand by non-native speakers of English.\n",
    "Keep the meaning same, but make it simpler.\n",
    "Respond only and always with the simplified sentence, nothing else.\n",
    "Examples:\n"
)

smaller_main_prompt_DE = (
    "Bitte schreibe den folgenden komplexen Satz um, damit er für Nicht-Muttersprachler leichter verständlich wird.\n",
    "Behalte die Bedeutung bei, aber mache ihn einfacher.\n",
    "Antworte ausschließlich und immer nur mit dem vereinfachten Satz, nichts weiter.\n",
    "Beispiele:\n"
)

# %%
# Hint: Uses locally installed LLama model (with LM Studio)

from openai import OpenAI

LMstudio_client = OpenAI(
    base_url="http://localhost:1234/v1",
    api_key="lm-studio"
)

def generate_simplified_sentence_LLama(complex_sentence):

    prompt = generate_main_prompt(smaller_main_prompt)
    prompt += f"Original sentences to simplify:\n\"{complex_sentence}\".\n Simplified: "

    print("Prompt: ", prompt)
    
    response = LMstudio_client.chat.completions.create(
        model="someString", 
        messages=[
            {"role": "system", "content": "You are a helpful assistant."},
            {"role": "user", "content": "What is the capital of Paris?"},
        ])
    # Extract the simplified sentence from the response

    response_text = response.choices[0].message.content
    print("Response text:" + response_text) 
    simplified_sentence = response_text
    
    print(f"\n\nSimplified OG sentence: {complex_sentence} to {simplified_sentence}")
    print("----------------------------\n\n")

    return simplified_sentence

# %%
# Process all datasets with the LLama model and save them

run_model_on_multiple_datasets(
    model_function = generate_simplified_sentence_LLama, 
    datasets = datasets, 
    input_column = 'complex_sentence', 
    output_column = 'simplified_sentence', 
    save_dir = save_directory, 
    model_name = 'LLAMA31')
# Out:
# Prompt:  Please rewrite the following complex sentence in order to make it easier to understand by non-native speakers of English.
# Keep the meaning same, but make it simpler.
# Respond only and always with the simplified sentence, nothing else.
# Examples:
#  Original: The year 1976 saw Punk arrive on what some people perceived to be a stagnant music scene and NME, like other "specialist" publications, was slow to cover this new phenomenon.
#  Simplified: Punk arrived in 1976 on what was thought to be a stale music scene. NME was slow to cover this new situation.
#
#  Original: It is the fastest growing census division in Canada, expected to surpass 1.5 million residents by 2031.
#  Simplified: It is the fastest growing census division in Canada. It is expected to surpass 1.5 million residents by 2031.
#
#  Original: The BCG matrix (aka B. C. G. analysis, BCG-matrix, Boston Box, Boston Matrix, Boston Consulting Group analysis) is a chart that had been created by Bruce Henderson for the Boston Consulting Group in 1970 to help corporations with analyzing their business units or product lines.
#  Simplified: The BCG matrix is a chart that was made by Bruce Henderson for the Boston Consulting Group (BCG) in 1970 to help with analyzing business units or product lines.
#
# Original sentences to simplify:
# "The N1 road also designated as RN1, is a road in Central African Republic that spans a total distance of 498 kilometers.".
#  Simplified:
# {'model': 'llama3.1', 'created_at': '2024-08-14T15
# Response text: His actions forced the Chiricahua people to move to the San Carlos Apache Indian Reservation.
#
#
# ...
#  28  Acmispon tomentosus has one subspecies with bu...
#  29  Before becoming an actor, he hosted a TV show ...
#  30  Lin made his acting debut in the 2013 movie Ca...
#  31  In 2021, Lin got his first main male character...
#  32  He supervised the growth of the Duke Universit...
#  33  Breedlove was born in 1875 in North Carolina t...
#  34  Breedlove had to deal with a lot of donations ...
#  35   He was involved in planning three new libraries.
#  36  A major gift helped build a new library. It wa...
#  37  A house he built in 1915 at 407 Watts Street w...
#  38  National coach Alfred Gislason added Fischer t...
#  39  The squadron was initially a photo reconnaissa...
#  40  After being disbanded and reactivated, the squ...
#  41  The squadron celebrates its Golden Jubilee eve...
#  42  The unit started flying photos with small plan...
#  43  During the 1965 India-Pakistan war, the squadr...
#  44  After the war, No. 2 Squadron took over its as...
#  45  Grgić joined the extended Germany team in May ...
#  46  The presence of ancient remains at North Elmha...
#  47  Before joining the 1922 Mount Everest expediti...
#  48  He died in 1959, allegedly while playing crick...
#  49  The prominent Monaldeschi family had many pala...  ,
#  'cochrane':                                      complex_sentence  \
#  0   TEP technique may carry a higher risk of conve...
#  1   An inguinal hernia occurs when part of the int...
#  2   There may be little to no difference between T...
#  3   TEP technique may carry a higher risk of conve...
#  4   CBT may result in a small‐to‐moderate reductio...
#  5   However, compared to this benefit with CBT imm...
#  6   CBT may result in a reduction of comorbid depr...
#  7   There is not enough evidence to determine whet...
#  8   To assess the effects of Cognitive Behavioural...
#  9   Percutaneous and surgical interventions combin...
#  10  To evaluate the benefits and harms of preopera...
#  11  We included all randomised controlled trials (...
#  12  We excluded trials without a registered trial ...
#  13  Statins probably result in little to no differ...
#  14  Vitamin D supplementation during pregnancy may...
#  15  Selection criteria: Randomised and quasi‐rando...
#  16  The evidence is very uncertain about the effec...
#  17  Supplementation with vitamin D during pregnanc...
#  18  The evidence is very uncertain about the effec...
#  19  Feeding via a tube misplaced in the trachea ca...
#  20  The objective was to assess the diagnostic acc...
#  21  Based on limited evidence, ultrasound does not...
#  22  Our 2009 Cochrane review found that calcium ch...
#  23  Randomised controlled trials (RCTs) and quasi‐...
#  24  Compared to placebo or standard care alone, CC...
#  25  The effects of CCBs, ACEi or ARB compared to p...
#  26  For kidney transplant recipients, the use of C...
#  27  Cell transplantation offers a potential therap...
#  28  Normal pressure hydrocephalus (NPH) occurs whe...
#  29  It can occur after a clear brain injury such a...
#  30  Non‐randomised studies have shown a benefit fr...
#  31  CSF‐shunting probably improves gait speed at l...
#  32  CSF‐shunting may improve qualitative gait func...
#  33  The evidence is very uncertain about the effec...
#  34  Eczema (atopic dermatitis) is the most burdens...
#  35  The objective was to compare and rank the effi...
#  36  We included 291 studies involving 45,846 parti...
#  37  Treatment duration and trial participation wer...
#  38  NMA of 25 trials reporting skin thinning found...
#  39  The prevalence of tobacco use among people liv...
#  40  The objective was to assess the benefits, harm...
#  41  We included randomised controlled trials (RCTs...
#  42  We also included RCTs, quasi‐RCTs, other non‐r...
#  43  Low‐certainty evidence did not demonstrate a c...
#  44  Moderate‐certainty evidence suggested that var...
#  45  Low‐certainty evidence did not detect a differ...
#  46  No studies assessed SAEs for the following: be...
#  47  Repetitive transcranial magnetic stimulation (...
#  48  Current pharmacological and psychotherapeutic ...
#  49  The evidence is very uncertain about the effec...
#
#                               original_simple_sentence  \
#  0   If the TEP technique is used, there may be a h...
#  1   A groin hernia is a weakness or defect in the ...
#  2   The evidence suggests there may be little to n...
#  3   The evidence suggests that the risk of needing...
#  4   Evidence suggests that cognitive behavioural t...
#  5   However, the lessening in anxiety severity may...
#  6   We found that, compared to minimal management,...
#  7   Due to a lack of evidence, we do not know if C...
#  8   We wanted to find out whether CBT works better...
#  9   Percutaneous interventions plus albendazole or...
#  10  We wanted to find out whether taking statins b...
#  11  We searched for studies published up to Septem...
#  12  We only included trials that we were sure were...
#  13  In people undergoing cardiac surgery, compared...
#  14  Vitamin D supplementation during pregnancy may...
#  15  We searched for clinical trials (December 2022...
#  16  Overall, we are not sure if supplementation wi...
#  17  It may prevent severe excessive bleeding at bi...
#  18  Also, we are not sure if supplementation with ...
#  19  If the gastric tube is misplaced and food or m...
#  20  We wanted to determine the accuracy of ultraso...
#  21  Ultrasound alone was not sufficient for confir...
#  22  Angiotensin receptor blockers prevent the loss...
#  23  We searched for all trials that assess the ben...
#  24  A specific type of blood pressure treatment, c...
#  25  Other blood pressure treatments, including ang...
#  26  We are confident that calcium channel blockers...
#  27  Bone marrow‐derived cells have been investigat...
#  28  Normal pressure hydrocephalus (NPH) is a medic...
#  29  Sometimes there is a clear reason for the vent...
#  30  There have been reports of patients with iNPH ...
#  31  Walking speed probably improves with CSF‐shunt...
#  32  CSF‐shunting may improve walking function by a...
#  33  It is unclear if CSF‐shunt surgery has an effe...
#  34  Eczema (atopic dermatitis) is a common inflamm...
#  35  We wanted to find the most effective and also ...
#  36  We analysed 291 studies involving 45,846 peopl...
#  37  The studies lasted between seven days and five...
#  38  There was no evidence of increased skin thinni...
#  39  Smoking rates are about four times higher in p...
#  40  We wanted to find the best methods to help peo...
#  41  We searched for studies that investigated quit...
#  42  Also, studies on system change, aimed at peopl...
#  43  There was no clear evidence that behavioural s...
#  44  Varenicline likely helps people living with HI...
#  45  There are probably no more serious unwanted ef...
#  46  No studies assessed serious unwanted effects f...
#  47  rTMS is a non‐invasive treatment that involves...
#  48  Existing treatments are associated with high d...
#  49  It is unclear whether rTMS is associated with ...
#
#                                    simplified_sentence
#  0   Compared to TAPP technique and open surgery, T...
#  1   An inguinal hernia happens when part of the in...
#  2   There is little to no difference in outcomes b...
#  3   The TEP technique is more likely to need a dif...
#  4    CBT can slightly reduce anxiety after treatment.
#  5   There was little to no difference between CBT ...
#  6   CBT can reduce symptoms of depression after tr...
#  7   There isn't enough research to say if CBT work...
#  8   To compare how well cognitive behaviour therap...
#  9   Percutaneous and surgical treatments, along wi...
#  10  To compare the benefits and harms of taking st...
#  11  We looked at all studies that compared taking ...
#  12  We left out trials that didn't have a plan or ...
#  13  Statins make little or no difference in heart ...
#  14  Vitamin D supplements can help pregnant women ...
#  15  Trials that compare the effect of vitamin D, e...
#  16  Supplementing with vitamin D during pregnancy ...
#  17  Supplementing with vitamin D during pregnancy ...
#  18  The effect of vitamin D and calcium on preterm...
#  19  A tube that goes into the wrong part of the th...
#  20  The goal was to see how accurately ultrasound ...
#  21  Ultrasound doesn't accurately confirm gastric ...
#  22  Our 2009 Cochrane review showed that calcium c...
#  23  Trials testing medicines that lower blood pres...
#  24  CCBs probably reduce death and transplant fail...
#  25  The effects of CCBs, ACEi or ARB compared to a...
#  26  For patients getting a new kidney, taking CCB ...
#  27  Cell transplantation can help fix damaged hear...
#  28  NPH is a condition where the brain's fluid-fil...
#  29  It can happen after a head injury. It can also...
#  30  Surgically diverting ventricular fluid to a lo...
#  31  CSF-shunting likely helps patients walk faster...
#  32  CSF-shunting may slightly improve walking abil...
#  33  The evidence is unclear about how well CSF-shu...
#  34  Eczema is a common and difficult-to-cure skin ...
#  35  The goal was to compare and evaluate the best ...
#  36  We looked at 291 studies that involved over 45...
#  37  The treatment lasted a median of 21 days. Pati...
#  38  No study found that using any kind of topical ...
#  39  Tobacco use is much more common among people l...
#  40  The goal was to find out whether quitting smok...
#  41  We studied randomised controlled trials that h...
#  42  We also included studies like randomised contr...
#  43  Low-certainty evidence does not show that givi...
#  44  Varenicline seems to help people with HIV who ...
#  45  Low-certainty evidence found no difference bet...
#  46  No studies have looked at side effects for the...
#  47  A non-invasive therapy called rTMS involves se...
#  48  Current treatments for PTSD often don't work w...
#  49  The evidence is unclear about the effect of ac...  ,
#  'scotus':                                      complex_sentence  \
#  0   To determine whether Corner Post’s APA claim i...
#  1   While the Board argues that §2401(a) should no...
#  2   Importantly, contemporaneous dictionaries also...
#  3   The Board leaves open the possibility that som...
#  4   The APA provisions grant Corner Post a cause o...
#  5   Statutes of limitations ‘require plaintiffs to...
#  6   The Board’s interpretation would thereby decou...
#  7   The Board’s arguments to the contrary lack merit.
#  8   Departing from the traditional rule is particu...
#  9   While §702 equips injured parties with a cause...
#  10  This traditional rule constitutes a strong bac...
#  11  Notwithstanding Crown Coat’s holding, the Boar...
#  12  Absent vacatur, the remedy for a regulated pla...
#  13  The Government’s current position on vacatur w...
#  14  To decide the facial challenges here, the cour...
#  15  But that conclusion would rest on a serious mi...
#  16  That controversy sounds a familiar note: We ha...
#  17  The Court has repeatedly held that ordering a ...
#  18  From that slew of individual cases, three gene...
#  19  First, the First Amendment offers protection w...
#  20  The next order of business is to decide which ...
#  21  To ensure “the free exchange of ideas and info...
#  22  However, the law allows platforms to censor sp...
#  23  NetChoice contends that the Florida and Texas ...
#  24  Represented by sophisticated counsel, NetChoic...
#  25  The reasons that justify the President’s absol...
#  26  Appreciating the “unique risks” that arise whe...
#  27  In Fitzgerald, for instance, the Court conclud...
#  28  And he contended that a President has absolute...
#  29  We conclude that under our constitutional stru...
#  30  Following the analysis set forth in Granfinanc...
#  31  To determine whether a suit is legal in nature...
#  32  On that basis, this Court has repeatedly expla...
#  33  Sur veying English cases and considering the r...
#  34  When a debtor files for bankruptcy, it “create...
#  35  Under Chapter 11, the debtor must develop a re...
#  36  Section 1123(b) addresses the kinds of provisi...
#  37  Because provisions like the Sackler discharge ...
#  38  While paragraph (6) doubtlessly confers additi...
#  39  If a federal official accepts a bribe for an o...
#  40  In 1984, Congress passed and President Reagan ...
#  41  As amended, the text of §666 now closely resem...
#  42  The dividing line between §201(b)’s bribery pr...
#  43  The Government says that the statute would not...
#  44  Under the doctrine of consular nonreviewabilit...
#  45  Asencio-Cordero cannot invoke the exception hi...
#  46  Thus in United States ex rel. Knauff v. Shaugh...
#  47  The District Court granted summary judgment to...
#  48   Thus in Apprendi v. New Jersey, 530 U. S. 466...
#  49  But a sentencing procedure followed by a few S...
#
#                                    simplified_sentence
#  0   To determine if Corner Post's lawsuit is on ti...
#  1   The Board says §2401(a) shouldn't be applied i...
#  2   A cause of action accrues on the date of the i...
#  3   The Board says someone might still challenge a...
#  4   The APA provisions allow Corner Post to sue, b...
#  5   Statutes of limitations require plaintiffs to ...
#  6   For some lawsuits, but not all, the time limit...
#  7             The Board's arguments don't make sense.
#  8   Congress created special rules for 1948, and t...
#  9   While §702 gives injured parties a cause of ac...
#  10               This tradition is generally assumed.
#  11  Despite Crown Coat’s opinion being ignored, th...
#  12  Absent vacatur, the remedy for one party would...
#  13  The government's current position would effect...
#  14  The courts need to consider all possible appli...
#  15  But that conclusion would be based on a mistak...
#  16  Requiring a party to host someone else's views...
#  17  The Court has said that forcing one party to g...
#  18                     Three main points can be seen.
#  19  When a company compiles and organizes someone ...
#  20  We need to identify which of these laws confli...
#  21  To ensure that people can share their ideas fr...
#  22  The law lets platforms remove speech that brea...
#  23  They say these laws directly contradict the Fi...
#  24  NetChoice chose to challenge both laws, knowin...
#  25  The reasons why the President can't be prosecu...
#  26  The Court recognizes special protections for t...
#  27  The court said a former president can't be sue...
#  28  He believed that a President should be complet...
#  29  The former President should be immune from pro...
#  30  This action involves a Seventh Amendment issue...
#  31  Courts decide if a lawsuit is legitimate by se...
#  32  Based on this, the Court has said many times t...
#  33  The Court decided that fraud cases were "funda...
#  34  When a debtor goes bankrupt, they create an es...
#  35  The debtor must create a plan for how to distr...
#  36  A Chapter 11 plan can include certain types of...
#  37  Because provisions like the Sackler discharge ...
#  38  Paragraph 6 gives more powers to a bankruptcy ...
#  39  A government official who is paid to do someth...
#  40  In 1984, Congress passed a law that made it il...
#  41  It's now a crime for most state and local offi...
#  42  Bribery requires an official to have a corrupt...
#  43  The Government says it won't cover small or ha...
#  44  An executive officer's decision on whether to ...
#  45  Muñoz had to say that denying her husband's vi...
#  46  The Court reaffirmed that the US can keep out ...
#  47  The court initially ruled in favor of the gove...
#  48  The Court said in Apprendi v. New Jersey that ...
#  49  A sentencing procedure in some states doesn't ...  }

# %%
# GERMAN prompt building and execution

def generate_simplified_sentence_LLama_DE(complex_sentence):
   
    prompt = generate_main_prompt(smaller_main_prompt_DE, language="DE")
    prompt += f"Originaler Satz zu vereinfachen:\n\"{complex_sentence}\".\n Vereinfacht: "

    print("Prompt: ", prompt)
    
    response = LMstudio_client.chat.completions.create(
        model="someString", 
        messages=[
            {"role": "system", "content": "You are a helpful assistant."},
            {"role": "user", "content": "What is the capital of Paris?"},
        ])
    # Extract the simplified sentence from the response

    response_text = response.choices[0].message.content
    print("Response text:" + response_text) 
    simplified_sentence = response_text
    
    print(f"\n\nSimplified OG sentence: {complex_sentence} to {simplified_sentence}")
    print("----------------------------\n\n")

    return simplified_sentence

# %%
# GERMAN Execution

run_model_on_multiple_datasets(
    model_function = generate_simplified_sentence_LLama_DE, 
    datasets = datasets_DE, 
    input_column = 'complex_sentence', 
    output_column = 'simplified_sentence', 
    save_dir = save_directory, 
    model_name = 'LLAMA31')
# Out:
# Prompt:  Bitte schreibe den folgenden komplexen Satz um, um ihn für Nicht-Muttersprachler leichter verständlich zu machen. Du kannst dies tun, indem du Teile des Satzes umstellst, komplexe Wörter durch einfachere Synonyme ersetzt (d.h. umformulieren), unwichtige Informationen weglässt (d.h. komprimieren) und/oder einen langen, komplexen Satz in mehrere einfachere Sätze aufteilst. Der vereinfachte Satz muss grammatikalisch korrekt, fließend und verständlich sein und die Hauptideen des ursprünglichen Satzes beibehalten, ohne dessen Bedeutung zu verändern.
# Antworte ausschließlich und immer nur mit dem vereinfachten Satz, nichts weiter. Beginne die Antwort nicht mit einer Einleitung.
# Beispiele:
#  Original: Werden keine Maßnahmen zur Bekämpfung des Klimawandels getroffen, sind weltweit 16 % aller Arten vom Aussterben bedroht, wie eine 2015 in Science erschienene Übersichtsarbeit ergab.
#  Vereinfacht: Ohne  Maßnahmen zur Bekämpfung des Klimawandels sind weltweit 16 % aller Arten vom Aussterben bedroht. Dies ergab eine 2015 in Science erschienene Übersichtsarbeit.
#
#  Original: Studien belegen, dass die Frage, ob Kinder aus der Situation einen Nachteil oder auch einen Vorteil beziehen, nicht mit Ja oder Nein beantwortet werden kann: Die Wirkung der Berufstätigkeit auf das Kind hängt von Kontextfaktoren ab, insbesondere vom Berufskontext, von der Art der Verwendung von Zeit und Geld, von der Qualität der nichtelterlichen Kinderbetreuung und von der Zufriedenheit der Frau mit ihrer Rolle.
#  Vereinfacht: Studien zeigen, dass man nicht sagen kann, ob Kinder aus der Situation einen Nachteil oder Vorteil bekommen. Ob die Eltern arbeiten oder nicht wirkt auf das Kind immer unterschiedlich. Es hängt auch sehr von den Umständen ab. Die Umstände sind zum Beispiel der Beruf, die Verwendung von Zeit und Geld, die Qualität der Kinderbetreuung und davon, wie zufrieden die Frau mit ihrer Rolle ist.
#
#  Original: Der Flottenbefehl vom 24. Oktober 1918 und die Vorbereitungen zum Auslaufen lösten zunächst eine Meuterei unter den betroffenen Matrosen und dann eine allgemeine Revolution aus, die in wenigen Tagen die Monarchie im Reich beseitigte.
#  Vereinfacht: Am 24. Oktober 1918 brach durch den Flottenbefehl eine Meuterei unter den Matrosen aus. Die Meuterei wurde später zu einer Revolution, die in wenigen Tagen die Monarchie beseitigte.
#
# Originaler Satz zu vereinfachen:
# "Am 22. März 1985 unterzeichnete die Europäische Gemeinschaft gemeinsam mit mehreren Mitgliedstaaten das Wiener Übereinkommen zum Schutz der Ozonschicht und darauf folgend am 16. September 1987 auch das Montrealer Protokoll.".
#  Vereinfacht:
# {'model': 'llama3.1', 'created_at': '2024-08-17T08
# Response text: Die Europäische Gemeinschaft und einige ihrer Mitgliedsstaaten unterzeichneten 1985 ein Abkommen, um die Ozonschicht zu schützen. Darauf folgte 1987 noch ein weiteres Abkommen in Montreal.
#
#
# Simplified OG sentence: Am 22. März 1985 unterzeichnete die Europäische Gemeinschaft gemeinsam mit mehreren Mitgliedstaaten das Wiener Übereinkommen zum Schutz der Ozonschicht und darauf folgend am 16. September 1987 auch das Montrealer Protokoll. to Die Europäische Gemeinschaft und einige ihrer Mitgliedsstaaten unterzeichneten 1985 ein Abkommen, um die Ozonschicht zu schützen. Darauf folgte 1987 noch ein weiteres Abkommen in Montreal.
# ----------------------------
#
#
# Prompt:  Bitte schreibe den folgenden komplexen Satz um, um ihn für Nicht-Muttersprachler leichter verständlich zu machen. Du kannst dies tun, indem du Teile des Satzes umstellst, komplexe Wörter durch einfachere Synonyme ersetzt (d.h. umformulieren), unwichtige Informationen weglässt (d.h. komprimieren) und/oder einen langen, komplexen Satz in mehrere einfachere Sätze aufteilst. Der vereinfachte Satz muss grammatikalisch korrekt, fließend und verständlich sein und die Hauptideen des ursprünglichen Satzes beibehalten, ohne dessen Bedeutung zu verändern.
# Antworte ausschließlich und immer nur mit dem vereinfachten Satz, nichts weiter. Beginne die Antwort nicht mit einer Einleitung.
# Beispiele:
#  Original: Eine Seifenblase entsteht, wenn sich ein dünner Wasserfilm mit Seifenmolekülen vermischt.
#  Vereinfacht: Eine Seifenblase entsteht, wenn sich eine kleine Menge von Wasser (auch Wasserfilm genannt) mit einer kleinen Menge Seife mischt.
#
#  Original: Für den barrierefreien Zugang verfügen einige GAA über größere Tasten und Displays sowie über einen Kopfhöreranschluss oder Lautsprecher zur Sprachausgabe, um Menschen mit einer Sehbehinderung die Bedienung zu erleichtern oder überhaupt erst möglich zu machen.
#  Vereinfacht: Für den barrierefreien Zugang verfügen einige Automaten über große Tasten und Displays. Sie verfügen auch über einen Kopfhöreranschluss oder Lautsprecher zur Sprachausgabe. Dadurch ist es möglich, dass Menschen mit einer Sehbehinderung den Automaten bedienen können.
#
#  Original: Verwendung finden Würfel in Rollenspielen, bei denen sich in den letzten Jahrzehnten die Verwendung einer Vielzahl weiterer Würfel mit anderen Seitenzahlen durchgesetzt hat, um die Zufallsentscheidungen flexibler und vielfältiger zu gestalten.
#  Vereinfacht: Auch in Rollenspielen wird gewürfelt. In den letzten Jahren wurden dafür neue Würfel entwickelt. Sie haben mehr oder weniger Seiten als die klassischen Würfel. Dadurch werden die Spiele interessanter.
#
# Originaler Satz zu vereinfachen:
# "Im folgenden Jahr wurde die VERORDNUNG (EWG) Nr. 3322/88, als erste europäische Verordnung zur Regelung ozonschädigender Stoffe verabschiedet.".
#  Vereinfacht:
# {'model': 'llama3.1', 'created_at': '2024-08-17T08:42:03.699636Z', 'response': 'Mit der Verordnung Nr. 3322/88 wurde zum ersten Mal eine europäische Verordnung zur Regelung von Stoffen, die das Ozon schaden können, erlassen.', 'done': True, 'done_reason': 'stop', 'context': [128006, 882, 128007, 271, 87919, 5817, 265, 24459, 3453, 9630, 87053, 127338, 268, 13479, 89, 4543, 11, 4543, 41762, 7328, 87517, 5364, 74870, 652, 613, 1565, 73035, 261, 2807, 48735, 6915, 6529, 38996, 13, 16062, 66936, 8898, 11716, 11, 65389, 3930, 2722, 458, 951, 13479, 32893, 4543, 42237, 267, 11, 84869, 8536, 468, 9603, 466, 20350, 36423, 486, 24028, 7987, 68, 220, 45246, 11949, 320, 67, 870, 13, 4543, 630, 360, 16414, 705, 15375, 4970, 7404, 49942, 584, 6200, 2357, 52000, 320, 67, 870, 13, 11129, 18375, 16414, 8, 2073, 14, 4414, 15826, 8859, 268, 11, 127338, 268, 13479, 89, 304, 19028, 486, 36423, 486, 328, 90593, 7367, 668, 19839, 13, 13031, 74043, 13885, 85742, 13479, 89, 36241, 23882, 8637, 88560, 16438, 33054, 265, 5964, 11, 1344, 648, 8156, 408, 2073, 2807, 48735, 6915, 19910, 2073, 2815, 473, 2933, 47309, 268, 951, 220, 1759, 67793, 983, 22412, 13479, 32893, 387, 581, 2701, 60593, 11, 29983, 21273, 268, 13394, 61153, 2234, 6529, 2807, 58496, 77, 627, 17555, 86, 16977, 25102, 331, 84190, 2073, 26612, 12500, 5568, 2486, 74043, 13885, 54876, 13479, 89, 11, 60865, 31732, 13, 19110, 818, 2815, 66854, 8969, 5568, 17495, 18560, 75562, 627, 3513, 13391, 25641, 512, 17674, 25, 52410, 1369, 56439, 2067, 521, 1218, 5455, 427, 11, 22850, 9267, 4466, 102963, 1215, 74894, 31255, 5568, 1369, 56439, 76, 1286, 103594, 2963, 2807, 34965, 14244, 627, 69932, 13885, 16317, 25, 52410, 1369, 56439, 2067, 521, 1218, 5455, 427, 11, 22850, 9267, 10021, 54655, 386, 6443, 6675, 74894, 320, 64, 1412, 74894, 31255, 4173, 94439, 8, 5568, 17495, 81478, 386, 6443, 1369, 1643, 5906, 14244, 382, 17674, 25, 46581, 3453, 3703, 85567, 25746, 3675, 77816, 526, 2807, 31266, 4469, 64720, 480, 6157, 14104, 75639, 486, 350, 561, 268, 2073, 50706, 40407,
, 1263, 23190, 12666, 10942, 10775, 51195, 45956, 6375, 1141, 69, 15184, 52821, 16419, 2009, 84314, 784, 403, 1297, 74561, 15165, 627, 69932, 13885, 16317, 25, 74607, 637, 97389, 21865, 6127, 2815, 11246, 83036, 797, 2234, 7367, 17901, 74607, 637, 329, 13, 2418, 76118, 11168, 21254, 98022, 12666, 7367, 5817, 906, 3213, 16438, 31298, 1073, 21865, 54897, 13, 74607, 637, 97389, 21865, 42952, 265, 20938, 2815, 6383, 67771, 6675, 74607, 637, 31975, 944, 737, 6383, 82212, 2073, 10942, 18707, 472, 13, 2418, 16095, 74607, 637, 97389, 21865, 304, 2761, 7730, 553, 275, 11, 17761, 9939, 40516, 2234, 2761, 21031, 1263, 23190, 12666, 10942, 18707, 472, 1297, 61422, 382, 18902, 261, 13479, 89, 6529, 74043, 13885, 46799, 512, 1, 20863, 261, 38160, 48927, 2815, 469, 2796, 268, 6675, 67387, 29952, 2002, 800, 1885, 268, 304, 2815, 24218, 86, 3903, 2807 ...
# Response text: Unternehmen müssen die Schadstoffe, die sie freisetzen, minimieren oder ganz vermeiden.
#
#
# Simplified OG sentence: Unternehmen müssen die Emissionen von geregelten Stoffen in die Umwelt verhindern oder auf ein Mindestmaß reduzieren. to Unternehmen müssen die Schadstoffe, die sie freisetzen, minimieren oder ganz vermeiden.
# ----------------------------
#
#
# Prompt:  Bitte schreibe den folgenden komplexen Satz um, um ihn für Nicht-Muttersprachler leichter verständlich zu machen. Du kannst dies tun, indem du Teile des Satzes umstellst, komplexe Wörter durch einfachere Synonyme ersetzt (d.h. umformulieren), unwichtige Informationen weglässt (d.h. komprimieren) und/oder einen langen, komplexen Satz in mehrere einfachere Sätze aufteilst. Der vereinfachte Satz muss grammatikalisch korrekt, fließend und verständlich sein und die Hauptideen des ursprünglichen Satzes beibehalten, ohne dessen Bedeutung zu verändern.
# Antworte ausschließlich und immer nur mit dem vereinfachten Satz, nichts weiter. Beginne die Antwort nicht mit einer Einleitung.
# Beispiele:
#  Original: Allerdings wurde das Rasieren nicht durchgängig einheitlich gehandhabt.
#  Vereinfacht: Allerdings wurde nicht immer auf gleiche Art rasiert.
#
#  Original: Kryokonit ist ein dunkler biogener Oberflächenstaub auf Schnee und Eis, der durch Winde in der Atmosphäre über weite Strecken transportiert wird und gewöhnlich auf Gletschern weltweit zu beobachten ist.
#  Vereinfacht: Kryokonit ist ein dunkler organischer Staub auf Schnee und Eis. Der Staub wird durch Winde in der Atmosphäre über weite Strecken transportiert. Man kann den Staub meistens auf Gletschern sehen.
#
#  Original: Um laute Aufprallgeräusche und ein Wegrollen der Würfel zu vermeiden, wird manchmal ein gepolstertes und berandetes Brett (Würfelbrett oder Würfelteller genannt) eingesetzt.
#  Vereinfacht: Damit die Würfel nicht laut aufprallen und wegrollen wird manchmal ein gepolstertes Brett mit Rand eingesetzt. Dieses Brett nennt man Würfelbrett oder Würfelteller.
#
# Originaler Satz zu vereinfachen:
# "Francesco Calzolari stammte aus einer alteingesessenen Veroneser Familie, die sich bereits im 13. Jahrhundert unter Ezzelino da Romano einen Namen gemacht hatte.".
#  Vereinfacht:
# {'model': 'llama3.1', 'created_at': '2024-08-17T08:42:30.478763Z', 'response': 'Francesco Calzolari kam aus einer alten Familie in Verona. Seine Familie war schon im 13. Jahrhundert bekannt, weil sie dem italienischen Herrscher Ezzelino da Romano geholfen hatte.', 'done': True, 'done_reason': 'stop', 'context': [128006, 882, 128007, 271, 87919, 5817, 265, 24459, 3453, 9630, 87053, 127338, 268, 13479, 89, 4543, 11, 4543, 41762, 7328, 87517, 5364, 74870, 652, 613, 1565, 73035, 261, 2807, 48735, 6915, 6529, 38996, 13, 16062, 66936, 8898, 11716, 11, 65389, 3930, 2722, 458, 951, 13479, 32893, 4543, 42237, 267, 11, 84869, 8536, 468, 9603, 466, 20350, 36423, 486, 24028, 7987, 68, 220, 45246, 11949, 320, 67, 870, 13, 4543, 630, 360, 16414, 705, 15375, 4970, 7404, 49942, 584, 6200, 2357, 52000, 320, 67, 870, 13, 11129, 18375, 16414, 8, 2073, 14, 4414, 15826, 8859, 268, 11, 127338, 268, 13479, 89, 304, 19028, 486, 36423, 486, 328, 90593, 7367, 668, 19839, 13, 13031, 74043, 13885, 85742, 13479, 89, 36241, 23882, 8637, 88560, 16438, 33054, 265, 5964, 11, 1344, 648, 8156, 408, 2073, 2807, 48735, 6915, 19910, 2073, 2815, 473, 2933, 47309, 268, 951, 220, 1759, 67793, 983, 22412, 13479, 32893, 387, 581, 2701, 60593, 11, 29983, 21273, 268, 13394, 61153, 2234, 6529, 2807, 58496, 77, 627, 17555, 86, 16977, 25102, 331, 84190, 2073, 26612, 12500, 5568, 2486, 74043, 13885, 54876, 13479, 89, 11, 60865, 31732, 13, 19110, 818, 2815, 66854, 8969, 5568, 17495, 18560, 75562, 627, 3513, 13391, 25641, 512, 17674, 25, 2052, 69727, 27201, 6754, 59130, 16414, 8969, 20350, 70, 26498, 343, 4466, 23190, 6915, 30795, 438, 10796, 83, 627, 69932, 13885, 16317, 25, 2052, 69727, 27201, 8969, 26612, 7367, 30103, 12333, 5277, 436, 10426, 531, 382, 17674, 25, 735, 894, 564, 263, 275, 6127, 4466, 64572, 1565, 6160, 540, 804, 52245, 1517, 2357, 7674
5568, 17495, 81478, 386, 6443, 1369, 1643, 5906, 14244, 382, 18902, 261, 13479, 89, 6529, 74043, 13885, 46799, 512, 1, 18674, 5345, 78, 1820, 441, 513, 1572, 650, 11796, 27201, 11168, 6675, 4323, 273, 4171, 2002, 7367, 4282, 33130, 11, 2815, 53534, 35849, 60430, 11856, 2073, 9939, 2779, 406, 77, 15760, 100206, 12119, 43988, 2073, 2815, 15826, 37952, 59026, 20468, 18560, 1517, 1892, 7367, 3453, 7367, 38385, 101458, 2002, 11, 503, 11856, 89699, 3400, 89, 337, 2850, 9608, 109463, 2002, 1210, 627, 69932, 13885, 16317, 25, 220, 128009, 128006, 78191, 128007, 271, 644, 2761, 5345, 78, 1 ...
# Response text: In der Apotheke seines Vaters trafen sich Gelehrte. Sie teilten ihre Gedanken und Entdeckungen mit einander und hatten großen Einfluss auf den jungen Francesco Calzolari.
#
#
# Simplified OG sentence: Die Apotheke seines Vaters wurde auch von Gelehrten aufgesucht, die dort ihre Meinungen und Erkenntnisse austauschten und die einen entscheidenden Einfluss auf den aufgeweckten, jungen Francesco Calzolari ausübten. to In der Apotheke seines Vaters trafen sich Gelehrte. Sie teilten ihre Gedanken und Entdeckungen mit einander und hatten großen Einfluss auf den jungen Francesco Calzolari.
# ----------------------------
#
#
# ...
# Response text: In der britischen Stadt Bristol fand ein Protest gegen einen vorherigen Aufstand statt.
#
#
# Simplified OG sentence: Auch in Bristol, das einige Tage zuvor Schauplatz gewalttätiger Aktionen gewesen war, fand am 7. August 2024 eine Gegendemonstration statt. to In der britischen Stadt Bristol fand ein Protest gegen einen vorherigen Aufstand statt.
# ----------------------------
#
#
# Prompt:  Bitte schreibe den folgenden komplexen Satz um, um ihn für Nicht-Muttersprachler leichter verständlich zu machen. Du kannst dies tun, indem du Teile des Satzes umstellst, komplexe Wörter durch einfachere Synonyme ersetzt (d.h. umformulieren), unwichtige Informationen weglässt (d.h. komprimieren) und/oder einen langen, komplexen Satz in mehrere einfachere Sätze aufteilst. Der vereinfachte Satz muss grammatikalisch korrekt, fließend und verständlich sein und die Hauptideen des ursprünglichen Satzes beibehalten, ohne dessen Bedeutung zu verändern.
# Antworte ausschließlich und immer nur mit dem vereinfachten Satz, nichts weiter. Beginne die Antwort nicht mit einer Einleitung.
# Beispiele:
#  Original: Dieser Berührungspunkt kann insbesondere daher problematisch werden, da das menschliche Becken mit seinen Sitzbeinhöckern und dem Schambein (bzw. den Schambeinkufen, auch Schambeinkamm genannt) durch den Kippwinkel des Beckens Auswirkungen auf die Biegung der gesamten Wirbelsäule hat.
#  Vereinfacht: Das menschliche Becken besitzt Sitzbeinhöcker und Schambein bzw. Schambeinkufen (auch Schambeinkamm genannt), die beim Fahrradfahren gekippt werden. Dieser Kippwinkel hat Auswirkungen auf die Biegung der gesamten Wirbelsäule. Deshalb kann dieser Berührungspunkt problematisch sein.
#
# Response text: Mehrere Länder wie Australien, Nigeria und Indonesien haben am 5. August Reisewarnungen für das Vereinigte Königreich ausgegeben.
#
#
# Simplified OG sentence: Als Reaktion auf die anhaltenden Unruhen veröffentlichten am 5. August mehrere Länder, darunter Australien, Nigeria und Indonesien, Reisewarnungen für das Vereinigte Königreich. to Mehrere Länder wie Australien, Nigeria und Indonesien haben am 5. August Reisewarnungen für das Vereinigte Königreich ausgegeben.
# ----------------------------
#
#
# Processed and saved dataset: wikiDE_LLAMA31_simplified.csv
# {'wikiDE':                                      complex_sentence  \
#  0   Am 22. März 1985 unterzeichnete die Europäisch...
#  1   Im folgenden Jahr wurde die VERORDNUNG (EWG) N...
#  2   Zur Anpassung an die Änderungen des Montrealer...
#  3   Unternehmen müssen die Emissionen von geregelt...
#  4   Francesco Calzolari stammte aus einer alteinge...
#  5   Francescos kindliche Neugierde beschränkte sic...
#  6   Die Apotheke seines Vaters wurde auch von Gele...
#  7   Calzolari trat in die Fußstapfen seines Vaters...
#  8   Auch wenn ihn seine Arbeit als Apotheker davon...
#  9   Um den Monte Baldo noch näher zu sein, ließ si...
#  10  Es gilt als erstes und ältestes Naturkundemuse...
#  11  Diese kostete nur 20 Pfennig (ab 1871) und war...
#  12  Im Mittelalter lag südöstlich des heutigen Hof...
#  13  Nach der Auflösung der Garnison Weingarten nac...
#  14  In den Wäldern um Nessenreben findet man häufi...
#  15  In den Wäldern leben Rehe, Wildschweine und Fü...
#  16  Die Schweiz ist auch Mitgründer des Internatio...
#  17  Zusätzlich zu den drei Disziplinen wird im Lev...
#  18  An den vier Qualifikationswettkämpfen können s...
#  19  An der Schweizer Meisterschaft wird jeweils au...
#  20  Die Premiere der deutschen Produktion mit Vish...
#  21  Als der inhaftierten iranischen Menschenrechts...
#  22  Der ebenfalls in Teheran geborenene Majid Bakh...
#  23  Die Gumer kamen durch zwei Handelsunternehmen ...
#  24  Durch Einheirat waren die Gumer mit anderen al...
#  25  In Folge des Firmenkonkurses von 1799 und 1817...
#  26  Nach dem Bankrott des Handelshauses von Franz ...
#  27  Nach der österreichischen Rückeroberung Tirols...
#  28  Am 9. August 2024 stürzte das Flugzeug, eine A...
#  29  Im März 2024 wurde das Flugzeug durch einen Ta...
#  30  Das Flugzeug war laut VoePass „ohne betrieblic...
#  31  Die im Februar 2011 in den Systems Two Studios...
#  32  Das Album entstand als Tribut an den 2011 vers...
#  33  Dieses Projekt wurde bereits vor Motians Tod k...
#  34  Einheits-Schnellzugwagen Bauart 28 sind eine S...
#  35  Von der Vorläuferbauart wurde auch die Länge ü...
#  36  Die für den Fährverkehr nach Schweden und Däne...
#  37  Die Gepäckwagen der Bauarten Pw4ü-28 und Pw4ü-...
#  38  Internationale Aufmerksamkeit erhielt die Gass...
#  39  Alle Gebäude der Corneliusgasse (bis auf Haus ...
#  40  Viele Fans suchten nach der Absage, etwa um Tr...
#  41  Die Unruhen im Vereinigten Königreich 2024 sin...
#  42  Ebenso beteiligte er sich an der Verbreitung v...
#  43  Am 31. Juli 2024 kam es bei einer Demonstratio...
#  44  Alleine am 3. August 2024 wurden landesweit 14...
#  45  Diese Stadt hatte durch den Niedergang des Koh...
#  46  Am Tag nach den gewalttätigen Ausbrüchen versa...
#  47  Der Tag wurde als Wendepunkt in der Entwicklun...
#  48  Auch in Bristol, das einige Tage zuvor Schaupl...
#  49  Als Reaktion auf die anhaltenden Unruhen veröf...
#
#                                    simplified_sentence
#  0   Die Europäische Gemeinschaft und einige ihrer ...
#  1   Mit der Verordnung Nr. 3322/88 wurde zum erste...
#  2   Die EU änderte ihr Montrealer Protokoll mehrma...
#  3   Unternehmen müssen die Schadstoffe, die sie fr...
#  4   Francesco Calzolari kam aus einer alten Famili...
#  5   Francesco war sehr neugierig. Er interessierte...
#  6   In der Apotheke seines Vaters trafen sich Gele...
#  7   Nachdem sein Vater aus dem Geschäft ausgestieg...
#  8   Trotz seiner Arbeit als Apotheker hatte er vie...
#  9   Calzolari ließ sich in Rivoli Veronese ein Hau...
#  10  Es ist das erste Naturkundemuseum der Welt. Es...
#  11  Diese Buchserie war sehr billig, nämlich nur 2...
#  12  Südöstlich vom heutigen Hofgut stand im Mittel...
#  13  Nach dem Ersten Weltkrieg richtete die Stadt W...
#  14  In den Wäldern um Nessenreben wachsen häufig B...
#  15  In den Wäldern leben Rehe, Wildschweine und Fü...
#  16  Die Schweiz ist ein Gründungsmitglied der Firm...
#  17  Im Level Elite gibt es zusätzlich einen Mehrka...
#  18  Die besten Turner und Turnerinnen qualifiziere...
#  19  Die Schweizer Meisterschaft bestimmt, welche A...
#  20  Vishka Asayesh soll im September 2024 bei dem ...
#  21  Maryam, eine iranische Menschenrechtsaktivisti...
#  22  Majid Bakhtiari, der auch in Filmen wie "Rhein...
#  23  Durch Handel wurden die Gumer reich und zählte...
#  24  Die Familie Gumer war durch Heiraten mit ander...
#  25  In den Jahren 1799 und 1817 verloren die Gumer...
#  26  Nach dem Bankrott der Familie Gumer verloren s...
#  27  Nachdem Österreich Tirol wieder zurückerobert ...
#  28  Das Flugzeug stürzte am 9. August 2024 nordwes...
#  29  Am 9. Juli war ein Flugzeug endlich wieder vol...
#  30  Laut dem Unternehmen VoePass war das Flugzeug ...
#  31  Im Jahr 2011 wurden die Songs in einem Studio ...
#  32  Das Album wurde als Tribute an den 2011 versto...
#  33  Das Projekt wurde erst nach dem Tod des Musike...
#  34  Die Deutsche Reichsbahn-Gesellschaft beschafft...
#  35  Die neue Bauart hatte ein Längen von 21,72 Met...
#  36  Die Wagen für die Fähre nach Schweden und Däne...
#  37  Die beiden Züge hatten die gleichen Funktionen...
#  38  Im August 2024 musste Taylor Swift ihre Konzer...
#  39  Das Gebiet der Corneliusgasse ist durch eine S...
#  40  Nach der Absage suchten viele Fans nach Trost....
#  41  Im Vereinigten Königreich gibt es aktuell Unru...
#  42  Er verbreitete Inhalte, die zur Spaltung der b...
#  43  Es gab eine Demonstration in London mit dem Mo...
#  44  Am 3. August 2024 wurden in dem Land 147 Mensc...
#  45  Zwischen 1975 und 1989 ging die Stadt aufgrund...
#  46  Die Bürger sammelten sich, um die Schäden zu b...
#  47  Der Tag wurde als Wende in den Unruhen gesehen...
#  48  In der britischen Stadt Bristol fand ein Prote...
#  49  Mehrere Länder wie Australien, Nigeria und Ind...  }

# %% [markdown]
# ### MUSS
#
# RUN FILE WITH FOLLOWING COMMAND:
# python scripts/simplify.py scripts/examples.en --model-name "muss_en_wikilarge_mined"

# %%
# Export data to file for processing by MUSS

MUSS_export_dir = "../data/MUSS_inputs"

def export_complex_sentences(datasets, export_directory):
    os.makedirs(export_directory, exist_ok=True)
    
    for dataset_name, dataset in datasets.items():
        filename = f"{dataset_name}_complex_sentences.txt"
        file_path = os.path.join(export_directory, filename)
        
        with open(file_path, 'w', encoding='utf-8') as f:
            for sentence in dataset['complex_sentence']:
                f.write(f"{sentence}\n")
        
        print(f"Exported complex sentences for {dataset_name} to {file_path}")

export_complex_sentences(datasets, MUSS_export_dir)
# Out:
# Exported complex sentences for wikiEN to ../data/MUSS_inputs/wikiEN_complex_sentences.txt
# Exported complex sentences for cochrane to ../data/MUSS_inputs/cochrane_complex_sentences.txt
# Exported complex sentences for scotus to ../data/MUSS_inputs/scotus_complex_sentences.txt

# %%
# 1. Paste the exported data file into the MUSS Input folder

# 2. Run commands in terminal in dedicated env (py38muss):

# conda activate py38muss

# python scripts/simplify.py FOLDER/cochrane_complex_sentences.txt --model-name "muss_en_wikilarge_mined"
# python scripts/simplify.py FOLDER/wikiEN_complex_sentences.txt --model-name "muss_en_wikilarge_mined"
# python scripts/simplify.py FOLDER/scotus_complex_sentences.txt --model-name "muss_en_wikilarge_mined"

# python scripts/simplify.py FOLDER/FILENAME --model-name "muss_en_wikilarge_mined"

# Copy the simplified sentences from the MUSS_system_output folder back to the TS data folder and name accordingly

# %% [markdown]
# ### mBART DE (similar to MUSS; for German)
#
# https://huggingface.co/DEplain/trimmed_mbart_sents_apa_web

# %%
# Load model
tokenizer = AutoTokenizer.from_pretrained("DEplain/trimmed_mbart_sents_apa_web",  use_fast=False)
model = AutoModelForSeq2SeqLM.from_pretrained("DEplain/trimmed_mbart_sents_apa_web")

# %%
def run_mBART_on_sentence(sentence): 
    # Tokenize and generate output
    print("Komplexer Satz: " + sentence)
    inputs = tokenizer(sentence, return_tensors="pt")
    outputs = model.generate(**inputs)
    simplified_sentence = tokenizer.decode(outputs[0], skip_special_tokens=True)
    print("Simpler Satz: " + simplified_sentence + "\n")
    
    return simplified_sentence

# %%
run_mBART_on_sentence("Dies ist ein komplexer Satz, den ich, sofern möglich und irgendwie machbar, vereinfachen möchte.")
# Out:
# Komplexer Satz: Dies ist ein komplexer Satz, den ich, sofern möglich und irgendwie machbar, vereinfachen möchte.
# Simpler Satz: Dies ist ein komplexer Satz, den ich vereinfachen möchte.
# 'Dies ist ein komplexer Satz, den ich vereinfachen möchte.'

# %%
run_model_on_multiple_datasets(
    model_function = run_mBART_on_sentence, 
    datasets = datasets_DE, 
    input_column = 'complex_sentence', 
    output_column = 'simplified_sentence', 
    save_dir = save_directory, 
    model_name = 'mBART_DE')
# Out:
# Komplexer Satz: Am 22. März 1985 unterzeichnete die Europäische Gemeinschaft gemeinsam mit mehreren Mitgliedstaaten das Wiener Übereinkommen zum Schutz der Ozonschicht und darauf folgend am 16. September 1987 auch das Montrealer Protokoll.
# Simpler Satz: Am 22. März 1985 unterzeichnete die Europäische Gemeinschaft das Wiener Übereinkommen zum Schutz der Ozonschicht.
#
# Komplexer Satz: Im folgenden Jahr wurde die VERORDNUNG (EWG) Nr. 3322/88, als erste europäische Verordnung zur Regelung ozonschädigender Stoffe verabschiedet.
# Simpler Satz: Im Jahr 2020 wurde die Verordnung zur Regelung ozonschädigender Stoffe verabschiedet.
#
# Komplexer Satz: Zur Anpassung an die Änderungen des Montrealer Protokolls wurden durch nachfolgende Verordnungen die geregelten Substanzen immer weiter ergänzt und Ein- und Ausfuhr, Produktion und Verwendung weiter eingeschränkt, Fristen verkürzt und Substanzen letztendlich verboten.
# Simpler Satz: Zur Anpassung an die Änderungen des Montrealer Protokolls wurden die geregelten Substanzen immer weiter eingeschränkt. Außerdem wurden Fristen verkürzt und Substanzen letztendlich verboten.
#
# Komplexer Satz: Unternehmen müssen die Emissionen von geregelten Stoffen in die Umwelt verhindern oder auf ein Mindestmaß reduzieren.
# Simpler Satz: Die Firmen müssen die Emissionen von geregelten Stoffen in die Umwelt verhindern.
#
# Komplexer Satz: Francesco Calzolari stammte aus einer alteingesessenen Veroneser Familie, die sich bereits im 13. Jahrhundert unter Ezzelino da Romano einen Namen gemacht hatte.
# Simpler Satz: Im 13. Jahrhundert wurde er von einer Veroneser Familie gezüchtet.
#
# Komplexer Satz: Francescos kindliche Neugierde beschränkte sich aber nicht nur auf die Botanik, auch Mineralien, Fossilien, und Insekten weckten sein Interesse, die er bei seinen Wanderungen mit seinem Vater sammelte.
# Simpler Satz: Der Bub sammelte nämlich Mineralien, Fossilien, Insekten und Insekten, die er bei seinen Wanderungen mit seinem Vater sammelte.
#
# Komplexer Satz: Die Apotheke seines Vaters wurde auch von Gelehrten aufgesucht, die dort ihre Meinungen und Erkenntnisse austauschten und die einen entscheidenden Einfluss auf den aufgeweckten, jungen Francesco Calzolari ausübten.
# Simpler Satz: Die Apotheke seines Vaters wurde auch von Gelehrten aufgesucht, die dort ihre Meinungen und Erkenntnisse tauschten.
#
# Komplexer Satz: Calzolari trat in die Fußstapfen seines Vaters und widmete sich mit Hingabe seiner Arbeit in der Apotheke, deren Leitung er übernahm.
# Simpler Satz: Die Arbeit in der Apotheke wurde ihm von seinem Vater übernahm.
#
# Komplexer Satz: Auch wenn ihn seine Arbeit als Apotheker davon abhielt, viel zu verreisen, unterhielt er ganze Reihe von Briefkontakten, unter anderem mit dem Züricher Botaniker Conrad Gessner und dem Nürnberger Arzt und Botaniker Joachim Camerarius dem Jüngeren.
# Simpler Satz: Auch wenn ihn seine Arbeit als Apotheker davon abhielt, viel zu verreisen, unterhielt er ganze Reihe von Briefkontakten mit den Jüngeren.
#
# Komplexer Satz: Um den Monte Baldo noch näher zu sein, ließ sich Calzolari in Rivoli Veronese am südlichen Rand der Bergkette ein Landhaus errichten.
# Simpler Satz: In Rivoli Veronese am südlichen Rand von der Bergkette konnte man ein Landhaus errichten.
#
# Komplexer Satz: Es gilt als erstes und ältestes Naturkundemuseum der Welt und ist erstmals 1554 dokumentiert, als Aldrovandi das von ihm als Naturae Theatrum beschriebene Museum besuchte.
# Simpler Satz: Das Museum gilt als erstes und ältestes Naturkunde-Museum der Welt. Es wurde erstmals 1554 Mal besucht.
#
# Komplexer Satz: Diese kostete nur 20 Pfennig (ab 1871) und war damit die billigste und auflagenstärkste deutsche Buchreihe.
# Simpler Satz: Diese Buchreihe kostete nur 20 Pfennig (ab 1871) und war damit die billigste und auflagenstärkste deutsche Buchreihe.
#
# Komplexer Satz: Im Mittelalter lag südöstlich des heutigen Hofguts eine Burg, von der heute nur noch der Burgstall erhalten ist.
# Simpler Satz: Im Mittelalter lag südöstlich des heutigen Hofguts eine Burg. Von der Burg ist heute nur noch der Burgstall erhalten.
#
# Komplexer Satz: Nach der Auflösung der Garnison Weingarten nach Beendigung des Ersten Weltkriegs wurde am oberen Froschweiher das städtische Freibad eingerichtet, dessen Vorläufer sich in der Nähe der Wileneggstrasse in Weingarten befanden.
# Simpler Satz: Nach der Auflösung der Garnison Weingarten nach Beendigung des Ersten Weltkriegs wurde am oberen Froschweiher das Freibad eingerichtet.
#
# Komplexer Satz: In den Wäldern um Nessenreben findet man häufig Buchen, Eichen und Fichten
# Simpler Satz: In den Wäldern um Nessenreben gibt es häufig Buchen, Eichen und Fichten.
#
# Komplexer Satz: In den Wäldern leben Rehe, Wildschweine und Füchse, während die Wiesen und Felder Lebensraum für Vogelarten wie Rotkehlchen, Meisen und Bussarde bieten
# Simpler Satz: In den Wäldern leben Rehe, Wildschweine und Füchse. Die Wiesen und Felder sind Lebensraum für Vogelarten wie Rotkehlchen, Meisen und Bussarde.
#
# Komplexer Satz: Die Schweiz ist auch Mitgründer des Internationalen Rhönradturn-Verbandes (IRV), welcher 1995 gegründet wurde und seinen Sitz in Bern hat.
# Simpler Satz: Die Schweiz ist auch Mitgründer vom Internationalen Rhönradturn-Verbandes (irV). Der Verein wurde im Jahr 1995 gegründet.
#
# Komplexer Satz: Zusätzlich zu den drei Disziplinen wird im Level Elite der Mehrkampf angeboten.
# Simpler Satz: In den 3 Disziplinen gibt es mehrkampfe.
#
# Komplexer Satz: An den vier Qualifikationswettkämpfen können sich die besten Turner und Turnerinnen für die Schweizer Meisterschaft im März / April qualifizieren.
# Simpler Satz: An den vier Qualifikationswettkämpfen können sich die besten Turner und Turnerinnen für die Schweizer Meisterschaft im März / April qualifizieren.
#
# Komplexer Satz: An der Schweizer Meisterschaft wird jeweils auch bekannt gegeben, wer die Schweiz an den Weltmeisterschaften vertreten darf.
# Simpler Satz: An der Schweizer Meisterschaft wird bekannt gegeben, wer die Schweiz bei den Weltmeisterschaften spielen darf.
# Simpler Satz: Am 9. August 2024 stürzte das Flugzeug ab.
#
# Komplexer Satz: Im März 2024 wurde das Flugzeug durch einen Tailstrike beschädigt und kam nach Reparaturarbeiten erst am 9. Juli wieder zum regulären Einsatz.
# Simpler Satz: Im März 2024 wurde das Flugzeug beschädigt und kam nach Reparatur-Arbeiten am 9. Juli wieder zum normalen Einsatz.
#
# Komplexer Satz: Das Flugzeug war laut VoePass „ohne betriebliche Einschränkungen gestartet und alle Systeme waren für den Flug bereit“.
# Simpler Satz: Das Flugzeug war ohne betriebliche Einschränkungen gestartet. Alle Systeme waren bereit für den Flug.
#
# Komplexer Satz: Die im Februar 2011 in den Systems Two Studios, Brooklyn, entstandenen Aufnahmen erschienen 2011 auf dem Label Grizzley Music.
# Simpler Satz: Die entstandenen Aufnahmen erschienen im Februar 2011 in den Systems Two Studios, Brooklyn. Grizzley Music ist eine Firma aus den USA.
#
# Komplexer Satz: Das Album entstand als Tribut an den 2011 verstorbenen Schlagzeuger, Bandleader und Komponisten Paul Motian.
# Simpler Satz: Das Album entstand als Tribut an den 2011 verstorbenen Schlagzeuger, Bandleader und Komponisten Paul Motian.
#
# Komplexer Satz: Dieses Projekt wurde bereits vor Motians Tod konzipiert und brauchte mehrere Jahre, um Gestalt anzunehmen.
# Simpler Satz: Sie brauchte mehrere Jahre, um Gestalt anzunehmen.
#
# Komplexer Satz: Einheits-Schnellzugwagen Bauart 28 sind eine Serie von Schnellzugwagen, die von der Deutschen Reichsbahn-Gesellschaft ab 1928 in mehreren Serien nach einheitlichen Zeichnungen (Austauschbauart) beschafft wurden.
# Simpler Satz: Ein Schnellzugwagen wurde von der Deutschen Reichsbahn-Gesellschaft ab 1928 gebaut.
#
# Komplexer Satz: Von der Vorläuferbauart wurde auch die Länge über Puffer von 21,72 Metern übernommen, was gegenüber den Anfang der zwanziger Jahre beschafften Fahrzeugen die Vergrößerung der Abteile ermöglichte, teilweise wurde aber auch die Abteilanzahl leicht erhöht.
# Simpler Satz: Von der Vorläuferbauart wurde auch die Länge über Puffer übernommen.
#
# Komplexer Satz: Die für den Fährverkehr nach Schweden und Dänemark vorgesehenen Wagen erhielten Drehgestelle amerikanischer Bauart, Trossenösen an den Langträgern und Scheuerleisten mit Ösen auf dem Dach.
# Simpler Satz: Die für den Fährverkehr nach Schweden und Dänemark vorgesehenen Wagen bekamen Drehgestelle amerikanischer Bauart, Trossenösen an den Langträgern und Scheuerleisten mit Ösen auf dem Dach.
#
# Komplexer Satz: Die Gepäckwagen der Bauarten Pw4ü-28 und Pw4ü-29 unterschieden sich grundsätzlich nur durch die verbesserte Beleuchtung der neueren Wagen.
# Simpler Satz: Die Bauarten Pw4ü-28 und Pw4ü-29 unterschieden sich grundsätzlich nur durch die Beleuchtung der neuen Wagen.
#
# Komplexer Satz: Internationale Aufmerksamkeit erhielt die Gasse, als im August 2024 die drei Wiener Konzerte der US-amerikanischen Musikerin Taylor Swift im Rahmen ihrer The Eras Tour aufgrund eines geplanten terroristischen Anschlags abgesagt wurden.
# Simpler Satz: Im August 2024 wurden in Wien 3 Konzerte von Taylor Swift abgesagt. Swift ist eine US-amerikanische Musikerin.
#
# Komplexer Satz: Alle Gebäude der Corneliusgasse (bis auf Haus Nr. 6) befindet sich in einer baulichen Schutzzone, die von der Stadt Wien definiert wurde.
# Simpler Satz: Alle Gebäude der Corneliusgasse (bis auf Haus Nr. 6) sind in einer baulichen Schutzzone.
#
# Komplexer Satz: Viele Fans suchten nach der Absage, etwa um Trost zu finden, die Corneliusgasse auf, da Taylor Swift in ihrem 2019 veröffentlichten Album „Lover“ einen Song mit dem Titel „Cornelia Street“ veröffentlichte.
# Simpler Satz: Viele Fans suchten nach der Absage, etwa um Trost zu finden, die Corneliusgasse auf, da Taylor Swift in ihrem 2019 veröffentlichten Album Lover einen Song mit dem Titel Cornelia Street veröffentlichte.
#
# Komplexer Satz: Die Unruhen im Vereinigten Königreich 2024 sind eine Serie gewalttätiger Ausschreitungen im Vereinigten Königreich, die nach der Messerattacke in Southport begannen und sich innerhalb von Tagen auf Städte in England und Nordirland ausweiteten.
# Simpler Satz: Die Unruhen im Vereinigten Königreich 2024 sind eine Serie gewalttätiger Ausschreitungen im Vereinigten Königreich.
#
# Komplexer Satz: Ebenso beteiligte er sich an der Verbreitung von Inhalten, die zu einer Spaltung der britischen Gesellschaft beitragen könnten.
# Simpler Satz: Außerdem beteiligte er sich an der Verbreitung von Inhalten, die zu einer Spaltung der britischen Gesellschaft beitragen könnten.
#
# Komplexer Satz: Am 31. Juli 2024 kam es bei einer Demonstration unter dem Motto „Enough is enough“ („Genug ist genug“) nahe der Londoner Downing Street, dem Amtssitz des Premierministers, zu gewaltsamen Ausschreitungen zwischen Rechtsradikalen und der Polizei, bei denen über 100 Demonstranten vorübergehend festgenommen wurden.
# Simpler Satz: Am 31. Juli 2024 kam es bei einer Demonstration unter dem Motto Enough is genug (Genug ist genug) zu gewaltsamen Ausschreitungen zwischen Rechtsradikalen und der Polizei. Dabei wurden über 100 Demonstranten vorübergehend festgenommen.
#
# Komplexer Satz: Alleine am 3. August 2024 wurden landesweit 147 Personen wegen der Beteiligung an Ausschreitungen festgenommen.
# Simpler Satz: Alleine am 3. August 2024 wurden landesweit 147 Personen verhaftet.
#
# Komplexer Satz: Diese Stadt hatte durch den Niedergang des Kohlenabbaus und der Schiffbauindustrie zwischen 1975 und 1989 ein Viertel ihrer Arbeitsplätze verloren.
# Simpler Satz: Diese Stadt hatte durch den Niedergang des Kohlenabbaus und der Schiffbau-Industrie ein Viertel ihrer Arbeitsplätze verloren.
#
# Komplexer Satz: Am Tag nach den gewalttätigen Ausbrüchen versammelten sich Einwohner, um die Spuren zu beseitigen; wieder einen Tag später fand ein kleiner Friedensmarsch statt.
# Simpler Satz: Am Tag nach den Ausbrüchen versammelten sich Einwohner, um die Spuren zu beseitigen.
#
# Komplexer Satz: Der Tag wurde als Wendepunkt in der Entwicklung der Unruhen angesehen, jedoch noch nicht als das Ende dieser Vorkommnisse, zumal der relativ friedliche Verlauf dieses Tages möglicherweise hauptsächlich der Abschreckung durch die hohe Polizeipräsenz und durch die ersten Gefängnisstrafen, die für Gewalttäter verhängt worden waren, zu verdanken war.
# Simpler Satz: Der Tag wurde als Wendepunkt in der Entwicklung der Unruhen angesehen.
#
# Komplexer Satz: Auch in Bristol, das einige Tage zuvor Schauplatz gewalttätiger Aktionen gewesen war, fand am 7. August 2024 eine Gegendemonstration statt.
# Simpler Satz: Am 7. August 2024 war Schauplatz gewalttätiger Aktionen gewesen.
#
# Komplexer Satz: Als Reaktion auf die anhaltenden Unruhen veröffentlichten am 5. August mehrere Länder, darunter Australien, Nigeria und Indonesien, Reisewarnungen für das Vereinigte Königreich.
# Simpler Satz: Am 5. August wurden Reisewarnungen für das Vereinigte Königreich veröffentlicht.
#
# Processed and saved dataset: wikiDE_mBART_DE_simplified.csv
# {'wikiDE':                                      complex_sentence  \
#  0   Am 22. März 1985 unterzeichnete die Europäisch...
#  1   Im folgenden Jahr wurde die VERORDNUNG (EWG) N...
#  2   Zur Anpassung an die Änderungen des Montrealer...
#  3   Unternehmen müssen die Emissionen von geregelt...
#  4   Francesco Calzolari stammte aus einer alteinge...
#  5   Francescos kindliche Neugierde beschränkte sic...
#  6   Die Apotheke seines Vaters wurde auch von Gele...
#  7   Calzolari trat in die Fußstapfen seines Vaters...
#  8   Auch wenn ihn seine Arbeit als Apotheker davon...
#  9   Um den Monte Baldo noch näher zu sein, ließ si...
#  10  Es gilt als erstes und ältestes Naturkundemuse...
#  11  Diese kostete nur 20 Pfennig (ab 1871) und war...
#  12  Im Mittelalter lag südöstlich des heutigen Hof...
#  13  Nach der Auflösung der Garnison Weingarten nac...
#  14  In den Wäldern um Nessenreben findet man häufi...
#  15  In den Wäldern leben Rehe, Wildschweine und Fü...
#  16  Die Schweiz ist auch Mitgründer des Internatio...
#  17  Zusätzlich zu den drei Disziplinen wird im Lev...
#  18  An den vier Qualifikationswettkämpfen können s...
#  19  An der Schweizer Meisterschaft wird jeweils au...
#  20  Die Premiere der deutschen Produktion mit Vish...
#  21  Als der inhaftierten iranischen Menschenrechts...
#  22  Der ebenfalls in Teheran geborenene Majid Bakh...
#  23  Die Gumer kamen durch zwei Handelsunternehmen ...
#  24  Durch Einheirat waren die Gumer mit anderen al...
#  25  In Folge des Firmenkonkurses von 1799 und 1817...
#  26  Nach dem Bankrott des Handelshauses von Franz ...
#  27  Nach der österreichischen Rückeroberung Tirols...
#  28  Am 9. August 2024 stürzte das Flugzeug, eine A...
#  29  Im März 2024 wurde das Flugzeug durch einen Ta...
#  30  Das Flugzeug war laut VoePass „ohne betrieblic...
#  31  Die im Februar 2011 in den Systems Two Studios...
#  32  Das Album entstand als Tribut an den 2011 vers...
#  33  Dieses Projekt wurde bereits vor Motians Tod k...
#  34  Einheits-Schnellzugwagen Bauart 28 sind eine S...
#  35  Von der Vorläuferbauart wurde auch die Länge ü...
#  36  Die für den Fährverkehr nach Schweden und Däne...
#  37  Die Gepäckwagen der Bauarten Pw4ü-28 und Pw4ü-...
#  38  Internationale Aufmerksamkeit erhielt die Gass...
#  39  Alle Gebäude der Corneliusgasse (bis auf Haus ...
#  40  Viele Fans suchten nach der Absage, etwa um Tr...
#  41  Die Unruhen im Vereinigten Königreich 2024 sin...
#  42  Ebenso beteiligte er sich an der Verbreitung v...
#  43  Am 31. Juli 2024 kam es bei einer Demonstratio...
#  44  Alleine am 3. August 2024 wurden landesweit 14...
#  45  Diese Stadt hatte durch den Niedergang des Koh...
#  46  Am Tag nach den gewalttätigen Ausbrüchen versa...
#  47  Der Tag wurde als Wendepunkt in der Entwicklun...
#  48  Auch in Bristol, das einige Tage zuvor Schaupl...
#  49  Als Reaktion auf die anhaltenden Unruhen veröf...
#
#                                    simplified_sentence
#  0   Am 22. März 1985 unterzeichnete die Europäisch...
#  1   Im Jahr 2020 wurde die Verordnung zur Regelung...
#  2   Zur Anpassung an die Änderungen des Montrealer...
#  3   Die Firmen müssen die Emissionen von geregelte...
#  4   Im 13. Jahrhundert wurde er von einer Veronese...
#  5   Der Bub sammelte nämlich Mineralien, Fossilien...
#  6   Die Apotheke seines Vaters wurde auch von Gele...
#  7   Die Arbeit in der Apotheke wurde ihm von seine...
#  8   Auch wenn ihn seine Arbeit als Apotheker davon...
#  9   In Rivoli Veronese am südlichen Rand von der B...
#  10  Das Museum gilt als erstes und ältestes Naturk...
#  11  Diese Buchreihe kostete nur 20 Pfennig (ab 187...
#  12  Im Mittelalter lag südöstlich des heutigen Hof...
#  13  Nach der Auflösung der Garnison Weingarten nac...
#  14  In den Wäldern um Nessenreben gibt es häufig B...
#  15  In den Wäldern leben Rehe, Wildschweine und Fü...
#  16  Die Schweiz ist auch Mitgründer vom Internatio...
#  17           In den 3 Disziplinen gibt es mehrkampfe.
#  18  An den vier Qualifikationswettkämpfen können s...
#  19  An der Schweizer Meisterschaft wird bekannt ge...
#  20  Im September 2024 findet in Deutschland die Pr...
#  21  Die iranischen Menschenrechts-Aktivistin Marya...
#  22  Der ebenfalls in Teheran geborenene Majid Bakh...
#  23  Die Gumer kamen durch zwei Handelsunternehmen ...
#  24  Durch den Einheirat waren die Gumer mit andere...
#  25  In Folge des Firmen-Konkurses von 1799 und 181...
#  26  Nach dem Bankrott des Handelshauses von Franz ...
#  27  Nach der Rückeroberung Tirols zog sich 1814 na...
#  28         Am 9. August 2024 stürzte das Flugzeug ab.
#  29  Im März 2024 wurde das Flugzeug beschädigt und...
#  30  Das Flugzeug war ohne betriebliche Einschränku...
#  31  Die entstandenen Aufnahmen erschienen im Febru...
#  32  Das Album entstand als Tribut an den 2011 vers...
#  33  Sie brauchte mehrere Jahre, um Gestalt anzuneh...
#  34  Ein Schnellzugwagen wurde von der Deutschen Re...
#  35  Von der Vorläuferbauart wurde auch die Länge ü...
#  36  Die für den Fährverkehr nach Schweden und Däne...
#  37  Die Bauarten Pw4ü-28 und Pw4ü-29 unterschieden...
#  38  Im August 2024 wurden in Wien 3 Konzerte von T...
#  39  Alle Gebäude der Corneliusgasse (bis auf Haus ...
#  40  Viele Fans suchten nach der Absage, etwa um Tr...
#  41  Die Unruhen im Vereinigten Königreich 2024 sin...
#  42  Außerdem beteiligte er sich an der Verbreitung...
#  43  Am 31. Juli 2024 kam es bei einer Demonstratio...
#  44  Alleine am 3. August 2024 wurden landesweit 14...
#  45  Diese Stadt hatte durch den Niedergang des Koh...
#  46  Am Tag nach den Ausbrüchen versammelten sich E...
#  47  Der Tag wurde als Wendepunkt in der Entwicklun...
#  48  Am 7. August 2024 war Schauplatz gewalttätiger...
#  49  Am 5. August wurden Reisewarnungen für das Ver...  }

# %% [markdown]
# ### 4th Approach: DisSim by Niklaus et al.

# %%
# (first: intall DisSim: https://github.com/Lambda-3/DiscourseSimplification)

# open Terminal and run following commands in the DisSim folder:


# (installation; first time only)
# mvn clean install -DskipTests

# Create a text file input.txt (in the main DisSi folder) with the complex sentences to simplify
# hint: use the files in the "TS_MUSS_Sentences" folder, as the structure is identical

# run the program
# mvn clean compile exec:java

# copy the file JSON output file from the DisSim folder to the TS_model_outputs and name accordinlgy
# (e.g. wikiEN_DisSim_simplified.json)

# %%
import re
import pandas as pd
import json

def extract_simplified_sentences(json_data):
    sentences = []
    if 'sentences' in json_data:
        for sentence in json_data['sentences']:
            sentences.extend(extract_from_sentence(sentence))
    elif isinstance(json_data, list):
        for sentence in json_data:
            sentences.extend(extract_from_sentence(sentence))
    elif isinstance(json_data, dict):
        sentences.extend(extract_from_sentence(json_data))
    return sentences

def extract_from_sentence(sentence):
    extracted = []
    simple_contexts = {}
    element_texts = []

    for element in sentence['elementMap'].values():
        # Check if the element is a simplified version or part of the original sentence broken down
        if element['contextLayer'] > 0 or (element['contextLayer'] == 0 and element['text'] != sentence.get('originalSentence', '')):
            element_text = replace_brackets(element['text'].strip())
            element_texts.append(element_text)

        # Track simpleContexts
        if 'simpleContexts' in element:
            for context in element['simpleContexts']:
                if 'text' in context:
                    context_text = replace_brackets(context['text'].strip())
                    simple_contexts[context_text] = len(element_texts) - 1

    # Insert simpleContexts after their last mention
    for context_text, last_index in simple_contexts.items():
        element_texts.insert(last_index + 1, context_text)

    return element_texts

def replace_brackets(text):
    text = re.sub(r'-LRB- ', '(', text)
    text = re.sub(r' -RRB-', ')', text)
    text = re.sub(r'-LSB- ', '[', text)
    text = re.sub(r' -RSB-', ']', text)
    return text

def format_sentences(sentences):
    if not sentences:
        return "No simplified sentences found."
    formatted_sentences = ' '.join(sentences)
    formatted_sentences = re.sub(r'\s+([.,!?])', r'\1', formatted_sentences)
    return formatted_sentences

def process_json(json_data):
    results = []
    if 'sentences' in json_data:
        sentences = json_data['sentences']
    elif isinstance(json_data, list):
        sentences = json_data
    else:
        sentences = [json_data]
    
    for sentence in sentences:
        original_sentence = replace_brackets(sentence.get('originalSentence', 'No original sentence found.'))
        simplified = extract_from_sentence(sentence)
        formatted_simplified = format_sentences(simplified)
        results.append({
            'original_sentence': original_sentence,
            'simplified_sentences': formatted_simplified
        })
    return pd.DataFrame(results)

def run_DisSim_on_dataset(dataset_path):
    with open(dataset_path, "r") as file:
        data = json.load(file)
    return process_json(data)

# %%
lst_DisSim_files = [
    "../data/wikiEN_DisSim_simplified.json", 
    "../data/scotus_DisSim_simplified.json", 
    "../data/cochrane_DisSim_simplified.json"]

# turn into dataframe format and save as CSV
for file in lst_DisSim_files:
    df = run_DisSim_on_dataset(file)
    df.to_csv(file.replace(".json", ".csv"), index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 8
#       6 # turn into dataframe format and save as CSV
#       7 for file in lst_DisSim_files:
# ----> 8     df = run_DisSim_on_dataset(file)
#       9     df.to_csv(file.replace(".json", ".csv"), index=False)
#
# NameError: name 'run_DisSim_on_dataset' is not defined

# %% [markdown]
# ---
#
# ## Convert CSVs to SALSA Annotation Tool Format

# %%
data_f_wikiEN_DisSim = pd.read_csv("../data/TS_model_outputs/wikiEN_DisSim_simplified.csv")
data_f_wikiEN_DisSim.head(10)
# Out:
#                                    original_sentence  \
# 0  The N1 road also designated as RN1, is a road ...
# 1  Originating in the capital city of Bangui, the...
# 2  As a key component of the country's road netwo...
# 3  The N1 route commences in the heart of Bangui,...
# 4  The terrain along this stretch is characterize...
# 5  She married Marcus Claudius Marcellus Aesernin...
# 6  Asinia was a noblewoman of ancient Roman who w...
# 7  Influenced by his father Jinghui, whom was als...
# 8  In 1853, Saišangga was stripped of official po...
# 9  2-Chloronicotinic acid (2-CNA) is a halogenate...
#
#                                 simplified_sentences
# 0  The N1 road also designated as RN1, is a road ...
# 1  The road is originating in the capital city of...
# 2  The N1 facilitates connectivity between the ca...
# 3  The N1 route commences in the heart of Bangui,...
# 4  The terrain along this stretch is characterize...
# 5  She married Marcus Claudius Marcellus Aesernin...
# 6  Asinia was a noblewoman of ancient Roman. A no...
# 7  Jinghui, Saišangga was proficient in Manchu, M...
# 8  Saišangga was stripped of official position. S...
# 9  2-Chloronicotinic acid (2-CNA) is a halogenate...

# %%
data_f_SCOTUS_DisSim = pd.read_csv("../data/TS_model_outputs/scotus_DisSim_simplified.csv")
data_f_SCOTUS_DisSim.head(10)
# Out:
#                                    original_sentence  \
# 0  To determine whether Corner Post’s APA claim i...
# 1  While the Board argues that §2401(a) should no...
# 2  Importantly, contemporaneous dictionaries also...
# 3  The Board leaves open the possibility that som...
# 4  The APA provisions grant Corner Post a cause o...
# 5  Statutes of limitations ‘require plaintiffs to...
# 6  The Board’s interpretation would thereby decou...
# 7  The Board’s arguments to the contrary lack merit.
# 8  Departing from the traditional rule is particu...
# 9  While §702 equips injured parties with a cause...
#
#                                 simplified_sentences
# 0  The Court must interpret § 2401 (a), which pro...
# 1  § 2401 (a) should not be interpreted to adopt ...
# 2  A cause of action accrues `` on [the] date tha...
# 3  The Board leaves open the possibility. Someone...
# 4  Corner Post a cause of action subject to certa...
# 5  Statutes of limitations ` require plaintiffs t...
# 6  The Board 's interpretation would thereby deco...
# 7  The Board 's arguments to the contrary lack me...
# 8  Departing from the traditional rule is particu...
# 9  § 702 equips injured parties. This is with a c...

# %%
data_f_Cochrane_DisSim = pd.read_csv("../data/TS_model_outputs/cochrane_DisSim_simplified.csv")
data_f_Cochrane_DisSim.head(10)
# Out:
#                                    original_sentence  \
# 0  TEP technique may carry a higher risk of conve...
# 1  An inguinal hernia occurs when part of the int...
# 2  There may be little to no difference between T...
# 3  TEP technique may carry a higher risk of conve...
# 4  CBT may result in a small‐to‐moderate reductio...
# 5  However, compared to this benefit with CBT imm...
# 6  CBT may result in a reduction of comorbid depr...
# 7  There is not enough evidence to determine whet...
# 8  To assess the effects of Cognitive Behavioural...
# 9  Percutaneous and surgical interventions combin...
#
#                                 simplified_sentences
# 0  TEP technique may carry a higher risk of conve...
# 1  An inguinal hernia occurs. Part of the intesti...
# 2  There may be little to no difference between T...
# 3  TEP technique may carry a higher risk of conve...
# 4  CBT may result in a small‐to‐moderate reductio...
# 5  There was little to no difference between CBT ...
# 6  CBT may result in a reduction of comorbid depr...
# 7  There is not enough evidence to determine whet...
# 8  To assess the effects of Cognitive Behavioural...
# 9  Percutaneous can be used to treat uncomplicate...

# %%
# read in model generated output files

data_f_wikiEN_ChatGPT = pd.read_csv("../data/TS_model_outputs/TS_final_sentences/wikiEN_OpenAI_simplified.csv")
data_f_wikiEN_LLAMA = pd.read_csv("../data/TS_model_outputs/TS_final_sentences/wikiEN_LLAMA31_simplified.csv")
data_f_wikiEN_MUSS = pd.read_csv("../data/TS_model_outputs/TS_final_sentences/wikiEN_MUSS_simplified.csv") # TODO: change to TS_final_sentences folder
data_f_wikiEN_MUSS.columns = ['complex_sentence', 'simplified_sentence']
data_f_wikiEN_DisSim = pd.read_csv("../data/TS_model_outputs/TS_final_sentences/wikiEN_DisSim_simplified.csv")
data_f_wikiEN_DisSim.columns = ['complex_sentence', 'simplified_sentence']

data_f_Cochrane_ChatGPT = pd.read_csv("../data/TS_model_outputs/TS_final_sentences/cochrane_OpenAI_simplified.csv")
data_f_Cochrane_LLAMA = pd.read_csv("../data/TS_model_outputs/TS_final_sentences/cochrane_LLAMA31_simplified.csv")
data_f_Cochrane_MUSS = pd.read_csv("../data/TS_model_outputs/TS_final_sentences/cochrane_MUSS_simplified.csv")
data_f_Cochrane_MUSS.columns = ['complex_sentence', 'simplified_sentence']
data_f_Cochrane_DisSim = pd.read_csv("../data/TS_model_outputs/TS_final_sentences/cochrane_DisSim_simplified.csv")
data_f_Cochrane_DisSim.columns = ['complex_sentence', 'simplified_sentence']

data_f_SCOTUS_ChatGPT = pd.read_csv("../data/TS_model_outputs/TS_final_sentences/scotus_OpenAI_simplified.csv")
data_f_SCOTUS_LLAMA = pd.read_csv("../data/TS_model_outputs/TS_final_sentences/scotus_LLAMA31_simplified.csv")
data_f_SCOTUS_MUSS = pd.read_csv("../data/TS_model_outputs/TS_final_sentences/scotus_MUSS_simplified.csv")
data_f_SCOTUS_MUSS.columns = ['complex_sentence', 'simplified_sentence']
data_f_SCOTUS_DisSim = pd.read_csv("../data/TS_model_outputs/TS_final_sentences/scotus_DisSim_simplified.csv")
data_f_SCOTUS_DisSim.columns = ['complex_sentence', 'simplified_sentence']

data_f_wikiDE_ChatGPT = pd.read_csv("../data/TS_model_outputs/TS_final_sentences/wikiDE_OpenAI_simplified.csv")
data_f_wikiDE_LLAMA = pd.read_csv("../data/TS_model_outputs/TS_final_sentences/wikiDE_LLAMA31_simplified.csv")
data_f_wikiDE_MBART = pd.read_csv("../data/TS_model_outputs/TS_final_sentences/wikiDE_mBART_DE_simplified.csv")
# No DisSim for German

# %%
# rename data_f_SCOTUS_DisSim.columns to complex_sentence and simplified_sentence
#data_f_SCOTUS_DisSim.columns = ['complex_sentence', 'simplified_sentence']

data_f_SCOTUS_DisSim.columns
# Out:
# Index(['complex_sentence', 'simplified_sentence'], dtype='object')

# %%
def convert_and_save_to_json(df, output_directory, df_name):
    result = []

    # Extract the model name from the DataFrame name
    model_name = df_name.split('_')[-1] if '_' in df_name else 'unknown_model'
    
    for _, row in df.iterrows():
        entry = {
            "source": row["complex_sentence"],
            "target": row["simplified_sentence"],
            "metadata": {
                "annotator": "annotator_0",
                "system": model_name
            },
            "edits": []
        }
        result.append(entry)

    # for all target sentences, replace ". " with ". || "
    for entry in result:
        entry['target'] = entry['target'].replace(". ", ". || ")
    
    # Create the output directory if it doesn't exist
    os.makedirs(output_directory, exist_ok=True)
    
    # Generate filename based on the DataFrame name
    filename = f"{df_name}.json"
    
    # Full path for the output file
    output_path = os.path.join(output_directory, filename)
    
    # Save the JSON to the file
    with open(output_path, 'w', encoding='utf-8') as f:
        json.dump(result, f, ensure_ascii=False, indent=2)
    
    #print(f"JSON file saved to: {output_path}")
    print(f"Exported {var_name} to {filename}")
    return json.dumps(result, indent=2)

# %%
output_directory = "../data/salsa_annotations/raw_unannotated"

# for ds in datasets_complete:
#     convert_and_save_to_json(ds, output_directory, df_name)

# Get all global variables
global_vars = sys.modules['__main__'].__dict__.copy()

# Iterate through global variables
for var_name, var_value in global_vars.items():
    # Check if the variable is a pandas DataFrame and starts with 'data_'
    if isinstance(var_value, pd.DataFrame) and var_name.startswith('data_f'):
        print(".. trying to convert: ", var_name)
        convert_and_save_to_json(var_value, output_directory, var_name)
# Out:
# .. trying to convert:  data_f_wikiEN_ChatGPT
# Exported data_f_wikiEN_ChatGPT to data_f_wikiEN_ChatGPT.json
# .. trying to convert:  data_f_wikiEN_LLAMA
# Exported data_f_wikiEN_LLAMA to data_f_wikiEN_LLAMA.json
# .. trying to convert:  data_f_wikiEN_MUSS
# Exported data_f_wikiEN_MUSS to data_f_wikiEN_MUSS.json
# .. trying to convert:  data_f_wikiEN_DisSim
# Exported data_f_wikiEN_DisSim to data_f_wikiEN_DisSim.json
# .. trying to convert:  data_f_Cochrane_ChatGPT
# Exported data_f_Cochrane_ChatGPT to data_f_Cochrane_ChatGPT.json
# .. trying to convert:  data_f_Cochrane_LLAMA
# Exported data_f_Cochrane_LLAMA to data_f_Cochrane_LLAMA.json
# .. trying to convert:  data_f_Cochrane_MUSS
# Exported data_f_Cochrane_MUSS to data_f_Cochrane_MUSS.json
# .. trying to convert:  data_f_Cochrane_DisSim
# Exported data_f_Cochrane_DisSim to data_f_Cochrane_DisSim.json
# .. trying to convert:  data_f_SCOTUS_ChatGPT
# Exported data_f_SCOTUS_ChatGPT to data_f_SCOTUS_ChatGPT.json
# .. trying to convert:  data_f_SCOTUS_LLAMA
# Exported data_f_SCOTUS_LLAMA to data_f_SCOTUS_LLAMA.json
# .. trying to convert:  data_f_SCOTUS_MUSS
# Exported data_f_SCOTUS_MUSS to data_f_SCOTUS_MUSS.json
# .. trying to convert:  data_f_SCOTUS_DisSim
# Exported data_f_SCOTUS_DisSim to data_f_SCOTUS_DisSim.json
# .. trying to convert:  data_f_wikiDE_ChatGPT
# Exported data_f_wikiDE_ChatGPT to data_f_wikiDE_ChatGPT.json
# .. trying to convert:  data_f_wikiDE_LLAMA
# Exported data_f_wikiDE_LLAMA to data_f_wikiDE_LLAMA.json
# .. trying to convert:  data_f_wikiDE_MBART
# Exported data_f_wikiDE_MBART to data_f_wikiDE_MBART.json
